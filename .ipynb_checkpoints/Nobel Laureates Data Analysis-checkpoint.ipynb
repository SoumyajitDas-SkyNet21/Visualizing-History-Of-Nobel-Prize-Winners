# %% [markdown]
# ## Visualizing History Of Nobel Prize Winners

# %% [markdown]
# ### Project Description

# %% [markdown]
# <b>Project Goal: <b>
# - Analyze Nobel Prize winner data
#
# <b>Business Problem</b>
# - What is the most commonly awarded gender and birth country?
# - Which decade had the highest ratio of US-born Nobel Prize winners to total winners in all categories ?
# - Which decade and Nobel Prize category combination had the highest proportion of female laureates ?
# - Who was the first woman to receive a Nobel Prize, and in what category?
# - Which individuals or organizations have won more than one Nobel Prize throughout the years?
#
# <b> Data Source </b>
# - Developer Zone - API Version 1 -https://api.nobelprize.org/2.1/laureates

# %%
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# #### API Version 1

# %%
url='http://api.nobelprize.org/v1/prize.json'

# %%
response_api_v1=requests.get(url).json()

# %%
response_api_v1['prizes'][0]
# Out:
# {'year': '2024',
#  'category': 'chemistry',
#  'laureates': [{'id': '1039',
#    'firstname': 'David',
#    'surname': 'Baker',
#    'motivation': '"for computational protein design"',
#    'share': '2'},
#   {'id': '1040',
#    'firstname': 'Demis',
#    'surname': 'Hassabis',
#    'motivation': '"for protein structure prediction"',
#    'share': '4'},
#   {'id': '1041',
#    'firstname': 'John',
#    'surname': 'Jumper',
#    'motivation': '"for protein structure prediction"',
#    'share': '4'}]}

# %%
response_api_v1['prizes'][3]
# Out:
# {'year': '2024',
#  'category': 'peace',
#  'laureates': [{'id': '1043',
#    'motivation': '"for its efforts to achieve a world free of nuclear weapons and for demonstrating through witness testimony that nuclear weapons must never be used again"',
#    'share': '1',
#    'firstname': 'Nihon Hidankyo'}]}

# %%
ids=[]
firstname=[]
surname=[]
year=[]
category=[]
motivation=[]
share=[]
for i in response_api_v1['prizes'][0]['laureates']:
    # Here, i means each individual dictionary.
    # Appending the details of laureates dictionary to a list
    # Appending the id to the list 
    ids.append(i['id'])
    # Appending the firstname to the list
    firstname.append(i['firstname'])
    # Appending the surname to the list 
    surname.append(i['surname'])
    # Appending the motivation to the list 
    motivation.append(i['motivation'])
    year.append(response_api_v1['prizes'][0]['year'])
    category.append(response_api_v1['prizes'][0]['category'])

# %%
print(ids)
print(firstname)
print(surname)
print(year)
print(category)
print(motivation)
# Out:
# ['1039', '1040', '1041']
# ['David', 'Demis', 'John']
# ['Baker', 'Hassabis', 'Jumper']
# ['2024', '2024', '2024']
# ['chemistry', 'chemistry', 'chemistry']
# ['"for computational protein design"', '"for protein structure prediction"', '"for protein structure prediction"']

# %%
# Length of the whole dictionary
var=len(response_api_v1['prizes'])
var
# Out:
# 676

# %% [markdown]
# ### Checking Consistencies of keys in dictionary

# %%
'surname' in response_api_v1['prizes'][0]['laureates'][0]
# Out:
# True

# %%
response_api_v1['prizes'][0]['laureates'][0]['surname']
# Out:
# 'Baker'

# %% [markdown]
# #### Checking 'surname' is there in every 'laureate' or not

# %%
k=0
for count in range(var):
    if 'laureates' in response_api_v1['prizes'][count]:
        for index,j in enumerate(response_api_v1['prizes'][count]['laureates']):
            if 'surname' in response_api_v1['prizes'][count]['laureates'][index]:
                pass
            else:
                # Printing out the keys where surname is not present
                print('Not Consistent Key',count,response_api_v1['prizes'][count]['laureates'][index].keys())
                k+=1
                break
    else: 
        print(count)
        break
print(k)
# Out:
# Not Consistent Key 3 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 15 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 27 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 45 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 57 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 69 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 75 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 105 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 111 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 117 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 141 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 153 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 165 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 177 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 201 dict_keys(['id', 'firstname', 'motivation', 'share'])
# Not Consistent Key 219 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 237 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 261 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 285 dict_keys(['id', 'motivation', 'share', 'firstname'])
# Not Consistent Key 309 dict_keys(['id', 'firstname', 'motivation', 'share'])
# 315
# 20

# %% [markdown]
# #### Checking 'firstname' is there in every 'laureate' or not

# %%
k=True
for count in range(var):
    if 'laureates' in response_api_v1['prizes'][count]:
        for index,j in enumerate(response_api_v1['prizes'][count]['laureates']):
            if 'firstname' in response_api_v1['prizes'][count]['laureates'][index]:
                pass
            else:
                # Printing out the keys where surname is not present
                k=False
                print('Not Consistent Key',count,response_api_v1['prizes'][count]['laureates'][index].keys())
                break
if k==False:
    print('firstname is not present in all of the dictionary')
else:
    print('firstname is there in all of the dictionary')
# Out:
# firstname is there in all of the dictionary

# %% [markdown]
# #### Checking 'motivation' is there in every 'laureate' or not

# %%
k=True
for count in range(var):
    if 'laureates' in response_api_v1['prizes'][count]:
        for index,j in enumerate(response_api_v1['prizes'][count]['laureates']):
            if 'motivation' in response_api_v1['prizes'][count]['laureates'][index]:
                pass
            else:
                # Printing out the keys where surname is not present
                k=False
                print('Not Consistent Key',count,response_api_v1['prizes'][count]['laureates'][index].keys())
                break
if k==False:
    print('motivation is not present in all of the dictionary')
else:
    print('motivation is there in all of the dictionary')
# Out:
# motivation is there in all of the dictionary

# %% [markdown]
# #### Checking 'share' is there in every 'laureate' or not

# %%
k=True
for count in range(var):
    if 'laureates' in response_api_v1['prizes'][count]:
        for index,j in enumerate(response_api_v1['prizes'][count]['laureates']):
            if 'share' in response_api_v1['prizes'][count]['laureates'][index]:
                pass
            else:
                # Printing out the keys where surname is not present
                print('Not Consistent Key',count,response_api_v1['prizes'][count]['laureates'][index].keys())
                break
if k==False:
    print('share is not present in all of the dictionary')
else:
    print('share is there in all of the dictionary')
# Out:
# share is there in all of the dictionary

# %% [markdown]
# #### Checking 'share' is there in every 'laureate' or not

# %%
k=True
for count in range(var):
    if 'laureates' in response_api_v1['prizes'][count]:
        for index,j in enumerate(response_api_v1['prizes'][count]['laureates']):
            if 'id' in response_api_v1['prizes'][count]['laureates'][index]:
                pass
            else:
                # Printing out the keys where surname is not present
                k=False
                print('Not Consistent Key',count,response_api_v1['prizes'][count]['laureates'][index].keys())
                break
if k==False:
    print('id is not present in all of the dictionary')
else:
    print('id is there in all of the dictionary')
# Out:
# id is there in all of the dictionary

# %% [markdown]
# ### Now writing a script where the surname is not present

# %%
ids=[]
firstname=[]
surname=[]
year=[]
category=[]
motivation=[]
share=[]

# %%
for count in range(var):
    if 'laureates' in response_api_v1['prizes'][count]:
        for index,j in enumerate(response_api_v1['prizes'][count]['laureates']):
            if 'surname' not in response_api_v1['prizes'][count]['laureates'][index]:
                surname.append(None)
                ids.append(j['id'])
                # Appending the firstname to the list
                firstname.append(j['firstname'])
                # Appending the motivation to the list 
                motivation.append(j['motivation'])
                year.append(response_api_v1['prizes'][count]['year'])
                category.append(response_api_v1['prizes'][count]['category'])
                share.append(j['share'])
            else:
                ids.append(j['id'])
                # Appending the firstname to the list
                firstname.append(j['firstname'])
                # Appending the motivation to the list 
                motivation.append(j['motivation'])
                # Appending the surname to the list 
                surname.append(j['surname'])
                year.append(response_api_v1['prizes'][count]['year'])
                category.append(response_api_v1['prizes'][count]['category'])
                share.append(j['share'])

# %%
len(surname)
# Out:
# 1012

# %%
len(ids)
# Out:
# 1012

# %%
len(firstname)
# Out:
# 1012

# %%
len(motivation)
# Out:
# 1012

# %%
len(category)
# Out:
# 1012

# %%
len(share)
# Out:
# 1012

# %%
len(year)
# Out:
# 1012

# %%
count=0
for i in surname:
    if i==None:
        count+=1
print(count)
# Out:
# 33

# %%
for i in surname:
    print(type(i),i)
# Out:
# <class 'str'> Baker
# <class 'str'> Hassabis
# <class 'str'> Jumper
# <class 'str'> Acemoglu
# <class 'str'> Johnson
# <class 'str'> Robinson
# <class 'str'> Han
# <class 'NoneType'> None
# <class 'str'> Hopfield
# <class 'str'> Hinton
# <class 'str'> Ambros
# <class 'str'> Ruvkun
# <class 'str'> Bawendi
# <class 'str'> Brus
# <class 'str'> Yekimov
# <class 'str'> Goldin
# <class 'str'> Fosse
# <class 'str'> Mohammadi
# <class 'str'> Agostini
# <class 'str'> Krausz
# <class 'str'> L’Huillier
# <class 'str'> Karikó
# <class 'str'> Weissman
# <class 'str'> Bertozzi
# <class 'str'> Meldal
# <class 'str'> Sharpless
# <class 'str'> Bernanke
# <class 'str'> Diamond
# <class 'str'> Dybvig
# <class 'str'> Ernaux
# <class 'str'> Bialiatski
# <class 'NoneType'> None
# <class 'NoneType'> None
# <class 'str'> Aspect
# <class 'str'> Clauser
# <class 'str'> Zeilinger
# <class 'str'> Pääbo
# <class 'str'> List
# <class 'str'> MacMillan
# <class 'str'> Card
# <class 'str'> Angrist
# <class 'str'> Imbens
# <class 'str'> Gurnah
# <class 'str'> Ressa
# <class 'str'> Muratov
# <class 'str'> Manabe
# <class 'str'> Hasselmann
# <class 'str'> Parisi
# <class 'str'> Julius
# <class 'str'> Patapoutian
# <class 'str'> Charpentier
# <class 'str'> Doudna
# <class 'str'> Milgrom
# <class 'str'> Wilson
# <class 'str'> Glück
# <class 'NoneType'> None
# <class 'str'> Penrose
# <class 'str'> Genzel
# <class 'str'> Ghez
# <class 'str'> Alter
# <class 'str'> Houghton
# <class 'str'> Rice
# <class 'str'> Goodenough
# <class 'str'> Whittingham
# <class 'str'> Yoshino
# <class 'str'> Banerjee
# <class 'str'> Duflo
# <class 'str'> Kremer
# <class 'str'> Handke
# <class 'str'> Ahmed Ali
# <class 'str'> Peebles
# <class 'str'> Mayor
# <class 'str'> Queloz
# <class 'str'> Kaelin
# <class 'str'> Ratcliffe
# <class 'str'> Semenza
# <class 'str'> Arnold
# <class 'str'> Smith
# <class 'str'> Winter
# <class 'str'> Nordhaus
# <class 'str'> Romer
# <class 'str'> Tokarczuk
# <class 'str'> Mukwege
# <class 'str'> Murad
# <class 'str'> Ashkin
# <class 'str'> Mourou
# <class 'str'> Strickland
# <class 'str'> Allison
# <class 'str'> Honjo
# <class 'str'> Dubochet
# <class 'str'> Frank
# <class 'str'> Henderson
# <class 'str'> Thaler
# <class 'str'> Ishiguro
# <class 'NoneType'> None
# <class 'str'> Weiss
# <class 'str'> Barish
# <class 'str'> Thorne
# <class 'str'> Hall
# <class 'str'> Rosbash
# <class 'str'> Young
# <class 'str'> Sauvage
# <class 'str'> Stoddart
# <class 'str'> Feringa
# <class 'str'> Hart
# <class 'str'> Holmström
# <class 'str'> Dylan
# <class 'str'> Santos
# <class 'str'> Thouless
# <class 'str'> Haldane
# <class 'str'> Kosterlitz
# <class 'str'> Ohsumi
# <class 'str'> Lindahl
# <class 'str'> Modrich
# <class 'str'> Sancar
# <class 'str'> Deaton
# <class 'str'> Alexievich
# <class 'NoneType'> None
# <class 'str'> Kajita
# <class 'str'> McDonald
# <class 'str'> Campbell
# <class 'str'> Ōmura
# <class 'str'> Tu
# <class 'str'> Betzig
# <class 'str'> Hell
# <class 'str'> Moerner
# <class 'str'> Tirole
# <class 'str'> Modiano
# <class 'str'> Satyarthi
# <class 'str'> Yousafzai
# <class 'str'> Akasaki
# <class 'str'> Amano
# <class 'str'> Nakamura
# <class 'str'> O'Keefe
# <class 'str'> Moser
# <class 'str'> Moser
# <class 'str'> Karplus
# <class 'str'> Levitt
# <class 'str'> Warshel
# <class 'str'> Fama
# <class 'str'> Hansen
# <class 'str'> Shiller
# <class 'str'> Munro
# <class 'NoneType'> None
# <class 'str'> Englert
# <class 'str'> Higgs
# <class 'str'> Rothman
# <class 'str'> Schekman
# <class 'str'> Südhof
# <class 'str'> Lefkowitz
# <class 'str'> Kobilka
# <class 'str'> Roth
# <class 'str'> Shapley
# <class 'str'> Yan
# <class 'NoneType'> None
# <class 'str'> Haroche
# <class 'str'> Wineland
# <class 'str'> Gurdon
# <class 'str'> Yamanaka
# <class 'str'> Shechtman
# <class 'str'> Sargent
# <class 'str'> Sims
# <class 'str'> Tranströmer
# <class 'str'> Johnson Sirleaf
# <class 'str'> Gbowee
# <class 'str'> Karman
# <class 'str'> Perlmutter
# <class 'str'> Schmidt
# <class 'str'> Riess
# <class 'str'> Beutler
# <class 'str'> Hoffmann
# <class 'str'> Steinman
# <class 'str'> Heck
# <class 'str'> Negishi
# <class 'str'> Suzuki
# <class 'str'> Diamond
# <class 'str'> Mortensen
# <class 'str'> Pissarides
# <class 'str'> Vargas Llosa
# <class 'str'> Liu
# <class 'str'> Geim
# <class 'str'> Novoselov
# <class 'str'> Edwards
# <class 'str'> Ramakrishnan
# <class 'str'> Steitz
# <class 'str'> Yonath
# <class 'str'> Ostrom
# <class 'str'> Williamson
# <class 'str'> Müller
# <class 'str'> Obama
# <class 'str'> Kao
# <class 'str'> Boyle
# <class 'str'> Smith
# <class 'str'> Blackburn
# <class 'str'> Greider
# <class 'str'> Szostak
# <class 'str'> Shimomura
# <class 'str'> Chalfie
# <class 'str'> Tsien
# <class 'str'> Krugman
# <class 'str'> Le Clézio
# <class 'str'> Ahtisaari
# <class 'str'> Nambu
# <class 'str'> Kobayashi
# <class 'str'> Maskawa
# <class 'str'> zur Hausen
# <class 'str'> Barré-Sinoussi
# <class 'str'> Montagnier
# <class 'str'> Ertl
# <class 'str'> Hurwicz
# <class 'str'> Maskin
# <class 'str'> Myerson
# <class 'str'> Lessing
# <class 'NoneType'> None
# <class 'str'> Gore
# <class 'str'> Fert
# <class 'str'> Grünberg
# <class 'str'> Capecchi
# <class 'str'> Evans
# <class 'str'> Smithies
# <class 'str'> Kornberg
# <class 'str'> Phelps
# <class 'str'> Pamuk
# <class 'str'> Yunus
# <class 'NoneType'> None
# <class 'str'> Mather
# <class 'str'> Smoot
# <class 'str'> Fire
# <class 'str'> Mello
# <class 'str'> Chauvin
# <class 'str'> Grubbs
# <class 'str'> Schrock
# <class 'str'> Aumann
# <class 'str'> Schelling
# <class 'str'> Pinter
# <class 'NoneType'> None
# <class 'str'> ElBaradei
# <class 'str'> Glauber
# <class 'str'> Hall
# <class 'str'> Hänsch
# <class 'str'> Marshall
# <class 'str'> Warren
# <class 'str'> Ciechanover
# <class 'str'> Hershko
# <class 'str'> Rose
# <class 'str'> Kydland
# <class 'str'> Prescott
# <class 'str'> Jelinek
# <class 'str'> Maathai
# <class 'str'> Gross
# <class 'str'> Politzer
# <class 'str'> Wilczek
# <class 'str'> Axel
# <class 'str'> Buck
# <class 'str'> Agre
# <class 'str'> MacKinnon
# <class 'str'> Engle III
# <class 'str'> Granger
# <class 'str'> Coetzee
# <class 'str'> Ebadi
# <class 'str'> Abrikosov
# <class 'str'> Ginzburg
# <class 'str'> Leggett
# <class 'str'> Lauterbur
# <class 'str'> Mansfield
# <class 'str'> Fenn
# <class 'str'> Tanaka
# <class 'str'> Wüthrich
# <class 'str'> Kahneman
# <class 'str'> Smith
# <class 'str'> Kertész
# <class 'str'> Carter
# <class 'str'> Davis Jr.
# <class 'str'> Koshiba
# <class 'str'> Giacconi
# <class 'str'> Brenner
# <class 'str'> Horvitz
# <class 'str'> Sulston
# <class 'str'> Knowles
# <class 'str'> Noyori
# <class 'str'> Sharpless
# <class 'str'> Akerlof
# <class 'str'> Spence
# <class 'str'> Stiglitz
# <class 'str'> Naipaul
# <class 'NoneType'> None
# <class 'str'> Annan
# <class 'str'> Cornell
# <class 'str'> Ketterle
# <class 'str'> Wieman
# <class 'str'> Nurse
# <class 'str'> Hartwell
# <class 'str'> Hunt
# <class 'str'> Heeger
# <class 'str'> MacDiarmid
# <class 'str'> Shirakawa
# <class 'str'> Heckman
# <class 'str'> McFadden
# <class 'str'> Gao
# <class 'str'> Dae-jung
# <class 'str'> Alferov
# <class 'str'> Kroemer
# <class 'str'> Kilby
# <class 'str'> Carlsson
# <class 'str'> Greengard
# <class 'str'> Kandel
# <class 'str'> Zewail
# <class 'str'> Mundell
# <class 'str'> Grass
# <class 'NoneType'> None
# <class 'str'> 't Hooft
# <class 'str'> Veltman
# <class 'str'> Blobel
# <class 'str'> Kohn
# <class 'str'> Pople
# <class 'str'> Sen
# <class 'str'> Saramago
# <class 'str'> Hume
# <class 'str'> Trimble
# <class 'str'> Laughlin
# <class 'str'> Störmer
# <class 'str'> Tsui
# <class 'str'> Furchgott
# <class 'str'> Ignarro
# <class 'str'> Murad
# <class 'str'> Boyer
# <class 'str'> Walker
# <class 'str'> Skou
# <class 'str'> Merton
# <class 'str'> Scholes
# <class 'str'> Fo
# <class 'NoneType'> None
# <class 'str'> Williams
# <class 'str'> Chu
# <class 'str'> Cohen-Tannoudji
# <class 'str'> Phillips
# <class 'str'> Prusiner
# <class 'str'> Curl Jr.
# <class 'str'> Kroto
# <class 'str'> Smalley
# <class 'str'> Mirrlees
# <class 'str'> Vickrey
# <class 'str'> Szymborska
# <class 'str'> Belo
# <class 'str'> Ramos-Horta
# <class 'str'> Lee
# <class 'str'> Osheroff
# <class 'str'> Richardson
# <class 'str'> Doherty
# <class 'str'> Zinkernagel
# <class 'str'> Crutzen
# <class 'str'> Molina
# <class 'str'> Rowland
# <class 'str'> Lucas Jr.
# <class 'str'> Heaney
# <class 'str'> Rotblat
# <class 'NoneType'> None
# <class 'str'> Perl
# <class 'str'> Reines
# <class 'str'> Lewis
# <class 'str'> Nüsslein-Volhard
# <class 'str'> Wieschaus
# <class 'str'> Olah
# <class 'str'> Harsanyi
# <class 'str'> Nash Jr.
# <class 'str'> Selten
# <class 'str'> Oe
# <class 'str'> Arafat
# <class 'str'> Peres
# <class 'str'> Rabin
# <class 'str'> Brockhouse
# <class 'str'> Shull
# <class 'str'> Gilman
# <class 'str'> Rodbell
# <class 'str'> Mullis
# <class 'str'> Smith
# <class 'str'> Fogel
# <class 'str'> North
# <class 'str'> Morrison
# <class 'str'> Mandela
# <class 'str'> de Klerk
# <class 'str'> Hulse
# <class 'str'> Taylor Jr.
# <class 'str'> Roberts
# <class 'str'> Sharp
# <class 'str'> Marcus
# <class 'str'> Becker
# <class 'str'> Walcott
# <class 'str'> Menchú Tum
# <class 'str'> Charpak
# <class 'str'> Fischer
# <class 'str'> Krebs
# <class 'str'> Ernst
# <class 'str'> Coase
# <class 'str'> Gordimer
# <class 'NoneType'> None
# <class 'str'> de Gennes
# <class 'str'> Neher
# <class 'str'> Sakmann
# <class 'str'> Corey
# <class 'str'> Markowitz
# <class 'str'> Miller
# <class 'str'> Sharpe
# <class 'str'> Paz
# <class 'str'> Gorbachev
# <class 'str'> Friedman
# <class 'str'> Kendall
# <class 'str'> Taylor
# <class 'str'> Murray
# <class 'str'> Thomas
# <class 'str'> Altman
# <class 'str'> Cech
# <class 'str'> Haavelmo
# <class 'str'> Cela
# <class 'str'> Thondup
# <class 'str'> Ramsey
# <class 'str'> Dehmelt
# <class 'str'> Paul
# <class 'str'> Bishop
# <class 'str'> Varmus
# <class 'str'> Deisenhofer
# <class 'str'> Huber
# <class 'str'> Michel
# <class 'str'> Allais
# <class 'str'> Mahfouz
# <class 'NoneType'> None
# <class 'str'> Lederman
# <class 'str'> Schwartz
# <class 'str'> Steinberger
# <class 'str'> Black
# <class 'str'> Elion
# <class 'str'> Hitchings
# <class 'str'> Cram
# <class 'str'> Lehn
# <class 'str'> Pedersen
# <class 'str'> Solow
# <class 'str'> Brodsky
# <class 'str'> Arias Sánchez
# <class 'str'> Bednorz
# <class 'str'> Müller
# <class 'str'> Tonegawa
# <class 'str'> Herschbach
# <class 'str'> Lee
# <class 'str'> Polanyi
# <class 'str'> Buchanan Jr.
# <class 'str'> Soyinka
# <class 'str'> Wiesel
# <class 'str'> Ruska
# <class 'str'> Binnig
# <class 'str'> Rohrer
# <class 'str'> Cohen
# <class 'str'> Levi-Montalcini
# <class 'str'> Hauptman
# <class 'str'> Karle
# <class 'str'> Modigliani
# <class 'str'> Simon
# <class 'NoneType'> None
# <class 'str'> von Klitzing
# <class 'str'> Brown
# <class 'str'> Goldstein
# <class 'str'> Merrifield
# <class 'str'> Stone
# <class 'str'> Seifert
# <class 'str'> Tutu
# <class 'str'> Rubbia
# <class 'str'> van der Meer
# <class 'str'> Jerne
# <class 'str'> Köhler
# <class 'str'> Milstein
# <class 'str'> Taube
# <class 'str'> Debreu
# <class 'str'> Golding
# <class 'str'> Wałęsa
# <class 'str'> Chandrasekhar
# <class 'str'> Fowler
# <class 'str'> McClintock
# <class 'str'> Klug
# <class 'str'> Stigler
# <class 'str'> García Márquez
# <class 'str'> Myrdal
# <class 'str'> García Robles
# <class 'str'> Wilson
# <class 'str'> Bergström
# <class 'str'> Samuelsson
# <class 'str'> Vane
# <class 'str'> Fukui
# <class 'str'> Hoffmann
# <class 'str'> Tobin
# <class 'str'> Canetti
# <class 'NoneType'> None
# <class 'str'> Bloembergen
# <class 'str'> Schawlow
# <class 'str'> Siegbahn
# <class 'str'> Sperry
# <class 'str'> Hubel
# <class 'str'> Wiesel
# <class 'str'> Berg
# <class 'str'> Gilbert
# <class 'str'> Sanger
# <class 'str'> Klein
# <class 'str'> Miłosz
# <class 'str'> Pérez Esquivel
# <class 'str'> Cronin
# <class 'str'> Fitch
# <class 'str'> Benacerraf
# <class 'str'> Dausset
# <class 'str'> Snell
# <class 'str'> Brown
# <class 'str'> Wittig
# <class 'str'> Schultz
# <class 'str'> Lewis
# <class 'str'> Elytis
# <class 'str'> Bojaxhiu
# <class 'str'> Glashow
# <class 'str'> Salam
# <class 'str'> Weinberg
# <class 'str'> Cormack
# <class 'str'> Hounsfield
# <class 'str'> Mitchell
# <class 'str'> Simon
# <class 'str'> Singer
# <class 'str'> al-Sadat
# <class 'str'> Begin
# <class 'str'> Kapitsa
# <class 'str'> Penzias
# <class 'str'> Wilson
# <class 'str'> Arber
# <class 'str'> Nathans
# <class 'str'> Smith
# <class 'str'> Prigogine
# <class 'str'> Ohlin
# <class 'str'> Meade
# <class 'str'> Aleixandre
# <class 'NoneType'> None
# <class 'str'> Anderson
# <class 'str'> Mott
# <class 'str'> Van Vleck
# <class 'str'> Guillemin
# <class 'str'> Schally
# <class 'str'> Yalow
# <class 'str'> Lipscomb
# <class 'str'> Friedman
# <class 'str'> Bellow
# <class 'str'> Williams
# <class 'str'> Corrigan
# <class 'str'> Richter
# <class 'str'> Ting
# <class 'str'> Blumberg
# <class 'str'> Gajdusek
# <class 'str'> Cornforth
# <class 'str'> Prelog
# <class 'str'> Kantorovich
# <class 'str'> Koopmans
# <class 'str'> Montale
# <class 'str'> Sakharov
# <class 'str'> Bohr
# <class 'str'> Mottelson
# <class 'str'> Rainwater
# <class 'str'> Baltimore
# <class 'str'> Dulbecco
# <class 'str'> Temin
# <class 'str'> Flory
# <class 'str'> Myrdal
# <class 'str'> von Hayek
# <class 'str'> Johnson
# <class 'str'> Martinson
# <class 'str'> MacBride
# <class 'str'> Satō
# <class 'str'> Ryle
# <class 'str'> Hewish
# <class 'str'> Claude
# <class 'str'> de Duve
# <class 'str'> Palade
# <class 'str'> Fischer
# <class 'str'> Wilkinson
# <class 'str'> Leontief
# <class 'str'> White
# <class 'str'> Kissinger
# <class 'NoneType'> None
# <class 'str'> Esaki
# <class 'str'> Giaever
# <class 'str'> Josephson
# <class 'str'> von Frisch
# <class 'str'> Lorenz
# <class 'str'> Tinbergen
# <class 'str'> Anfinsen
# <class 'str'> Moore
# <class 'str'> Stein
# <class 'str'> Hicks
# <class 'str'> Arrow
# <class 'str'> Böll
# <class 'str'> Bardeen
# <class 'str'> Cooper
# <class 'str'> Schrieffer
# <class 'str'> Edelman
# <class 'str'> Porter
# <class 'str'> Herzberg
# <class 'str'> Kuznets
# <class 'str'> Neruda
# <class 'str'> Brandt
# <class 'str'> Gabor
# <class 'str'> Sutherland, Jr.
# <class 'str'> Leloir
# <class 'str'> Samuelson
# <class 'str'> Solzhenitsyn
# <class 'str'> Borlaug
# <class 'str'> Alfvén
# <class 'str'> Néel
# <class 'str'> Katz
# <class 'str'> von Euler
# <class 'str'> Axelrod
# <class 'str'> Barton
# <class 'str'> Hassel
# <class 'str'> Frisch
# <class 'str'> Tinbergen
# <class 'str'> Beckett
# <class 'NoneType'> None
# <class 'str'> Gell-Mann
# <class 'str'> Delbrück
# <class 'str'> Hershey
# <class 'str'> Luria
# <class 'str'> Onsager
# <class 'str'> Kawabata
# <class 'str'> Cassin
# <class 'str'> Alvarez
# <class 'str'> Holley
# <class 'str'> Khorana
# <class 'str'> Nirenberg
# <class 'str'> Eigen
# <class 'str'> Norrish
# <class 'str'> Porter
# <class 'str'> Asturias
# <class 'str'> Bethe
# <class 'str'> Granit
# <class 'str'> Hartline
# <class 'str'> Wald
# <class 'str'> Mulliken
# <class 'str'> Agnon
# <class 'str'> Sachs
# <class 'str'> Kastler
# <class 'str'> Rous
# <class 'str'> Huggins
# <class 'str'> Woodward
# <class 'str'> Sholokhov
# <class 'NoneType'> None
# <class 'str'> Tomonaga
# <class 'str'> Schwinger
# <class 'str'> Feynman
# <class 'str'> Jacob
# <class 'str'> Lwoff
# <class 'str'> Monod
# <class 'str'> Hodgkin
# <class 'str'> Sartre
# <class 'str'> King Jr.
# <class 'str'> Townes
# <class 'str'> Basov
# <class 'str'> Prokhorov
# <class 'str'> Bloch
# <class 'str'> Lynen
# <class 'str'> Ziegler
# <class 'str'> Natta
# <class 'str'> Seferis
# <class 'NoneType'> None
# <class 'NoneType'> None
# <class 'str'> Wigner
# <class 'str'> Goeppert Mayer
# <class 'str'> Jensen
# <class 'str'> Eccles
# <class 'str'> Hodgkin
# <class 'str'> Huxley
# <class 'str'> Perutz
# <class 'str'> Kendrew
# <class 'str'> Steinbeck
# <class 'str'> Pauling
# <class 'str'> Landau
# <class 'str'> Crick
# <class 'str'> Watson
# <class 'str'> Wilkins
# <class 'str'> Calvin
# <class 'str'> Andrić
# <class 'str'> Hammarskjöld
# <class 'str'> Hofstadter
# <class 'str'> Mössbauer
# <class 'str'> von Békésy
# <class 'str'> Libby
# <class 'str'> Perse
# <class 'str'> Lutuli
# <class 'str'> Glaser
# <class 'str'> Burnet
# <class 'str'> Medawar
# <class 'str'> Heyrovsky
# <class 'str'> Quasimodo
# <class 'str'> Noel-Baker
# <class 'str'> Segrè
# <class 'str'> Chamberlain
# <class 'str'> Ochoa
# <class 'str'> Kornberg
# <class 'str'> Sanger
# <class 'str'> Pasternak
# <class 'str'> Pire
# <class 'str'> Cherenkov
# <class 'str'> Tamm
# <class 'str'> Frank
# <class 'str'> Beadle
# <class 'str'> Tatum
# <class 'str'> Lederberg
# <class 'str'> Todd
# <class 'str'> Camus
# <class 'str'> Pearson
# <class 'str'> Yang
# <class 'str'> Lee
# <class 'str'> Bovet
# <class 'str'> Hinshelwood
# <class 'str'> Semenov
# <class 'str'> Jiménez
# <class 'str'> Shockley
# <class 'str'> Bardeen
# <class 'str'> Brattain
# <class 'str'> Cournand
# <class 'str'> Forssmann
# <class 'str'> Richards
# <class 'str'> du Vigneaud
# <class 'str'> Laxness
# <class 'str'> Lamb
# <class 'str'> Kusch
# <class 'str'> Theorell
# <class 'str'> Pauling
# <class 'str'> Hemingway
# <class 'NoneType'> None
# <class 'str'> Born
# <class 'str'> Bothe
# <class 'str'> Enders
# <class 'str'> Weller
# <class 'str'> Robbins
# <class 'str'> Staudinger
# <class 'str'> Churchill
# <class 'str'> Marshall
# <class 'str'> Zernike
# <class 'str'> Krebs
# <class 'str'> Lipmann
# <class 'str'> Martin
# <class 'str'> Synge
# <class 'str'> Mauriac
# <class 'str'> Schweitzer
# <class 'str'> Bloch
# <class 'str'> Purcell
# <class 'str'> Waksman
# <class 'str'> McMillan
# <class 'str'> Seaborg
# <class 'str'> Lagerkvist
# <class 'str'> Jouhaux
# <class 'str'> Cockcroft
# <class 'str'> Walton
# <class 'str'> Theiler
# <class 'str'> Diels
# <class 'str'> Alder
# <class 'str'> Russell
# <class 'str'> Bunche
# <class 'str'> Powell
# <class 'str'> Kendall
# <class 'str'> Reichstein
# <class 'str'> Hench
# <class 'str'> Giauque
# <class 'str'> Faulkner
# <class 'str'> Boyd Orr
# <class 'str'> Yukawa
# <class 'str'> Hess
# <class 'str'> Moniz
# <class 'str'> Tiselius
# <class 'str'> Eliot
# <class 'str'> Blackett
# <class 'str'> Müller
# <class 'str'> Robinson
# <class 'str'> Gide
# <class 'NoneType'> None
# <class 'NoneType'> None
# <class 'str'> Appleton
# <class 'str'> Cori
# <class 'str'> Cori
# <class 'str'> Houssay
# <class 'str'> Sumner
# <class 'str'> Northrop
# <class 'str'> Stanley
# <class 'str'> Hesse
# <class 'str'> Balch
# <class 'str'> Mott
# <class 'str'> Bridgman
# <class 'str'> Muller
# <class 'str'> Virtanen
# <class 'str'> Mistral
# <class 'str'> Hull
# <class 'str'> Pauli
# <class 'str'> Fleming
# <class 'str'> Chain
# <class 'str'> Florey
# <class 'str'> Hahn
# <class 'str'> Jensen
# <class 'NoneType'> None
# <class 'str'> Rabi
# <class 'str'> Erlanger
# <class 'str'> Gasser
# <class 'str'> de Hevesy
# <class 'str'> Stern
# <class 'str'> Dam
# <class 'str'> Doisy
# <class 'str'> Butenandt
# <class 'str'> Ruzicka
# <class 'str'> Sillanpää
# <class 'str'> Lawrence
# <class 'str'> Domagk
# <class 'str'> Kuhn
# <class 'str'> Buck
# <class 'NoneType'> None
# <class 'str'> Fermi
# <class 'str'> Heymans
# <class 'str'> Haworth
# <class 'str'> Karrer
# <class 'str'> Martin du Gard
# <class 'str'> Cecil
# <class 'str'> Davisson
# <class 'str'> Thomson
# <class 'str'> Szent-Györgyi
# <class 'str'> Debye
# <class 'str'> O'Neill
# <class 'str'> Saavedra Lamas
# <class 'str'> Hess
# <class 'str'> Anderson
# <class 'str'> Dale
# <class 'str'> Loewi
# <class 'str'> Joliot
# <class 'str'> Joliot-Curie
# <class 'str'> von Ossietzky
# <class 'str'> Chadwick
# <class 'str'> Spemann
# <class 'str'> Urey
# <class 'str'> Pirandello
# <class 'str'> Henderson
# <class 'str'> Whipple
# <class 'str'> Minot
# <class 'str'> Murphy
# <class 'str'> Bunin
# <class 'str'> Angell
# <class 'str'> Schrödinger
# <class 'str'> Dirac
# <class 'str'> Morgan
# <class 'str'> Langmuir
# <class 'str'> Galsworthy
# <class 'str'> Heisenberg
# <class 'str'> Sherrington
# <class 'str'> Adrian
# <class 'str'> Bosch
# <class 'str'> Bergius
# <class 'str'> Karlfeldt
# <class 'str'> Addams
# <class 'str'> Butler
# <class 'str'> Warburg
# <class 'str'> Fischer
# <class 'str'> Lewis
# <class 'str'> Söderblom
# <class 'str'> Raman
# <class 'str'> Landsteiner
# <class 'str'> Harden
# <class 'str'> von Euler-Chelpin
# <class 'str'> Mann
# <class 'str'> Kellogg
# <class 'str'> de Broglie
# <class 'str'> Eijkman
# <class 'str'> Hopkins
# <class 'str'> Windaus
# <class 'str'> Undset
# <class 'str'> Richardson
# <class 'str'> Nicolle
# <class 'str'> Wieland
# <class 'str'> Bergson
# <class 'str'> Buisson
# <class 'str'> Quidde
# <class 'str'> Compton
# <class 'str'> Wilson
# <class 'str'> Wagner-Jauregg
# <class 'str'> Svedberg
# <class 'str'> Deledda
# <class 'str'> Briand
# <class 'str'> Stresemann
# <class 'str'> Perrin
# <class 'str'> Fibiger
# <class 'str'> Zsigmondy
# <class 'str'> Shaw
# <class 'str'> Chamberlain
# <class 'str'> Dawes
# <class 'str'> Franck
# <class 'str'> Hertz
# <class 'str'> Reymont
# <class 'str'> Siegbahn
# <class 'str'> Einthoven
# <class 'str'> Pregl
# <class 'str'> Yeats
# <class 'str'> Millikan
# <class 'str'> Banting
# <class 'str'> Macleod
# <class 'str'> Aston
# <class 'str'> Benavente
# <class 'str'> Nansen
# <class 'str'> Bohr
# <class 'str'> Hill
# <class 'str'> Meyerhof
# <class 'str'> Soddy
# <class 'str'> France
# <class 'str'> Branting
# <class 'str'> Lange
# <class 'str'> Einstein
# <class 'str'> Nernst
# <class 'str'> Hamsun
# <class 'str'> Bourgeois
# <class 'str'> Guillaume
# <class 'str'> Krogh
# <class 'str'> Spitteler
# <class 'str'> Wilson
# <class 'str'> Stark
# <class 'str'> Bordet
# <class 'str'> Haber
# <class 'str'> Planck
# <class 'str'> Gjellerup
# <class 'str'> Pontoppidan
# <class 'NoneType'> None
# <class 'str'> Barkla
# <class 'str'> von Heidenstam
# <class 'str'> Willstätter
# <class 'str'> Rolland
# <class 'str'> Bragg
# <class 'str'> Bragg
# <class 'str'> Richards
# <class 'str'> von Laue
# <class 'str'> Bárány
# <class 'str'> Werner
# <class 'str'> Tagore
# <class 'str'> La Fontaine
# <class 'str'> Kamerlingh Onnes
# <class 'str'> Richet
# <class 'str'> Grignard
# <class 'str'> Sabatier
# <class 'str'> Hauptmann
# <class 'str'> Root
# <class 'str'> Dalén
# <class 'str'> Carrel
# <class 'str'> Curie
# <class 'str'> Maeterlinck
# <class 'str'> Asser
# <class 'str'> Fried
# <class 'str'> Wien
# <class 'str'> Gullstrand
# <class 'str'> Wallach
# <class 'str'> Heyse
# <class 'NoneType'> None
# <class 'str'> van der Waals
# <class 'str'> Kossel
# <class 'str'> Ostwald
# <class 'str'> Lagerlöf
# <class 'str'> Beernaert
# <class 'str'> d'Estournelles de Constant
# <class 'str'> Marconi
# <class 'str'> Braun
# <class 'str'> Kocher
# <class 'str'> Rutherford
# <class 'str'> Eucken
# <class 'str'> Arnoldson
# <class 'str'> Bajer
# <class 'str'> Lippmann
# <class 'str'> Mechnikov
# <class 'str'> Ehrlich
# <class 'str'> Buchner
# <class 'str'> Kipling
# <class 'str'> Moneta
# <class 'str'> Renault
# <class 'str'> Michelson
# <class 'str'> Laveran
# <class 'str'> Moissan
# <class 'str'> Carducci
# <class 'str'> Roosevelt
# <class 'str'> Thomson
# <class 'str'> Golgi
# <class 'str'> Ramón y Cajal
# <class 'str'> von Baeyer
# <class 'str'> Sienkiewicz
# <class 'str'> von Suttner
# <class 'str'> Lenard
# <class 'str'> Koch
# <class 'str'> Ramsay
# <class 'str'> Mistral
# <class 'str'> Echegaray
# <class 'NoneType'> None
# <class 'str'> Rayleigh
# <class 'str'> Pavlov
# <class 'str'> Arrhenius
# <class 'str'> Bjørnson
# <class 'str'> Cremer
# <class 'str'> Becquerel
# <class 'str'> Curie
# <class 'str'> Curie
# <class 'str'> Finsen
# <class 'str'> Fischer
# <class 'str'> Mommsen
# <class 'str'> Ducommun
# <class 'str'> Gobat
# <class 'str'> Lorentz
# <class 'str'> Zeeman
# <class 'str'> Ross
# <class 'str'> van 't Hoff
# <class 'str'> Prudhomme
# <class 'str'> Dunant
# <class 'str'> Passy
# <class 'str'> Röntgen
# <class 'str'> von Behring

# %% [markdown]
# #### Now, creating a dictionary using this list

# %%
data={'id':ids,'year':year,'category':category,'firstname':firstname,'surname':surname,'motivation':motivation,'share':share}

# %% [markdown]
# #### Importing this data into pandas dataframe

# %%
data=pd.DataFrame(data)
data
# Out:
#         id  year    category       firstname      surname  \
# 0     1039  2024   chemistry           David        Baker
# 1     1040  2024   chemistry           Demis     Hassabis
# 2     1041  2024   chemistry            John       Jumper
# 3     1044  2024   economics           Daron     Acemoglu
# 4     1045  2024   economics           Simon      Johnson
# ...    ...   ...         ...             ...          ...
# 1007   569  1901  literature           Sully    Prudhomme
# 1008   462  1901       peace           Henry       Dunant
# 1009   463  1901       peace        Frédéric        Passy
# 1010     1  1901     physics  Wilhelm Conrad      Röntgen
# 1011   293  1901    medicine            Emil  von Behring
#
#                                              motivation share
# 0                    "for computational protein design"     2
# 1                    "for protein structure prediction"     4
# 2                    "for protein structure prediction"     4
# 3     "for studies of how institutions are formed an...     3
# 4     "for studies of how institutions are formed an...     3
# ...                                                 ...   ...
# 1007  "in special recognition of his poetic composit...     1
# 1008  "for his humanitarian efforts to help wounded ...     2
# 1009  "for his lifelong work for international peace...     2
# 1010  "in recognition of the extraordinary services ...     1
# 1011  "for his work on serum therapy, especially its...     1
#
# [1012 rows x 7 columns]

# %%
len(data['id'])
# Out:
# 1012

# %%
data['year'].max()
# Out:
# '2024'

# %%
data['year'].min()
# Out:
# '1901'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1012 entries, 0 to 1011
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1012 non-null   object
#  1   year        1012 non-null   object
#  2   category    1012 non-null   object
#  3   firstname   1012 non-null   object
#  4   surname     979 non-null    object
#  5   motivation  1012 non-null   object
#  6   share       1012 non-null   object
# dtypes: object(7)
# memory usage: 55.5+ KB

# %%
data[data['surname'].isnull()]
# Out:
#        id  year category                                          firstname  \
# 7    1043  2024    peace                                     Nihon Hidankyo
# 31   1019  2022    peace                                           Memorial
# 32   1020  2022    peace                         Center for Civil Liberties
# 55    994  2020    peace                               World Food Programme
# 94    948  2017    peace  International Campaign to Abolish Nuclear Weapons
# 117   925  2015    peace                          National Dialogue Quartet
# 143   893  2013    peace  Organisation for the Prohibition of Chemical W...
# 154   881  2012    peace                                     European Union
# 213   818  2007    peace          Intergovernmental Panel on Climate Change
# 224   810  2006    peace                                       Grameen Bank
# 235   797  2005    peace                 International Atomic Energy Agency
# 285   748  2001    peace                                     United Nations
# 309   568  1999    peace                            Doctors Without Borders
# 331   564  1997    peace            International Campaign to Ban Landmines
# 356   561  1995    peace   Pugwash Conferences on Science and World Affairs
# 395   553  1991    peace                                   Aung San Suu Kyi
# 425   550  1988    peace                 United Nations Peacekeeping Forces
# 456   547  1985    peace  International Physicians for the Prevention of...
# 489   515  1981    peace  Office of the United Nations High Commissioner...
# 533   537  1977    peace                              Amnesty International
# 578   531  1973    peace                                         Le Duc Tho
# 616   527  1969    peace                  International Labour Organization
# 644   525  1965    peace                     United Nations Children's Fund
# 662   482  1963    peace           International Committee of the Red Cross
# 663   523  1963    peace                      League of Red Cross Societies
# 728   515  1954    peace  Office of the United Nations High Commissioner...
# 774   508  1947    peace                            Friends Service Council
# 775   509  1947    peace                 American Friends Service Committee
# 797   482  1944    peace           International Committee of the Red Cross
# 812   503  1938    peace           Nansen International Office for Refugees
# 923   482  1917    peace           International Committee of the Red Cross
# 952   477  1910    peace               Permanent International Peace Bureau
# 989   467  1904    peace                     Institute of International Law
#
#     surname                                         motivation share
# 7      None  "for its efforts to achieve a world free of nu...     1
# 31     None  "The Peace Prize laureates represent civil soc...     3
# 32     None  "The Peace Prize laureates represent civil soc...     3
# 55     None  "for its efforts to combat hunger, for its con...     1
# 94     None  "for its work to draw attention to the catastr...     1
# 117    None  "for its decisive contribution to the building...     1
# 143    None  "for its extensive efforts to eliminate chemic...     1
# 154    None  "for over six decades contributed to the advan...     1
# 213    None  "for their efforts to build up and disseminate...     2
# 224    None  "for their efforts to create economic and soci...     2
# 235    None  "for their efforts to prevent nuclear energy f...     2
# 285    None  "for their work for a better organized and mor...     2
# 309    None  "in recognition of the organisation's pioneeri...     1
# 331    None  "for their work for the banning and clearing o...     2
# 356    None  "for their efforts to diminish the part played...     2
# 395    None  "for her non-violent struggle for democracy an...     1
# 425    None  "for preventing armed clashes and creating con...     1
# 456    None  "for spreading authoritative information and b...     1
# 489    None  "for promoting the fundamental rights of refug...     1
# 533    None           "for worldwide respect for human rights"     1
# 578    None  "for jointly having negotiated a cease fire in...     2
# 616    None  "for creating international legislation insuri...     1
# 644    None  "for its effort to enhance solidarity between ...     1
# 662    None  "for promoting the principles of the Geneva Co...     2
# 663    None  "for promoting the principles of the Geneva Co...     2
# 728    None  "for its efforts to heal the wounds of war by ...     1
# 774    None  "for their pioneering work in the internationa...     2
# 775    None  "for their pioneering work in the internationa...     2
# 797    None  "for the great work it has performed during th...     1
# 812    None  "for having carried on the work of Fridtjof Na...     1
# 923    None  "for the efforts to take care of wounded soldi...     1
# 952    None  "for acting as a link between the peace societ...     1
# 989    None  "for its striving in public law to develop pea...     1

# %% [markdown]
# #### Creating an column name laureate_type

# %%
data['laureate_type']=np.where(data['surname'].isnull(),'Organization','Individual')

# %%
data
# Out:
#         id  year    category       firstname      surname  \
# 0     1039  2024   chemistry           David        Baker
# 1     1040  2024   chemistry           Demis     Hassabis
# 2     1041  2024   chemistry            John       Jumper
# 3     1044  2024   economics           Daron     Acemoglu
# 4     1045  2024   economics           Simon      Johnson
# ...    ...   ...         ...             ...          ...
# 1007   569  1901  literature           Sully    Prudhomme
# 1008   462  1901       peace           Henry       Dunant
# 1009   463  1901       peace        Frédéric        Passy
# 1010     1  1901     physics  Wilhelm Conrad      Röntgen
# 1011   293  1901    medicine            Emil  von Behring
#
#                                              motivation share laureate_type
# 0                    "for computational protein design"     2    Individual
# 1                    "for protein structure prediction"     4    Individual
# 2                    "for protein structure prediction"     4    Individual
# 3     "for studies of how institutions are formed an...     3    Individual
# 4     "for studies of how institutions are formed an...     3    Individual
# ...                                                 ...   ...           ...
# 1007  "in special recognition of his poetic composit...     1    Individual
# 1008  "for his humanitarian efforts to help wounded ...     2    Individual
# 1009  "for his lifelong work for international peace...     2    Individual
# 1010  "in recognition of the extraordinary services ...     1    Individual
# 1011  "for his work on serum therapy, especially its...     1    Individual
#
# [1012 rows x 8 columns]

# %%
str.rstrip(' Hello ')
# Out:
# ' Hello'

# %%
def clean_motivation(string):
    string=string.replace('"','')
    string=string.lstrip()
    string=string.capitalize()
    return string

# %%
data['motivation']=data['motivation'].apply(clean_motivation)

# %%
data
# Out:
#         id  year    category       firstname      surname  \
# 0     1039  2024   chemistry           David        Baker
# 1     1040  2024   chemistry           Demis     Hassabis
# 2     1041  2024   chemistry            John       Jumper
# 3     1044  2024   economics           Daron     Acemoglu
# 4     1045  2024   economics           Simon      Johnson
# ...    ...   ...         ...             ...          ...
# 1007   569  1901  literature           Sully    Prudhomme
# 1008   462  1901       peace           Henry       Dunant
# 1009   463  1901       peace        Frédéric        Passy
# 1010     1  1901     physics  Wilhelm Conrad      Röntgen
# 1011   293  1901    medicine            Emil  von Behring
#
#                                              motivation share laureate_type
# 0                     For computational protein design      2    Individual
# 1                     For protein structure prediction      4    Individual
# 2                     For protein structure prediction      4    Individual
# 3     For studies of how institutions are formed and...     3    Individual
# 4     For studies of how institutions are formed and...     3    Individual
# ...                                                 ...   ...           ...
# 1007  In special recognition of his poetic compositi...     1    Individual
# 1008  For his humanitarian efforts to help wounded s...     2    Individual
# 1009  For his lifelong work for international peace ...     2    Individual
# 1010  In recognition of the extraordinary services h...     1    Individual
# 1011  For his work on serum therapy, especially its ...     1    Individual
#
# [1012 rows x 8 columns]

# %%
data['id'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[370], line 1
# ----> 1 data['id'].astype(int)
#
# TypeError: list indices must be integers or slices, not str

# %%
# Creating list to store the items in each dictionary 
ids=[]
firstname=[]
surname=[]
year=[]
category=[]
motivation=[]
share=[]

# %%
var=len(response_api_v1['prizes'])
var
# Out:
# 676

# %%
# Checking if the

# %%
for dict_track in range(var):
    for i in response_api_v1['prizes'][dict_track]['laureates']:
        ids.append(i['id'])
        firstname.append(i['firstname'])
        surname.append(i['surname'])
        motivation.append(i['motivation'])
        year.append(response_api_v1['prizes'][dict_track]['year'])
        category.append(response_api_v1['prizes'][dict_track]['category'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 5
#       3 ids.append(i['id'])
#       4 firstname.append(i['firstname'])
# ----> 5 surname.append(i['surname'])
#       6 motivation.append(i['motivation'])
#       7 year.append(response_api_v1['prizes'][dict_track]['year'])
#
# KeyError: 'surname'

# %%
key3='laureates'
list_of_incon_keys=[]
for i in range(var):
    if key3 in response_api_v1['prizes'][i].keys():
        pass
    else:
        list_of_incon_keys.append(i)

# %%
# Keys which doesn't match with rest of the keys
len(list_of_incon_keys)
# Out:
# 49

# %%
# Dictionary for years in which nobel prize was not awarded 
for i in list_of_incon_keys:
    print(response_api_v1['prizes'][i].keys())
# Out:
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])
# dict_keys(['year', 'category', 'overallMotivation'])

# %%
print(np.nan)
# Out:
# nan

# %%
for dict_track in range(var):
    for i in response_api_v1['prizes'][dict_track]:
        if 'laureates' in i.keys():
        pass
        """
        else:
            
            ids.append(np.nan)
            firstname.append(np.nan)
            surname.append(np.nan)
            motivation.append(np.nan)
            year.append(np.nan)
            category.append(np.nan)
            print(i)
            break
        """
    
    #for i in response_api_v1['prizes'][dict_track]['laureates']:
        """
        ids.append(i['id'])
        firstname.append(i['firstname'])
        surname.append(i['surname'])
        motivation.append(i['motivation'])
        year.append(response_api_v1['prizes'][dict_track]['year'])
        category.append(response_api_v1['prizes'][dict_track]['category'])"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[245], line 3
#       1 for dict_track in range(var):
#       2     for i in response_api_v1['prizes'][dict_track]:
# ----> 3         if 'laureates' in i.keys():
#       4             pass
#       5         """
#       6         else:
#       7
#    (...)
#      15             break
#      16         """
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
surname
# Out:
# ['Baker',
#  'Hassabis',
#  'Jumper',
#  'Acemoglu',
#  'Johnson',
#  'Robinson',
#  'Han',
#  'Baker',
#  'Hassabis',
#  'Jumper',
#  'Acemoglu',
#  'Johnson',
#  'Robinson',
#  'Han',
#  nan,
#  nan,
#  'Baker',
#  'Hassabis',
#  'Jumper',
#  'Acemoglu',
#  'Johnson',
#  'Robinson',
#  'Han']

# %%
ids=[]
firstname=[]
surname=[]
year=[]
category=[]
motivation=[]
share=[]

# %%
for dict_track in range(var):
    if 'laureates' in response_api_v1['prizes'][dict_track]:
        for i in response_api_v1['prizes'][dict_track]['laureates']:
            ids.append(i['id'])
            firstname.append(i['firstname'])
            surname.append(i['surname'])
            motivation.append(i['motivation'])
            year.append(response_api_v1['prizes'][dict_track]['year'])
            category.append(response_api_v1['prizes'][dict_track]['category'])
    else:
        print(dict_track)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[257], line 6
#       4 ids.append(i['id'])
#       5 firstname.append(i['firstname'])
# ----> 6 surname.append(i['surname'])
#       7 motivation.append(i['motivation'])
#       8 year.append(response_api_v1['prizes'][dict_track]['year'])
#
# KeyError: 'surname'

# %%
# Checking if surname is consistent all over the dicrionary of not
for dict_track in range(var):
    if 'laureates' in response_api_v1['prizes'][dict_track]:
        if 'surname' in response_api_v1['prizes'][dict_track]['laureates'].keys():
            pass
        else:
            print(dict_track)
            break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[263], line 4
#       2 for dict_track in range(var):
#       3     if 'laureates' in response_api_v1['prizes'][dict_track]:
# ----> 4         if 'surname' in response_api_v1['prizes'][dict_track]['laureates'].keys():
#       5             pass
#       6         else:
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
'laureates' in response_api_v1['prizes'][0].keys()
# Out:
# True

# %%
response_api_v1['prizes'][608]
# Out:
# {'year': '1914',
#  'category': 'peace',
#  'overallMotivation': '"No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section."'}

# %%
response_api_v1['prizes'][343]
# Out:
# {'year': '1967',
#  'category': 'peace',
#  'overallMotivation': '"No Nobel Prize was awarded this year. 1/3 of the prize money was allocated to the main fund and 2/3 was allocated to the special fund of this prize section."'}

# %%
response_api_v1['prizes'][315]
# Out:
# {'year': '1972',
#  'category': 'peace',
#  'overallMotivation': '"No Nobel Prize was awarded this year. The prize money for 1972 was allocated to the Main Fund."'}

# %%
response_api_v1['prizes'][0].keys()
# Out:
# dict_keys(['year', 'category', 'laureates'])

# %%
# Checking the consistency of ids again API Version 2 
# Checking an arbitary id e.g-> 164

# %%
check_id='745'

# %%
for i in range(var):
    if 'laureates' in response_api_v1['prizes'][i]:
        for j in response_api_v1['prizes'][i]['laureates']:
            if j['id']==check_id:
                print(j['id'],j['firstname']+' '+j['surname'])
# Out:
# 745 A. Michael Spence

# %%
# API Version 2 
url="https://api.nobelprize.org/2.1/laureates"

# %%
# Fetching the response from the api version 2 
response_laureates=requests.get(url).json()

# %%
len(response_laureates['laureates'])
# Out:
# 25

# %%
response_laureates['laureates'][-1]
# Out:
# {'id': '403',
#  'knownName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#  'givenName': {'en': 'Albert', 'se': 'Albert'},
#  'familyName': {'en': 'Claude', 'se': 'Claude'},
#  'fullName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#  'fileName': 'claude',
#  'gender': 'male',
#  'birth': {'date': '1898-08-24',
#   'place': {'city': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#    'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#    'cityNow': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#    'countryNow': {'en': 'Belgium',
#     'no': 'Belgia',
#     'se': 'Belgien',
#     'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#     'latitude': '50.641111',
#     'longitude': '4.668056'},
#    'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#    'locationString': {'en': 'Longlier, Belgium',
#     'no': 'Longlier, Belgia',
#     'se': 'Longlier, Belgien'}}},
#  'death': {'date': '1983-05-22',
#   'place': {'city': {'en': 'Brussels', 'no': 'Brussel', 'se': 'Bryssel'},
#    'country': {'en': 'Belgium',
#     'no': 'Belgia',
#     'se': 'Belgien',
#     'sameAs': 'https://www.wikidata.org/wiki/Q31'},
#    'cityNow': {'en': 'Brussels',
#     'no': 'Brussel',
#     'se': 'Bryssel',
#     'sameAs': ['https://www.wikidata.org/wiki/Q239',
#      'https://www.wikipedia.org/wiki/City_of_Brussels'],
#     'latitude': '50.849243',
#     'longitude': '4.354815'},
#    'countryNow': {'en': 'Belgium',
#     'no': 'Belgia',
#     'se': 'Belgien',
#     'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#     'latitude': '50.641111',
#     'longitude': '4.668056'},
#    'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#    'locationString': {'en': 'Brussels, Belgium',
#     'no': 'Brussel, Belgia',
#     'se': 'Bryssel, Belgien'}}},
#  'wikipedia': {'slug': 'Albert_Claude',
#   'english': 'https://en.wikipedia.org/wiki/Albert_Claude'},
#  'wikidata': {'id': 'Q233943', 'url': 'https://www.wikidata.org/wiki/Q233943'},
#  'sameAs': ['https://www.wikidata.org/wiki/Q233943',
#   'https://en.wikipedia.org/wiki/Albert_Claude'],
#  'links': [{'rel': 'laureate',
#    'href': 'https://api.nobelprize.org/2/laureate/403',
#    'action': 'GET',
#    'types': 'application/json'},
#   {'rel': 'external',
#    'href': 'https://www.nobelprize.org/laureate/403',
#    'title': 'Albert Claude - Facts',
#    'action': 'GET',
#    'types': 'text/html',
#    'class': ['laureate facts']}],
#  'nobelPrizes': [{'awardYear': '1974',
#    'category': {'en': 'Physiology or Medicine',
#     'no': 'Fysiologi eller medisin',
#     'se': 'Fysiologi eller medicin'},
#    'categoryFullName': {'en': 'The Nobel Prize in Physiology or Medicine',
#     'no': 'Nobelprisen i fysiologi eller medisin',
#     'se': 'Nobelpriset i fysiologi eller medicin'},
#    'sortOrder': '1',
#    'portion': '1/3',
#    'dateAwarded': '1974-10-10',
#    'prizeStatus': 'received',
#    'motivation': {'en': 'for their discoveries concerning the structural and functional organization of the cell',
#     'se': 'för deras upptäckter rörande cellens strukturella och funktionella organisation'},
#    'prizeAmount': 550000,
#    'prizeAmountAdjusted': 4126741,
#    'affiliations': [{'name': {'en': 'Université Catholique de Louvain',
#       'no': 'Université Catholique de Louvain',
#       'se': 'Université Catholique de Louvain'},
#      'nameNow': {'en': 'Université Catholique de Louvain'},
#      'city': {'en': 'Louvain', 'no': 'Louvain', 'se': 'Louvain'},
#      'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#      'cityNow': {'en': 'Louvain',
#       'no': 'Louvain',
#       'se': 'Louvain',
#       'sameAs': ['https://www.wikidata.org/wiki/Q118958',
#        'https://www.wikipedia.org/wiki/Leuven'],
#       'latitude': '50.883029',
#       'longitude': '4.713949'},
#      'countryNow': {'en': 'Belgium',
#       'no': 'Belgia',
#       'se': 'Belgien',
#       'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#       'latitude': '50.641111',
#       'longitude': '4.668056'},
#      'continent': {'en': 'Europe'},
#      'locationString': {'en': 'Louvain, Belgium',
#       'no': 'Louvain, Belgia',
#       'se': 'Louvain, Belgien'}}],
#    'links': [{'rel': 'nobelPrize',
#      'href': 'https://api.nobelprize.org/2/nobelPrize/med/1974',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/prizes/medicine/1974/claude/facts/',
#      'title': 'Albert Claude - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/prizes/medicine/1974/summary/',
#      'title': 'The Nobel Prize in Physiology or Medicine 1974',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['prize summary']}]}]}

# %%
# Basically, we want the following dictionary from this response.
# title,gender,birthdate,birthcity,birthcountry,sex,organization_name,organization_city,organization_country,death_date,death_city,death_country,dateAwarded

# %%
response_laureates
# Out:
# {'laureates': [{'id': '745',
#    'knownName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#    'givenName': {'en': 'A. Michael', 'se': 'A. Michael'},
#    'familyName': {'en': 'Spence', 'se': 'Spence'},
#    'fullName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#    'fileName': 'spence',
#    'gender': 'male',
#    'birth': {'date': '1943-00-00',
#     'place': {'city': {'en': 'Montclair, NJ',
#       'no': 'Montclair, NJ',
#       'se': 'Montclair, NJ'},
#      'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#      'cityNow': {'en': 'Montclair, NJ',
#       'no': 'Montclair, NJ',
#       'se': 'Montclair, NJ',
#       'sameAs': ['https://www.wikidata.org/wiki/Q678437',
#        'https://www.wikipedia.org/wiki/Montclair,_New_Jersey'],
#       'latitude': '40.825930',
#       'longitude': '-74.209030'},
#      'countryNow': {'en': 'USA',
#       'no': 'USA',
#       'se': 'USA',
#       'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#       'latitude': '39.828175',
#       'longitude': '-98.579500'},
#      'continent': {'en': 'North America',
#       'no': 'Nord-Amerika',
#       'se': 'Nordamerika'},
#      'locationString': {'en': 'Montclair, NJ, USA',
#       'no': 'Montclair, NJ, USA',
#       'se': 'Montclair, NJ, USA'}}},
#    'wikipedia': {'slug': 'Michael_Spence',
#     'english': 'https://en.wikipedia.org/wiki/Michael_Spence'},
#    'wikidata': {'id': 'Q157245',
#     'url': 'https://www.wikidata.org/wiki/Q157245'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q157245',
#     'https://en.wikipedia.org/wiki/Michael_Spence'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/745',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/745',
#      'title': 'A. Michael Spence - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2001',
#      'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#      'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#       'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#       'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#      'sortOrder': '2',
#      'portion': '1/3',
#      'dateAwarded': '2001-10-10',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for their analyses of markets with asymmetric information',
#       'se': 'för deras analys av marknader med assymetrisk informations'},
#      'prizeAmount': 10000000,
#      'prizeAmountAdjusted': 15547541,
#      'affiliations': [{'name': {'en': 'Stanford University',
#         'no': 'Stanford University',
#         'se': 'Stanford University'},
#        'nameNow': {'en': 'Stanford University'},
#        'city': {'en': 'Stanford, CA',
#         'no': 'Stanford, CA',
#         'se': 'Stanford, CA'},
#        'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#        'cityNow': {'en': 'Stanford, CA',
#         'no': 'Stanford, CA',
#         'se': 'Stanford, CA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q173813',
#          'https://www.wikipedia.org/wiki/Stanford,_California'],
#         'latitude': '37.424734',
#         'longitude': '-122.163858'},
#        'countryNow': {'en': 'USA',
#         'no': 'USA',
#         'se': 'USA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#         'latitude': '39.828175',
#         'longitude': '-98.579500'},
#        'continent': {'en': 'North America'},
#        'locationString': {'en': 'Stanford, CA, USA',
#         'no': 'Stanford, CA, USA',
#         'se': 'Stanford, CA, USA'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2001',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/spence/facts/',
#        'title': 'A. Michael Spence - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/summary/',
#        'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2001',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '102',
#    'knownName': {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'},
#    'givenName': {'en': 'Aage N.', 'se': 'Aage N.'},
#    'familyName': {'en': 'Bohr', 'se': 'Bohr'},
#    'fullName': {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bohr'},
#    'fileName': 'bohr',
#    'gender': 'male',
#    'birth': {'date': '1922-06-19',
#     'place': {'city': {'en': 'Copenhagen',
#       'no': 'København',
#       'se': 'Köpenhamn'},
#      'country': {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danmark'},
#      'cityNow': {'en': 'Copenhagen',
#       'no': 'København',
#       'se': 'Köpenhamn',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#        'https://www.wikipedia.org/wiki/Copenhagen'],
#       'latitude': '55.678127',
#       'longitude': '12.572532'},
#      'countryNow': {'en': 'Denmark',
#       'no': 'Danmark',
#       'se': 'Danmark',
#       'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#       'latitude': '56.000000',
#       'longitude': '10.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Copenhagen, Denmark',
#       'no': 'København, Danmark',
#       'se': 'Köpenhamn, Danmark'}}},
#    'death': {'date': '2009-09-08',
#     'place': {'city': {'en': 'Copenhagen',
#       'no': 'København',
#       'se': 'Köpenhamn'},
#      'country': {'en': 'Denmark',
#       'no': 'Danmark',
#       'se': 'Danmark',
#       'sameAs': 'https://www.wikidata.org/wiki/Q35'},
#      'cityNow': {'en': 'Copenhagen',
#       'no': 'København',
#       'se': 'Köpenhamn',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#        'https://www.wikipedia.org/wiki/Copenhagen'],
#       'latitude': '55.678127',
#       'longitude': '12.572532'},
#      'countryNow': {'en': 'Denmark',
#       'no': 'Danmark',
#       'se': 'Danmark',
#       'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#       'latitude': '56.000000',
#       'longitude': '10.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Copenhagen, Denmark',
#       'no': 'København, Danmark',
#       'se': 'Köpenhamn, Danmark'}}},
#    'wikipedia': {'slug': 'Aage_Bohr',
#     'english': 'https://en.wikipedia.org/wiki/Aage_Bohr'},
#    'wikidata': {'id': 'Q103854',
#     'url': 'https://www.wikidata.org/wiki/Q103854'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q103854',
#     'https://en.wikipedia.org/wiki/Aage_Bohr'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/102',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/102',
#      'title': 'Aage N. Bohr - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1975',
#      'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#      'categoryFullName': {'en': 'The Nobel Prize in Physics',
#       'no': 'Nobelprisen i fysikk',
#       'se': 'Nobelpriset i fysik'},
#      'sortOrder': '1',
#      'portion': '1/3',
#      'dateAwarded': '1975-10-17',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for the discovery of the connection between collective motion and particle motion in atomic nuclei and the development of the theory of the structure of the atomic nucleus based on this connection',
#       'se': 'för upptäckten av sambandet mellan kollektiva rörelser och partikelrörelser i atomkärnor, samt den därpå baserade utvecklingen av teorien för atomkärnans struktur'},
#      'prizeAmount': 630000,
#      'prizeAmountAdjusted': 4304697,
#      'affiliations': [{'name': {'en': 'Niels Bohr Institute',
#         'no': 'Niels Bohr Institute',
#         'se': 'Niels Bohr Institute'},
#        'nameNow': {'en': 'Niels Bohr Institute'},
#        'city': {'en': 'Copenhagen', 'no': 'København', 'se': 'Köpenhamn'},
#        'country': {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danmark'},
#        'cityNow': {'en': 'Copenhagen',
#         'no': 'København',
#         'se': 'Köpenhamn',
#         'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#          'https://www.wikipedia.org/wiki/Copenhagen'],
#         'latitude': '55.678127',
#         'longitude': '12.572532'},
#        'countryNow': {'en': 'Denmark',
#         'no': 'Danmark',
#         'se': 'Danmark',
#         'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#         'latitude': '56.000000',
#         'longitude': '10.000000'},
#        'continent': {'en': 'Europe'},
#        'locationString': {'en': 'Copenhagen, Denmark',
#         'no': 'København, Danmark',
#         'se': 'Köpenhamn, Danmark'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1975',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/1975/bohr/facts/',
#        'title': 'Aage N. Bohr - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/1975/summary/',
#        'title': 'The Nobel Prize in Physics 1975',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '779',
#    'knownName': {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciechanover'},
#    'givenName': {'en': 'Aaron', 'se': 'Aaron'},
#    'familyName': {'en': 'Ciechanover', 'se': 'Ciechanover'},
#    'fullName': {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciechanover'},
#    'fileName': 'ciechanover',
#    'gender': 'male',
#    'birth': {'date': '1947-10-01',
#     'place': {'city': {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'},
#      'country': {'en': 'British Protectorate of Palestine',
#       'no': 'British i Palestina',
#       'se': 'British Protectorate of Palestine'},
#      'cityNow': {'en': 'Haifa',
#       'no': 'Haifa',
#       'se': 'Haifa',
#       'sameAs': ['https://www.wikidata.org/wiki/Q41621',
#        'https://www.wikipedia.org/wiki/Haifa'],
#       'latitude': '32.794421',
#       'longitude': '34.990340'},
#      'countryNow': {'en': 'Israel',
#       'no': 'Israel',
#       'se': 'Israel',
#       'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#       'latitude': '31.000000',
#       'longitude': '35.000000'},
#      'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#      'locationString': {'en': 'Haifa, British Protectorate of Palestine (now Israel)',
#       'no': 'Haifa, British i Palestina (nå Israel)',
#       'se': 'Haifa, British Protectorate of Palestine (nu Israel)'}}},
#    'wikipedia': {'slug': 'Aaron_Ciechanover',
#     'english': 'https://en.wikipedia.org/wiki/Aaron_Ciechanover'},
#    'wikidata': {'id': 'Q233205',
#     'url': 'https://www.wikidata.org/wiki/Q233205'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q233205',
#     'https://en.wikipedia.org/wiki/Aaron_Ciechanover'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/779',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/779',
#      'title': 'Aaron Ciechanover - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2004',
#      'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#      'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#       'no': 'Nobelprisen i kjemi',
#       'se': 'Nobelpriset i kemi'},
#      'sortOrder': '1',
#      'portion': '1/3',
#      'dateAwarded': '2004-10-06',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for the discovery of ubiquitin-mediated protein degradation',
#       'se': 'för upptäckten av ubiquitinmedierad proteinnedbrytning'},
#      'prizeAmount': 10000000,
#      'prizeAmountAdjusted': 14874529,
#      'affiliations': [{'name': {'en': 'Technion - Israel Institute of Technology',
#         'no': 'Technion - Israel Institute of Technology',
#         'se': 'Technion - Israel Institute of Technology'},
#        'nameNow': {'en': 'Technion - Israel Institute of Technology'},
#        'city': {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'},
#        'country': {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'},
#        'cityNow': {'en': 'Haifa',
#         'no': 'Haifa',
#         'se': 'Haifa',
#         'sameAs': ['https://www.wikidata.org/wiki/Q41621',
#          'https://www.wikipedia.org/wiki/Haifa'],
#         'latitude': '32.794421',
#         'longitude': '34.990340'},
#        'countryNow': {'en': 'Israel',
#         'no': 'Israel',
#         'se': 'Israel',
#         'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#         'latitude': '31.000000',
#         'longitude': '35.000000'},
#        'continent': {'en': 'Asia'},
#        'locationString': {'en': 'Haifa, Israel',
#         'no': 'Haifa, Israel',
#         'se': 'Haifa, Israel'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/che/2004',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/2004/ciechanover/facts/',
#        'title': 'Aaron Ciechanover - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/2004/summary/',
#        'title': 'The Nobel Prize in Chemistry 2004',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '259',
#    'knownName': {'en': 'Aaron Klug', 'se': 'Aaron Klug'},
#    'givenName': {'en': 'Aaron', 'se': 'Aaron'},
#    'familyName': {'en': 'Klug', 'se': 'Klug'},
#    'fullName': {'en': 'Aaron Klug', 'se': 'Aaron Klug'},
#    'fileName': 'klug',
#    'gender': 'male',
#    'birth': {'date': '1926-08-11',
#     'place': {'city': {'en': 'Zelvas', 'no': 'Zelvas', 'se': 'Zelvas'},
#      'country': {'en': 'Lithuania', 'no': 'Litauen', 'se': 'Litauen'},
#      'cityNow': {'en': 'Zelvas',
#       'no': 'Zelvas',
#       'se': 'Zelvas',
#       'sameAs': ['https://www.wikidata.org/wiki/Q691679',
#        'https://www.wikipedia.org/wiki/%C5%BDelva'],
#       'latitude': '53.148256',
#       'longitude': '24.816515'},
#      'countryNow': {'en': 'Lithuania',
#       'no': 'Litauen',
#       'se': 'Litauen',
#       'sameAs': ['https://www.wikidata.org/wiki/Q37'],
#       'latitude': '55.200000',
#       'longitude': '24.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Zelvas, Lithuania',
#       'no': 'Zelvas, Litauen',
#       'se': 'Zelvas, Litauen'}}},
#    'death': {'date': '2018-11-20',
#     'place': {'locationString': {'en': '', 'no': '', 'se': ''}}},
#    'wikipedia': {'slug': 'Aaron_Klug',
#     'english': 'https://en.wikipedia.org/wiki/Aaron_Klug'},
#    'wikidata': {'id': 'Q190626',
#     'url': 'https://www.wikidata.org/wiki/Q190626'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q190626',
#     'https://en.wikipedia.org/wiki/Aaron_Klug'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/259',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/259',
#      'title': 'Aaron Klug - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1982',
#      'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#      'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#       'no': 'Nobelprisen i kjemi',
#       'se': 'Nobelpriset i kemi'},
#      'sortOrder': '1',
#      'portion': '1',
#      'dateAwarded': '1982-10-18',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for his development of crystallographic electron microscopy and his structural elucidation of biologically important nucleic acid-protein complexes',
#       'se': 'för hans utveckling av kristallografisk elektronmikroskopi och hans klarläggande av strukturen hos biologiskt viktiga nukleinsyra-proteinkomplex'},
#      'prizeAmount': 1150000,
#      'prizeAmountAdjusted': 3923237,
#      'affiliations': [{'name': {'en': 'MRC Laboratory of Molecular Biology',
#         'no': 'MRC Laboratory of Molecular Biology',
#         'se': 'MRC Laboratory of Molecular Biology'},
#        'nameNow': {'en': 'MRC Laboratory of Molecular Biology'},
#        'city': {'en': 'Cambridge', 'no': 'Cambridge', 'se': 'Cambridge'},
#        'country': {'en': 'United Kingdom',
#         'no': 'Storbritannia',
#         'se': 'Storbritannien'},
#        'cityNow': {'en': 'Cambridge',
#         'no': 'Cambridge',
#         'se': 'Cambridge',
#         'sameAs': ['https://www.wikidata.org/wiki/Q350',
#          'https://www.wikipedia.org/wiki/Cambridge'],
#         'latitude': '52.194605',
#         'longitude': '0.135092'},
#        'countryNow': {'en': 'United Kingdom',
#         'no': 'Storbritannia',
#         'se': 'Storbritannien',
#         'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#         'latitude': '54.600000',
#         'longitude': '-2.000000'},
#        'continent': {'en': 'Europe'},
#        'locationString': {'en': 'Cambridge, United Kingdom',
#         'no': 'Cambridge, Storbritannia',
#         'se': 'Cambridge, Storbritannien'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/che/1982',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/1982/klug/facts/',
#        'title': 'Aaron Klug - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/1982/summary/',
#        'title': 'The Nobel Prize in Chemistry 1982',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '1004',
#    'knownName': {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak Gurnah'},
#    'givenName': {'en': 'Abdulrazak', 'se': 'Abdulrazak'},
#    'familyName': {'en': 'Gurnah', 'se': 'Gurnah'},
#    'fullName': {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak Gurnah'},
#    'fileName': 'gurnah',
#    'gender': 'male',
#    'birth': {'date': '1948-00-00'},
#    'wikipedia': {'slug': 'Abdulrazak_Gurnah',
#     'english': 'https://en.wikipedia.org/wiki/Abdulrazak_Gurnah'},
#    'wikidata': {'id': 'Q317877',
#     'url': 'https://www.wikidata.org/wiki/Q317877'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q317877',
#     'https://en.wikipedia.org/wiki/Abdulrazak_Gurnah'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/1004',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/1004',
#      'title': 'Abdulrazak Gurnah - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2021',
#      'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'},
#      'categoryFullName': {'en': 'The Nobel Prize in Literature',
#       'no': 'Nobelprisen i litteratur',
#       'se': 'Nobelpriset i litteratur'},
#      'sortOrder': '1',
#      'portion': '1',
#      'dateAwarded': '2021-10-07',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for his uncompromising and compassionate penetration of the effects of colonialism and the fate of the refugee in the gulf between cultures and continents'},
#      'prizeAmount': 10000000,
#      'prizeAmountAdjusted': 12096939,
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/lit/2021',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/literature/2021/gurnah/facts/',
#        'title': 'Abdulrazak Gurnah - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/literature/2021/summary/',
#        'title': 'The Nobel Prize in Literature 2021',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '114',
#    'knownName': {'en': 'Abdus Salam', 'se': 'Abdus Salam'},
#    'givenName': {'en': 'Abdus', 'se': 'Abdus'},
#    'familyName': {'en': 'Salam', 'se': 'Salam'},
#    'fullName': {'en': 'Abdus Salam', 'se': 'Abdus Salam'},
#    'fileName': 'salam',
#    'gender': 'male',
#    'birth': {'date': '1926-01-29',
#     'place': {'city': {'en': 'Jhang Maghiāna',
#       'no': 'Jhang Maghiāna',
#       'se': 'Jhang Maghiāna'},
#      'country': {'en': 'India', 'no': 'India', 'se': 'Indien'},
#      'cityNow': {'en': 'Jhang Maghiāna',
#       'no': 'Jhang Maghiāna',
#       'se': 'Jhang Maghiāna',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1026616',
#        'https://www.wikipedia.org/wiki/Jhang'],
#       'latitude': '31.268056',
#       'longitude': '72.318056'},
#      'countryNow': {'en': 'Pakistan',
#       'no': 'Pakistan',
#       'se': 'Pakistan',
#       'sameAs': ['https://www.wikidata.org/wiki/Q843'],
#       'latitude': '30.000000',
#       'longitude': '71.000000'},
#      'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#      'locationString': {'en': 'Jhang Maghiāna, India (now Pakistan)',
#       'no': 'Jhang Maghiāna, India (nå Pakistan)',
#       'se': 'Jhang Maghiāna, Indien (nu Pakistan)'}}},
#    'death': {'date': '1996-11-21',
#     'place': {'city': {'en': 'Oxford', 'no': 'Oxford', 'se': 'Oxford'},
#      'country': {'en': 'United Kingdom',
#       'no': 'Storbritannia',
#       'se': 'Storbritannien',
#       'sameAs': 'https://www.wikidata.org/wiki/Q145'},
#      'cityNow': {'en': 'Oxford',
#       'no': 'Oxford',
#       'se': 'Oxford',
#       'sameAs': ['https://www.wikidata.org/wiki/Q34217',
#        'https://www.wikipedia.org/wiki/Oxford'],
#       'latitude': '51.753363',
#       'longitude': '-1.260979'},
#      'countryNow': {'en': 'United Kingdom',
#       'no': 'Storbritannia',
#       'se': 'Storbritannien',
#       'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#       'latitude': '54.600000',
#       'longitude': '-2.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Oxford, United Kingdom',
#       'no': 'Oxford, Storbritannia',
#       'se': 'Oxford, Storbritannien'}}},
#    'wikipedia': {'slug': 'Abdus_Salam',
#     'english': 'https://en.wikipedia.org/wiki/Abdus_Salam'},
#    'wikidata': {'id': 'Q28189', 'url': 'https://www.wikidata.org/wiki/Q28189'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q28189',
#     'https://en.wikipedia.org/wiki/Abdus_Salam'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/114',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/114',
#      'title': 'Abdus Salam - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1979',
#      'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#      'categoryFullName': {'en': 'The Nobel Prize in Physics',
#       'no': 'Nobelprisen i fysikk',
#       'se': 'Nobelpriset i fysik'},
#      'sortOrder': '2',
#      'portion': '1/3',
#      'dateAwarded': '1979-10-15',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for their contributions to the theory of the unified weak and electromagnetic interaction between elementary particles, including, inter alia, the prediction of the weak neutral current',
#       'se': 'för deras insatser inom teorin för förenad svag och elektromagnetisk växelverkan mellan elementar partiklar, innefattande bl.a. förutsägelsen av den svaga neutrala strömmen'},
#      'prizeAmount': 800000,
#      'prizeAmountAdjusted': 3778486,
#      'affiliations': [{'name': {'en': 'International Centre for Theoretical Physics',
#         'no': 'International Centre for Theoretical Physics',
#         'se': 'International Centre for Theoretical Physics'},
#        'nameNow': {'en': 'International Centre for Theoretical Physics'},
#        'city': {'en': 'Trieste', 'no': 'Trieste', 'se': 'Trieste'},
#        'country': {'en': 'Italy', 'no': 'Italia', 'se': 'Italien'},
#        'cityNow': {'en': 'Trieste',
#         'no': 'Trieste',
#         'se': 'Trieste',
#         'sameAs': ['https://www.wikidata.org/wiki/Q546',
#          'https://www.wikipedia.org/wiki/Trieste'],
#         'latitude': '45.649433',
#         'longitude': '13.776623'},
#        'countryNow': {'en': 'Italy',
#         'no': 'Italia',
#         'se': 'Italien',
#         'sameAs': ['https://www.wikidata.org/wiki/Q38'],
#         'latitude': '42.500000',
#         'longitude': '12.500000'},
#        'continent': {'en': 'Europe'},
#        'locationString': {'en': 'Trieste, Italy',
#         'no': 'Trieste, Italia',
#         'se': 'Trieste, Italien'}},
#       {'name': {'en': 'Imperial College',
#         'no': 'Imperial College',
#         'se': 'Imperial College'},
#        'nameNow': {'en': 'Imperial College'},
#        'city': {'en': 'London', 'no': 'London', 'se': 'London'},
#        'country': {'en': 'United Kingdom',
#         'no': 'Storbritannia',
#         'se': 'Storbritannien'},
#        'cityNow': {'en': 'London',
#         'no': 'London',
#         'se': 'London',
#         'sameAs': ['https://www.wikidata.org/wiki/Q84',
#          'https://www.wikipedia.org/wiki/London'],
#         'latitude': '51.510235',
#         'longitude': '-0.120852'},
#        'countryNow': {'en': 'United Kingdom',
#         'no': 'Storbritannia',
#         'se': 'Storbritannien',
#         'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#         'latitude': '54.600000',
#         'longitude': '-2.000000'},
#        'continent': {'en': 'Europe'},
#        'locationString': {'en': 'London, United Kingdom',
#         'no': 'London, Storbritannia',
#         'se': 'London, Storbritannien'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1979',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/1979/salam/facts/',
#        'title': 'Abdus Salam - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/1979/summary/',
#        'title': 'The Nobel Prize in Physics 1979',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '982',
#    'knownName': {'en': 'Abhijit Banerjee', 'se': 'Abhijit Banerjee'},
#    'givenName': {'en': 'Abhijit', 'se': 'Abhijit'},
#    'familyName': {'en': 'Banerjee', 'se': 'Banerjee'},
#    'fullName': {'en': 'Abhijit Banerjee', 'se': 'Abhijit Banerjee'},
#    'fileName': 'banerjee',
#    'gender': 'male',
#    'birth': {'date': '1961-02-21',
#     'place': {'city': {'en': 'Mumbai', 'no': 'Mumbai', 'se': 'Mumbai'},
#      'country': {'en': 'India', 'no': 'India', 'se': 'Indien'},
#      'cityNow': {'en': 'Mumbai',
#       'no': 'Mumbai',
#       'se': 'Mumbai',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1156',
#        'https://www.wikipedia.org/wiki/Mumbai'],
#       'latitude': '19.075833',
#       'longitude': '72.877500'},
#      'countryNow': {'en': 'India',
#       'no': 'India',
#       'se': 'Indien',
#       'sameAs': ['https://www.wikidata.org/wiki/Q668'],
#       'latitude': '22.800000',
#       'longitude': '83.000000'},
#      'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#      'locationString': {'en': 'Mumbai, India',
#       'no': 'Mumbai, India',
#       'se': 'Mumbai, Indien'}}},
#    'wikipedia': {'slug': 'Abhijit_Banerjee',
#     'english': 'https://en.wikipedia.org/wiki/Abhijit_Banerjee'},
#    'wikidata': {'id': 'Q320578',
#     'url': 'https://www.wikidata.org/wiki/Q320578'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q320578',
#     'https://en.wikipedia.org/wiki/Abhijit_Banerjee'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/982',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/982',
#      'title': 'Abhijit Banerjee - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2019',
#      'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#      'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#       'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#       'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#      'sortOrder': '1',
#      'portion': '1/3',
#      'dateAwarded': '2019-10-14',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for their experimental approach to alleviating global poverty',
#       'se': 'för deras experimentella ansats för att mildra global fattigdom'},
#      'prizeAmount': 9000000,
#      'prizeAmountAdjusted': 11178104,
#      'affiliations': [{'name': {'en': 'Massachusetts Institute of Technology (MIT)',
#         'no': 'Massachusetts Institute of Technology (MIT)',
#         'se': 'Massachusetts Institute of Technology (MIT)'},
#        'nameNow': {'en': 'Massachusetts Institute of Technology (MIT)'},
#        'city': {'en': 'Cambridge, MA',
#         'no': 'Cambridge, MA',
#         'se': 'Cambridge, MA'},
#        'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#        'cityNow': {'en': 'Cambridge, MA',
#         'no': 'Cambridge, MA',
#         'se': 'Cambridge, MA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q49111',
#          'https://www.wikipedia.org/wiki/Cambridge,_Massachusetts'],
#         'latitude': '42.374024',
#         'longitude': '-71.107306'},
#        'countryNow': {'en': 'USA',
#         'no': 'USA',
#         'se': 'USA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#         'latitude': '39.828175',
#         'longitude': '-98.579500'},
#        'continent': {'en': 'North America'},
#        'locationString': {'en': 'Cambridge, MA, USA',
#         'no': 'Cambridge, MA, USA',
#         'se': 'Cambridge, MA, USA'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2019',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/economic-sciences/2019/banerjee/facts/',
#        'title': 'Abhijit Banerjee - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/economic-sciences/2019/summary/',
#        'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2019',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '981',
#    'knownName': {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'},
#    'givenName': {'en': 'Abiy', 'se': 'Abiy'},
#    'familyName': {'en': 'Ahmed Ali', 'se': 'Ahmed Ali'},
#    'fullName': {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'},
#    'fileName': 'abiy',
#    'gender': 'male',
#    'birth': {'date': '1976-08-15',
#     'place': {'city': {'en': 'Beshasha', 'no': 'Beshasha', 'se': 'Beshasha'},
#      'country': {'en': 'Ethiopia', 'no': 'Etiopia', 'se': 'Etiopien'},
#      'cityNow': {'en': 'Beshasha',
#       'no': 'Beshasha',
#       'se': 'Beshasha',
#       'sameAs': ['https://www.wikidata.org/wiki/Q2899862',
#        'https://www.wikipedia.org/wiki/Beshasha'],
#       'latitude': '7.795864',
#       'longitude': '36.477062'},
#      'countryNow': {'en': 'Ethiopia',
#       'no': 'Etiopia',
#       'se': 'Etiopien',
#       'sameAs': ['https://www.wikidata.org/wiki/Q115'],
#       'latitude': '9.000000',
#       'longitude': '40.000000'},
#      'continent': {'en': 'Africa', 'no': 'Afrika', 'se': 'Afrika'},
#      'locationString': {'en': 'Beshasha, Ethiopia',
#       'no': 'Beshasha, Etiopia',
#       'se': 'Beshasha, Etiopien'}}},
#    'wikipedia': {'slug': 'Abiy_Ahmed',
#     'english': 'https://en.wikipedia.org/wiki/Abiy_Ahmed'},
#    'wikidata': {'id': 'Q50365049',
#     'url': 'https://www.wikidata.org/wiki/Q50365049'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q50365049',
#     'https://en.wikipedia.org/wiki/Abiy_Ahmed'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/981',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/981',
#      'title': 'Abiy Ahmed Ali - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2019',
#      'category': {'en': 'Peace', 'no': 'Fred', 'se': 'Fred'},
#      'categoryFullName': {'en': 'The Nobel Peace Prize',
#       'no': 'Nobels fredspris',
#       'se': 'Nobels fredspris'},
#      'sortOrder': '1',
#      'portion': '1',
#      'dateAwarded': '2019-10-11',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for his efforts to achieve peace and international cooperation, and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea',
#       'no': 'for hans innsats for fred og mellomstatlig samarbeid, og da særlig for hans avgjørande initiativ for å løsa grensekonflikten med nabolandet Eritrea'},
#      'prizeAmount': 9000000,
#      'prizeAmountAdjusted': 11178104,
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/pea/2019',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/peace/2019/abiy/facts/',
#        'title': 'Abiy Ahmed Ali - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/peace/2019/summary/',
#        'title': 'The Nobel Peace Prize 2019',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '843',
#    'knownName': {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'},
#    'givenName': {'en': 'Ada E.', 'se': 'Ada E.'},
#    'familyName': {'en': 'Yonath', 'se': 'Yonath'},
#    'fullName': {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'},
#    'fileName': 'yonath',
#    'gender': 'female',
#    'birth': {'date': '1939-06-22',
#     'place': {'city': {'en': 'Jerusalem',
#       'no': 'Jerusalem',
#       'se': 'Jerusalem'},
#      'country': {'en': 'British Mandate of Palestine',
#       'no': 'Palestinamandatet',
#       'se': 'Brittiska Palestinamandatet'},
#      'cityNow': {'en': 'Jerusalem',
#       'no': 'Jerusalem',
#       'se': 'Jerusalem',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1218',
#        'https://www.wikipedia.org/wiki/Jerusalem'],
#       'latitude': '31.767983',
#       'longitude': '35.213809'},
#      'countryNow': {'en': 'Israel',
#       'no': 'Israel',
#       'se': 'Israel',
#       'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#       'latitude': '31.000000',
#       'longitude': '35.000000'},
#      'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#      'locationString': {'en': 'Jerusalem, British Mandate of Palestine (now Israel)',
#       'no': 'Jerusalem, Palestinamandatet (nå Israel)',
#       'se': 'Jerusalem, Brittiska Palestinamandatet (nu Israel)'}}},
#    'wikipedia': {'slug': 'Ada_Yonath',
#     'english': 'https://en.wikipedia.org/wiki/Ada_Yonath'},
#    'wikidata': {'id': 'Q7426', 'url': 'https://www.wikidata.org/wiki/Q7426'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q7426',
#     'https://en.wikipedia.org/wiki/Ada_Yonath'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/843',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/843',
#      'title': 'Ada E. Yonath - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2009',
#      'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#      'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#       'no': 'Nobelprisen i kjemi',
#       'se': 'Nobelpriset i kemi'},
#      'sortOrder': '3',
#      'portion': '1/3',
#      'dateAwarded': '2009-10-07',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for studies of the structure and function of the ribosome',
#       'se': 'för studier av ribosomens struktur och funktion'},
#      'prizeAmount': 10000000,
#      'prizeAmountAdjusted': 13857393,
#      'affiliations': [{'name': {'en': 'Weizmann Institute of Science',
#         'no': 'Weizmann Institute of Science',
#         'se': 'Weizmann Institute of Science'},
#        'nameNow': {'en': 'Weizmann Institute of Science'},
#        'city': {'en': 'Rehovot', 'no': 'Rehovot', 'se': 'Rehovot'},
#        'country': {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'},
#        'cityNow': {'en': 'Rehovot',
#         'no': 'Rehovot',
#         'se': 'Rehovot',
#         'sameAs': ['https://www.wikidata.org/wiki/Q207350',
#          'https://www.wikipedia.org/wiki/Rehovot'],
#         'latitude': '31.892773',
#         'longitude': '34.811272'},
#        'countryNow': {'en': 'Israel',
#         'no': 'Israel',
#         'se': 'Israel',
#         'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#         'latitude': '31.000000',
#         'longitude': '35.000000'},
#        'continent': {'en': 'Asia'},
#        'locationString': {'en': 'Rehovot, Israel',
#         'no': 'Rehovot, Israel',
#         'se': 'Rehovot, Israel'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/che/2009',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/2009/yonath/facts/',
#        'title': 'Ada E. Yonath - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/2009/summary/',
#        'title': 'The Nobel Prize in Chemistry 2009',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '866',
#    'knownName': {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'},
#    'givenName': {'en': 'Adam G.', 'se': 'Adam G.'},
#    'familyName': {'en': 'Riess', 'se': 'Riess'},
#    'fullName': {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'},
#    'fileName': 'riess',
#    'gender': 'male',
#    'birth': {'date': '1969-12-16',
#     'place': {'city': {'en': 'Washington, D.C.',
#       'no': 'Washington, D.C.',
#       'se': 'Washington, D.C.'},
#      'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#      'cityNow': {'en': 'Washington, D.C.',
#       'no': 'Washington, D.C.',
#       'se': 'Washington, D.C.',
#       'sameAs': ['https://www.wikidata.org/wiki/Q61',
#        'https://www.wikipedia.org/wiki/Washington,_D.C.'],
#       'latitude': '38.899065',
#       'longitude': '-77.036523'},
#      'countryNow': {'en': 'USA',
#       'no': 'USA',
#       'se': 'USA',
#       'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#       'latitude': '39.828175',
#       'longitude': '-98.579500'},
#      'continent': {'en': 'North America',
#       'no': 'Nord-Amerika',
#       'se': 'Nordamerika'},
#      'locationString': {'en': 'Washington, D.C., USA',
#       'no': 'Washington, D.C., USA',
#       'se': 'Washington, D.C., USA'}}},
#    'wikipedia': {'slug': 'Adam_Riess',
#     'english': 'https://en.wikipedia.org/wiki/Adam_Riess'},
#    'wikidata': {'id': 'Q106454',
#     'url': 'https://www.wikidata.org/wiki/Q106454'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q106454',
#     'https://en.wikipedia.org/wiki/Adam_Riess'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/866',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/866',
#      'title': 'Adam G. Riess - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '2011',
#      'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#      'categoryFullName': {'en': 'The Nobel Prize in Physics',
#       'no': 'Nobelprisen i fysikk',
#       'se': 'Nobelpriset i fysik'},
#      'sortOrder': '3',
#      'portion': '1/4',
#      'dateAwarded': '2011-10-04',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for the discovery of the accelerating expansion of the Universe through observations of distant supernovae',
#       'se': 'för upptäckten av universums accelererande expansion genom observationer av avlägsna supernovor'},
#      'prizeAmount': 10000000,
#      'prizeAmountAdjusted': 13335208,
#      'affiliations': [{'name': {'en': 'Johns Hopkins University',
#         'no': 'Johns Hopkins University',
#         'se': 'Johns Hopkins University'},
#        'nameNow': {'en': 'Johns Hopkins University'},
#        'city': {'en': 'Baltimore, MD',
#         'no': 'Baltimore, MD',
#         'se': 'Baltimore, MD'},
#        'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#        'cityNow': {'en': 'Baltimore, MD',
#         'no': 'Baltimore, MD',
#         'se': 'Baltimore, MD',
#         'sameAs': ['https://www.wikidata.org/wiki/Q5092',
#          'https://www.wikipedia.org/wiki/Baltimore'],
#         'latitude': '39.291586',
#         'longitude': '-76.625305'},
#        'countryNow': {'en': 'USA',
#         'no': 'USA',
#         'se': 'USA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#         'latitude': '39.828175',
#         'longitude': '-98.579500'},
#        'continent': {'en': 'North America'},
#        'locationString': {'en': 'Baltimore, MD, USA',
#         'no': 'Baltimore, MD, USA',
#         'se': 'Baltimore, MD, USA'}},
#       {'name': {'en': 'Space Telescope Science Institute',
#         'no': 'Space Telescope Science Institute',
#         'se': 'Space Telescope Science Institute'},
#        'nameNow': {'en': 'Space Telescope Science Institute'},
#        'city': {'en': 'Baltimore, MD',
#         'no': 'Baltimore, MD',
#         'se': 'Baltimore, MD'},
#        'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#        'cityNow': {'en': 'Baltimore, MD',
#         'no': 'Baltimore, MD',
#         'se': 'Baltimore, MD',
#         'sameAs': ['https://www.wikidata.org/wiki/Q5092',
#          'https://www.wikipedia.org/wiki/Baltimore'],
#         'latitude': '39.291586',
#         'longitude': '-76.625305'},
#        'countryNow': {'en': 'USA',
#         'no': 'USA',
#         'se': 'USA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#         'latitude': '39.828175',
#         'longitude': '-98.579500'},
#        'continent': {'en': 'North America'},
#        'locationString': {'en': 'Baltimore, MD, USA',
#         'no': 'Baltimore, MD, USA',
#         'se': 'Baltimore, MD, USA'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/phy/2011',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/2011/riess/facts/',
#        'title': 'Adam G. Riess - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/2011/summary/',
#        'title': 'The Nobel Prize in Physics 2011',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '199',
#    'knownName': {'en': 'Adolf Butenandt', 'se': 'Adolf Butenandt'},
#    'givenName': {'en': 'Adolf', 'se': 'Adolf'},
#    'familyName': {'en': 'Butenandt', 'se': 'Butenandt'},
#    'fullName': {'en': 'Adolf Friedrich Johann Butenandt',
#     'se': 'Adolf Friedrich Johann Butenandt'},
#    'fileName': 'butenandt',
#    'gender': 'male',
#    'birth': {'date': '1903-03-24',
#     'place': {'city': {'en': 'Bremerhaven-Lehe',
#       'no': 'Bremerhaven-Lehe',
#       'se': 'Bremerhaven-Lehe'},
#      'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#      'cityNow': {'en': 'Bremerhaven-Lehe',
#       'no': 'Bremerhaven-Lehe',
#       'se': 'Bremerhaven-Lehe',
#       'sameAs': ['https://www.wikidata.org/wiki/Q2706',
#        'https://www.wikipedia.org/wiki/Bremerhaven'],
#       'latitude': '53.550000',
#       'longitude': '8.583333'},
#      'countryNow': {'en': 'Germany',
#       'no': 'Tyskland',
#       'se': 'Tyskland',
#       'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#       'latitude': '51.000000',
#       'longitude': '10.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Bremerhaven-Lehe, Germany',
#       'no': 'Bremerhaven-Lehe, Tyskland',
#       'se': 'Bremerhaven-Lehe, Tyskland'}}},
#    'death': {'date': '1995-01-18',
#     'place': {'city': {'en': 'Munich', 'no': 'München', 'se': 'München'},
#      'country': {'en': 'Germany',
#       'no': 'Tyskland',
#       'se': 'Tyskland',
#       'sameAs': 'https://www.wikidata.org/wiki/Q183'},
#      'cityNow': {'en': 'Munich',
#       'no': 'München',
#       'se': 'München',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1726',
#        'https://www.wikipedia.org/wiki/Munich'],
#       'latitude': '48.134703',
#       'longitude': '11.581995'},
#      'countryNow': {'en': 'Germany',
#       'no': 'Tyskland',
#       'se': 'Tyskland',
#       'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#       'latitude': '51.000000',
#       'longitude': '10.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Munich, Germany',
#       'no': 'München, Tyskland',
#       'se': 'München, Tyskland'}}},
#    'wikipedia': {'slug': 'Adolf_Butenandt',
#     'english': 'https://en.wikipedia.org/wiki/Adolf_Butenandt'},
#    'wikidata': {'id': 'Q5327', 'url': 'https://www.wikidata.org/wiki/Q5327'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q5327',
#     'https://en.wikipedia.org/wiki/Adolf_Butenandt'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/199',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/199',
#      'title': 'Adolf Butenandt - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1939',
#      'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#      'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#       'no': 'Nobelprisen i kjemi',
#       'se': 'Nobelpriset i kemi'},
#      'sortOrder': '1',
#      'portion': '1/2',
#      'dateAwarded': '1939-11-09',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for his work on sex hormones',
#       'se': 'för hans arbeten över sexualhormoner'},
#      'prizeAmount': 148822,
#      'prizeAmountAdjusted': 5346318,
#      'affiliations': [{'name': {'en': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#         'no': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#         'se': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie'},
#        'nameNow': {'en': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie'},
#        'city': {'en': 'Berlin-Dahlem',
#         'no': 'Berlin-Dahlem',
#         'se': 'Berlin-Dahlem'},
#        'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#        'cityNow': {'en': 'Berlin-Dahlem',
#         'no': 'Berlin-Dahlem',
#         'se': 'Berlin-Dahlem',
#         'sameAs': ['https://www.wikidata.org/wiki/Q700541',
#          'https://www.wikipedia.org/wiki/Dahlem_(Berlin)'],
#         'latitude': '52.453739',
#         'longitude': '13.293130'},
#        'countryNow': {'en': 'Germany',
#         'no': 'Tyskland',
#         'se': 'Tyskland',
#         'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#         'latitude': '51.000000',
#         'longitude': '10.000000'},
#        'continent': {'en': 'Europe'},
# ...
#         'se': 'Philadelphia, PA, USA'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/che/2000',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/2000/macdiarmid/facts/',
#        'title': 'Alan MacDiarmid - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/chemistry/2000/summary/',
#        'title': 'The Nobel Prize in Chemistry 2000',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '11',
#    'knownName': {'en': 'Albert A. Michelson', 'se': 'Albert A. Michelson'},
#    'givenName': {'en': 'Albert A.', 'se': 'Albert A.'},
#    'familyName': {'en': 'Michelson', 'se': 'Michelson'},
#    'fullName': {'en': 'Albert Abraham Michelson',
#     'se': 'Albert Abraham Michelson'},
#    'fileName': 'michelson',
#    'gender': 'male',
#    'birth': {'date': '1852-12-19',
#     'place': {'city': {'en': 'Strelno', 'no': 'Strelno', 'se': 'Strelno'},
#      'country': {'en': 'Prussia', 'no': 'Preussen', 'se': 'Preussen'},
#      'cityNow': {'en': 'Strzelno',
#       'no': 'Strzelno',
#       'se': 'Strzelno',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1005414',
#        'https://www.wikipedia.org/wiki/Strzelno'],
#       'latitude': '52.629444',
#       'longitude': '18.170000'},
#      'countryNow': {'en': 'Poland',
#       'no': 'Polen',
#       'se': 'Polen',
#       'sameAs': ['https://www.wikidata.org/wiki/Q36'],
#       'latitude': '52.000000',
#       'longitude': '19.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Strelno, Prussia (now Strzelno, Poland)',
#       'no': 'Strelno, Preussen (nå Strzelno, Polen)',
#       'se': 'Strelno, Preussen (nu Strzelno, Polen)'}}},
#    'death': {'date': '1931-05-09',
#     'place': {'city': {'en': 'Pasadena, CA',
#       'no': 'Pasadena, CA',
#       'se': 'Pasadena, CA'},
#      'country': {'en': 'USA',
#       'no': 'USA',
#       'se': 'USA',
#       'sameAs': 'https://www.wikidata.org/wiki/Q30'},
#      'cityNow': {'en': 'Pasadena, CA',
#       'no': 'Pasadena, CA',
#       'se': 'Pasadena, CA',
#       'sameAs': ['https://www.wikidata.org/wiki/Q485176',
#        'https://www.wikipedia.org/wiki/Pasadena,_California'],
#       'latitude': '34.150071',
#       'longitude': '-118.142111'},
#      'countryNow': {'en': 'USA',
#       'no': 'USA',
#       'se': 'USA',
#       'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#       'latitude': '39.828175',
#       'longitude': '-98.579500'},
#      'continent': {'en': 'North America',
#       'no': 'Nord-Amerika',
#       'se': 'Nordamerika'},
#      'locationString': {'en': 'Pasadena, CA, USA',
#       'no': 'Pasadena, CA, USA',
#       'se': 'Pasadena, CA, USA'}}},
#    'wikipedia': {'slug': 'Albert_Abraham_Michelson',
#     'english': 'https://en.wikipedia.org/wiki/Albert_Abraham_Michelson'},
#    'wikidata': {'id': 'Q127234',
#     'url': 'https://www.wikidata.org/wiki/Q127234'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q127234',
#     'https://en.wikipedia.org/wiki/Albert_Abraham_Michelson'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/11',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/11',
#      'title': 'Albert A. Michelson - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1907',
#      'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#      'categoryFullName': {'en': 'The Nobel Prize in Physics',
#       'no': 'Nobelprisen i fysikk',
#       'se': 'Nobelpriset i fysik'},
#      'sortOrder': '1',
#      'portion': '1',
#      'dateAwarded': '1907-11-12',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for his optical precision instruments and the spectroscopic and metrological investigations carried out with their aid',
#       'se': 'för hans optiska precisionsinstrument och hans därmed utförda spektroskopiska och metrologiska undersökningar'},
#      'prizeAmount': 138796,
#      'prizeAmountAdjusted': 8894198,
#      'affiliations': [{'name': {'en': 'University of Chicago',
#         'no': 'University of Chicago',
#         'se': 'University of Chicago'},
#        'nameNow': {'en': 'University of Chicago'},
#        'city': {'en': 'Chicago, IL', 'no': 'Chicago, IL', 'se': 'Chicago, IL'},
#        'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#        'cityNow': {'en': 'Chicago, IL',
#         'no': 'Chicago, IL',
#         'se': 'Chicago, IL',
#         'sameAs': ['https://www.wikidata.org/wiki/Q1297',
#          'https://www.wikipedia.org/wiki/Chicago'],
#         'latitude': '41.876228',
#         'longitude': '-87.638416'},
#        'countryNow': {'en': 'USA',
#         'no': 'USA',
#         'se': 'USA',
#         'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#         'latitude': '39.828175',
#         'longitude': '-98.579500'},
#        'continent': {'en': 'North America'},
#        'locationString': {'en': 'Chicago, IL, USA',
#         'no': 'Chicago, IL, USA',
#         'se': 'Chicago, IL, USA'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1907',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/1907/michelson/facts/',
#        'title': 'Albert A. Michelson - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/physics/1907/summary/',
#        'title': 'The Nobel Prize in Physics 1907',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '628',
#    'knownName': {'en': 'Albert Camus', 'se': 'Albert Camus'},
#    'givenName': {'en': 'Albert', 'se': 'Albert'},
#    'familyName': {'en': 'Camus', 'se': 'Camus'},
#    'fullName': {'en': 'Albert Camus', 'se': 'Albert Camus'},
#    'fileName': 'camus',
#    'gender': 'male',
#    'birth': {'date': '1913-11-07',
#     'place': {'city': {'en': 'Mondovi', 'no': 'Mondovi', 'se': 'Mondovi'},
#      'country': {'en': 'French Algeria',
#       'no': 'fransk Algerie',
#       'se': 'Franska Algeriet'},
#      'cityNow': {'en': 'Mondovi',
#       'no': 'Mondovi',
#       'se': 'Mondovi',
#       'sameAs': ['https://www.wikidata.org/wiki/Q1924629',
#        'https://www.wikipedia.org/wiki/Dr%C3%A9an'],
#       'latitude': '44.395064',
#       'longitude': '7.819452'},
#      'countryNow': {'en': 'Algeria',
#       'no': 'Algerie',
#       'se': 'Algeriet',
#       'sameAs': ['https://www.wikidata.org/wiki/Q262'],
#       'latitude': '28.000000',
#       'longitude': '1.000000'},
#      'continent': {'en': 'Africa', 'no': 'Afrika', 'se': 'Afrika'},
#      'locationString': {'en': 'Mondovi, French Algeria (now Algeria)',
#       'no': 'Mondovi, fransk Algerie (nå Algerie)',
#       'se': 'Mondovi, Franska Algeriet (nu Algeriet)'}}},
#    'death': {'date': '1960-01-04',
#     'place': {'city': {'en': 'Sens', 'no': 'Sens', 'se': 'Sens'},
#      'country': {'en': 'France',
#       'no': 'Frankrike',
#       'se': 'Frankrike',
#       'sameAs': 'https://www.wikidata.org/wiki/Q142'},
#      'cityNow': {'en': 'Sens',
#       'no': 'Sens',
#       'se': 'Sens',
#       'sameAs': ['https://www.wikidata.org/wiki/Q212420',
#        'https://www.wikipedia.org/wiki/Sens'],
#       'latitude': '48.197222',
#       'longitude': '3.283333'},
#      'countryNow': {'en': 'France',
#       'no': 'Frankrike',
#       'se': 'Frankrike',
#       'sameAs': ['https://www.wikidata.org/wiki/Q142'],
#       'latitude': '47.000000',
#       'longitude': '2.000000'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Sens, France',
#       'no': 'Sens, Frankrike',
#       'se': 'Sens, Frankrike'}}},
#    'wikipedia': {'slug': 'Albert_Camus',
#     'english': 'https://en.wikipedia.org/wiki/Albert_Camus'},
#    'wikidata': {'id': 'Q34670', 'url': 'https://www.wikidata.org/wiki/Q34670'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q34670',
#     'https://en.wikipedia.org/wiki/Albert_Camus'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/628',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/628',
#      'title': 'Albert Camus - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1957',
#      'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'},
#      'categoryFullName': {'en': 'The Nobel Prize in Literature',
#       'no': 'Nobelprisen i litteratur',
#       'se': 'Nobelpriset i litteratur'},
#      'sortOrder': '1',
#      'portion': '1',
#      'dateAwarded': '1957-10-17',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for his important literary production, which with clear-sighted earnestness illuminates the problems of the human conscience in our times',
#       'se': 'för hans betydelsefulla författarskap, som med skarpsynt allvar belyser mänskliga samvetsproblem i vår tid'},
#      'prizeAmount': 208629,
#      'prizeAmountAdjusted': 3411444,
#      'residences': [{'country': {'en': 'France',
#         'no': 'Frankrike',
#         'se': 'Frankrike'},
#        'countryNow': {'en': 'France', 'no': 'Frankrike', 'se': 'Frankrike'},
#        'continent': {'en': 'Europe'},
#        'locationString': {'en': 'France',
#         'no': 'Frankrike',
#         'se': 'Frankrike'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/lit/1957',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/literature/1957/camus/facts/',
#        'title': 'Albert Camus - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/literature/1957/summary/',
#        'title': 'The Nobel Prize in Literature 1957',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]},
#   {'id': '403',
#    'knownName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#    'givenName': {'en': 'Albert', 'se': 'Albert'},
#    'familyName': {'en': 'Claude', 'se': 'Claude'},
#    'fullName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#    'fileName': 'claude',
#    'gender': 'male',
#    'birth': {'date': '1898-08-24',
#     'place': {'city': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#      'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#      'cityNow': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#      'countryNow': {'en': 'Belgium',
#       'no': 'Belgia',
#       'se': 'Belgien',
#       'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#       'latitude': '50.641111',
#       'longitude': '4.668056'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Longlier, Belgium',
#       'no': 'Longlier, Belgia',
#       'se': 'Longlier, Belgien'}}},
#    'death': {'date': '1983-05-22',
#     'place': {'city': {'en': 'Brussels', 'no': 'Brussel', 'se': 'Bryssel'},
#      'country': {'en': 'Belgium',
#       'no': 'Belgia',
#       'se': 'Belgien',
#       'sameAs': 'https://www.wikidata.org/wiki/Q31'},
#      'cityNow': {'en': 'Brussels',
#       'no': 'Brussel',
#       'se': 'Bryssel',
#       'sameAs': ['https://www.wikidata.org/wiki/Q239',
#        'https://www.wikipedia.org/wiki/City_of_Brussels'],
#       'latitude': '50.849243',
#       'longitude': '4.354815'},
#      'countryNow': {'en': 'Belgium',
#       'no': 'Belgia',
#       'se': 'Belgien',
#       'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#       'latitude': '50.641111',
#       'longitude': '4.668056'},
#      'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#      'locationString': {'en': 'Brussels, Belgium',
#       'no': 'Brussel, Belgia',
#       'se': 'Bryssel, Belgien'}}},
#    'wikipedia': {'slug': 'Albert_Claude',
#     'english': 'https://en.wikipedia.org/wiki/Albert_Claude'},
#    'wikidata': {'id': 'Q233943',
#     'url': 'https://www.wikidata.org/wiki/Q233943'},
#    'sameAs': ['https://www.wikidata.org/wiki/Q233943',
#     'https://en.wikipedia.org/wiki/Albert_Claude'],
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/403',
#      'action': 'GET',
#      'types': 'application/json'},
#     {'rel': 'external',
#      'href': 'https://www.nobelprize.org/laureate/403',
#      'title': 'Albert Claude - Facts',
#      'action': 'GET',
#      'types': 'text/html',
#      'class': ['laureate facts']}],
#    'nobelPrizes': [{'awardYear': '1974',
#      'category': {'en': 'Physiology or Medicine',
#       'no': 'Fysiologi eller medisin',
#       'se': 'Fysiologi eller medicin'},
#      'categoryFullName': {'en': 'The Nobel Prize in Physiology or Medicine',
#       'no': 'Nobelprisen i fysiologi eller medisin',
#       'se': 'Nobelpriset i fysiologi eller medicin'},
#      'sortOrder': '1',
#      'portion': '1/3',
#      'dateAwarded': '1974-10-10',
#      'prizeStatus': 'received',
#      'motivation': {'en': 'for their discoveries concerning the structural and functional organization of the cell',
#       'se': 'för deras upptäckter rörande cellens strukturella och funktionella organisation'},
#      'prizeAmount': 550000,
#      'prizeAmountAdjusted': 4126741,
#      'affiliations': [{'name': {'en': 'Université Catholique de Louvain',
#         'no': 'Université Catholique de Louvain',
#         'se': 'Université Catholique de Louvain'},
#        'nameNow': {'en': 'Université Catholique de Louvain'},
#        'city': {'en': 'Louvain', 'no': 'Louvain', 'se': 'Louvain'},
#        'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#        'cityNow': {'en': 'Louvain',
#         'no': 'Louvain',
#         'se': 'Louvain',
#         'sameAs': ['https://www.wikidata.org/wiki/Q118958',
#          'https://www.wikipedia.org/wiki/Leuven'],
#         'latitude': '50.883029',
#         'longitude': '4.713949'},
#        'countryNow': {'en': 'Belgium',
#         'no': 'Belgia',
#         'se': 'Belgien',
#         'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#         'latitude': '50.641111',
#         'longitude': '4.668056'},
#        'continent': {'en': 'Europe'},
#        'locationString': {'en': 'Louvain, Belgium',
#         'no': 'Louvain, Belgia',
#         'se': 'Louvain, Belgien'}}],
#      'links': [{'rel': 'nobelPrize',
#        'href': 'https://api.nobelprize.org/2/nobelPrize/med/1974',
#        'action': 'GET',
#        'types': 'application/json'},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/medicine/1974/claude/facts/',
#        'title': 'Albert Claude - Facts',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['laureate facts']},
#       {'rel': 'external',
#        'href': 'https://www.nobelprize.org/prizes/medicine/1974/summary/',
#        'title': 'The Nobel Prize in Physiology or Medicine 1974',
#        'action': 'GET',
#        'types': 'text/html',
#        'class': ['prize summary']}]}]}],
#  'meta': {'offset': 0,
#   'limit': 25,
#   'count': 1004,
#   'terms': 'https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/',
#   'license': 'https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/#licence',
#   'disclaimer': 'https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/#disclaimer'},
#  'links': {'first': 'http://nobel-external-api-app.azurewebsites.net/2.1/laureates?offset=0&limit=25',
#   'self': 'http://nobel-external-api-app.azurewebsites.net/2.1/laureates?offset=0&limit=25',
#   'next': 'http://nobel-external-api-app.azurewebsites.net/2.1/laureates?offset=25&limit=25',
#   'last': 'http://nobel-external-api-app.azurewebsites.net/2.1/laureates?offset=1000&limit=25'}}

# %% [markdown]
# #### Importing the data into a JSON File

# %%
import json

filename='response_api_version_2.json'
data=response_laureates['laureates']
with open(filename,'w') as json_file:
    json.dump(data,json_file)
print(f'Data saved to {filename}')
# Out:
# Data saved to response_api_version_2.json

# %% [markdown]
# #### Loading the JSON data into pandas DataFrame

# %%
data_read=pd.read_json(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data_read=pd.read_json(filename)
#
# NameError: name 'filename' is not defined

# %%
data_read.tail()
# Out:
#      id                                          knownName  \
# 20  376       {'en': 'Alan Hodgkin', 'se': 'Alan Hodgkin'}
# 21  730  {'en': 'Alan MacDiarmid', 'se': 'Alan MacDiarm...
# 22   11  {'en': 'Albert A. Michelson', 'se': 'Albert A....
# 23  628       {'en': 'Albert Camus', 'se': 'Albert Camus'}
# 24  403     {'en': 'Albert Claude', 'se': 'Albert Claude'}
#
#                                  givenName  \
# 20            {'en': 'Alan', 'se': 'Alan'}
# 21            {'en': 'Alan', 'se': 'Alan'}
# 22  {'en': 'Albert A.', 'se': 'Albert A.'}
# 23        {'en': 'Albert', 'se': 'Albert'}
# 24        {'en': 'Albert', 'se': 'Albert'}
#
#                                   familyName  \
# 20        {'en': 'Hodgkin', 'se': 'Hodgkin'}
# 21  {'en': 'MacDiarmid', 'se': 'MacDiarmid'}
# 22    {'en': 'Michelson', 'se': 'Michelson'}
# 23            {'en': 'Camus', 'se': 'Camus'}
# 24          {'en': 'Claude', 'se': 'Claude'}
#
#                                              fullName    fileName gender  \
# 20  {'en': 'Alan Lloyd Hodgkin', 'se': 'Alan Lloyd...     hodgkin   male
# 21  {'en': 'Alan G. MacDiarmid', 'se': 'Alan G. Ma...  macdiarmid   male
# 22  {'en': 'Albert Abraham Michelson', 'se': 'Albe...   michelson   male
# 23       {'en': 'Albert Camus', 'se': 'Albert Camus'}       camus   male
# 24     {'en': 'Albert Claude', 'se': 'Albert Claude'}      claude   male
#
#                                                 birth  \
# 20  {'date': '1914-02-05', 'place': {'city': {'en'...
# 21  {'date': '1927-04-14', 'place': {'city': {'en'...
# 22  {'date': '1852-12-19', 'place': {'city': {'en'...
# 23  {'date': '1913-11-07', 'place': {'city': {'en'...
# 24  {'date': '1898-08-24', 'place': {'city': {'en'...
#
#                                             wikipedia  \
# 20  {'slug': 'Alan_Lloyd_Hodgkin', 'english': 'htt...
# 21  {'slug': 'Alan_MacDiarmid', 'english': 'https:...
# 22  {'slug': 'Albert_Abraham_Michelson', 'english'...
# 23  {'slug': 'Albert_Camus', 'english': 'https://e...
# 24  {'slug': 'Albert_Claude', 'english': 'https://...
#
#                                              wikidata  \
# 20  {'id': 'Q193650', 'url': 'https://www.wikidata...
# 21  {'id': 'Q110942', 'url': 'https://www.wikidata...
# 22  {'id': 'Q127234', 'url': 'https://www.wikidata...
# 23  {'id': 'Q34670', 'url': 'https://www.wikidata....
# 24  {'id': 'Q233943', 'url': 'https://www.wikidata...
#
#                                                sameAs  \
# 20  [https://www.wikidata.org/wiki/Q193650, https:...
# 21  [https://www.wikidata.org/wiki/Q110942, https:...
# 22  [https://www.wikidata.org/wiki/Q127234, https:...
# 23  [https://www.wikidata.org/wiki/Q34670, https:/...
# 24  [https://www.wikidata.org/wiki/Q233943, https:...
#
#                                                 links  \
# 20  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 21  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 22  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 23  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 24  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                           nobelPrizes  \
# 20  [{'awardYear': '1963', 'category': {'en': 'Phy...
# 21  [{'awardYear': '2000', 'category': {'en': 'Che...
# 22  [{'awardYear': '1907', 'category': {'en': 'Phy...
# 23  [{'awardYear': '1957', 'category': {'en': 'Lit...
# 24  [{'awardYear': '1974', 'category': {'en': 'Phy...
#
#                                                 death
# 20  {'date': '1998-12-20', 'place': {'city': {'en'...
# 21  {'date': '2007-02-07', 'place': {'city': {'en'...
# 22  {'date': '1931-05-09', 'place': {'city': {'en'...
# 23  {'date': '1960-01-04', 'place': {'city': {'en'...
# 24  {'date': '1983-05-22', 'place': {'city': {'en'...

# %%
data
# Out:
# [{'id': '745',
#   'knownName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#   'givenName': {'en': 'A. Michael', 'se': 'A. Michael'},
#   'familyName': {'en': 'Spence', 'se': 'Spence'},
#   'fullName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#   'fileName': 'spence',
#   'gender': 'male',
#   'birth': {'date': '1943-00-00',
#    'place': {'city': {'en': 'Montclair, NJ',
#      'no': 'Montclair, NJ',
#      'se': 'Montclair, NJ'},
#     'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#     'cityNow': {'en': 'Montclair, NJ',
#      'no': 'Montclair, NJ',
#      'se': 'Montclair, NJ',
#      'sameAs': ['https://www.wikidata.org/wiki/Q678437',
#       'https://www.wikipedia.org/wiki/Montclair,_New_Jersey'],
#      'latitude': '40.825930',
#      'longitude': '-74.209030'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Montclair, NJ, USA',
#      'no': 'Montclair, NJ, USA',
#      'se': 'Montclair, NJ, USA'}}},
#   'wikipedia': {'slug': 'Michael_Spence',
#    'english': 'https://en.wikipedia.org/wiki/Michael_Spence'},
#   'wikidata': {'id': 'Q157245',
#    'url': 'https://www.wikidata.org/wiki/Q157245'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q157245',
#    'https://en.wikipedia.org/wiki/Michael_Spence'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/745',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/745',
#     'title': 'A. Michael Spence - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2001',
#     'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#     'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#      'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#      'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#     'sortOrder': '2',
#     'portion': '1/3',
#     'dateAwarded': '2001-10-10',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their analyses of markets with asymmetric information',
#      'se': 'för deras analys av marknader med assymetrisk informations'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 15547541,
#     'affiliations': [{'name': {'en': 'Stanford University',
#        'no': 'Stanford University',
#        'se': 'Stanford University'},
#       'nameNow': {'en': 'Stanford University'},
#       'city': {'en': 'Stanford, CA',
#        'no': 'Stanford, CA',
#        'se': 'Stanford, CA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Stanford, CA',
#        'no': 'Stanford, CA',
#        'se': 'Stanford, CA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q173813',
#         'https://www.wikipedia.org/wiki/Stanford,_California'],
#        'latitude': '37.424734',
#        'longitude': '-122.163858'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Stanford, CA, USA',
#        'no': 'Stanford, CA, USA',
#        'se': 'Stanford, CA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2001',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/spence/facts/',
#       'title': 'A. Michael Spence - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/summary/',
#       'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2001',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '102',
#   'knownName': {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'},
#   'givenName': {'en': 'Aage N.', 'se': 'Aage N.'},
#   'familyName': {'en': 'Bohr', 'se': 'Bohr'},
#   'fullName': {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bohr'},
#   'fileName': 'bohr',
#   'gender': 'male',
#   'birth': {'date': '1922-06-19',
#    'place': {'city': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn'},
#     'country': {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danmark'},
#     'cityNow': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#       'https://www.wikipedia.org/wiki/Copenhagen'],
#      'latitude': '55.678127',
#      'longitude': '12.572532'},
#     'countryNow': {'en': 'Denmark',
#      'no': 'Danmark',
#      'se': 'Danmark',
#      'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#      'latitude': '56.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Copenhagen, Denmark',
#      'no': 'København, Danmark',
#      'se': 'Köpenhamn, Danmark'}}},
#   'death': {'date': '2009-09-08',
#    'place': {'city': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn'},
#     'country': {'en': 'Denmark',
#      'no': 'Danmark',
#      'se': 'Danmark',
#      'sameAs': 'https://www.wikidata.org/wiki/Q35'},
#     'cityNow': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#       'https://www.wikipedia.org/wiki/Copenhagen'],
#      'latitude': '55.678127',
#      'longitude': '12.572532'},
#     'countryNow': {'en': 'Denmark',
#      'no': 'Danmark',
#      'se': 'Danmark',
#      'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#      'latitude': '56.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Copenhagen, Denmark',
#      'no': 'København, Danmark',
#      'se': 'Köpenhamn, Danmark'}}},
#   'wikipedia': {'slug': 'Aage_Bohr',
#    'english': 'https://en.wikipedia.org/wiki/Aage_Bohr'},
#   'wikidata': {'id': 'Q103854',
#    'url': 'https://www.wikidata.org/wiki/Q103854'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q103854',
#    'https://en.wikipedia.org/wiki/Aage_Bohr'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/102',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/102',
#     'title': 'Aage N. Bohr - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1975',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '1975-10-17',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for the discovery of the connection between collective motion and particle motion in atomic nuclei and the development of the theory of the structure of the atomic nucleus based on this connection',
#      'se': 'för upptäckten av sambandet mellan kollektiva rörelser och partikelrörelser i atomkärnor, samt den därpå baserade utvecklingen av teorien för atomkärnans struktur'},
#     'prizeAmount': 630000,
#     'prizeAmountAdjusted': 4304697,
#     'affiliations': [{'name': {'en': 'Niels Bohr Institute',
#        'no': 'Niels Bohr Institute',
#        'se': 'Niels Bohr Institute'},
#       'nameNow': {'en': 'Niels Bohr Institute'},
#       'city': {'en': 'Copenhagen', 'no': 'København', 'se': 'Köpenhamn'},
#       'country': {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danmark'},
#       'cityNow': {'en': 'Copenhagen',
#        'no': 'København',
#        'se': 'Köpenhamn',
#        'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#         'https://www.wikipedia.org/wiki/Copenhagen'],
#        'latitude': '55.678127',
#        'longitude': '12.572532'},
#       'countryNow': {'en': 'Denmark',
#        'no': 'Danmark',
#        'se': 'Danmark',
#        'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#        'latitude': '56.000000',
#        'longitude': '10.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Copenhagen, Denmark',
#        'no': 'København, Danmark',
#        'se': 'Köpenhamn, Danmark'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1975',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1975/bohr/facts/',
#       'title': 'Aage N. Bohr - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1975/summary/',
#       'title': 'The Nobel Prize in Physics 1975',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '779',
#   'knownName': {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciechanover'},
#   'givenName': {'en': 'Aaron', 'se': 'Aaron'},
#   'familyName': {'en': 'Ciechanover', 'se': 'Ciechanover'},
#   'fullName': {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciechanover'},
#   'fileName': 'ciechanover',
#   'gender': 'male',
#   'birth': {'date': '1947-10-01',
#    'place': {'city': {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'},
#     'country': {'en': 'British Protectorate of Palestine',
#      'no': 'British i Palestina',
#      'se': 'British Protectorate of Palestine'},
#     'cityNow': {'en': 'Haifa',
#      'no': 'Haifa',
#      'se': 'Haifa',
#      'sameAs': ['https://www.wikidata.org/wiki/Q41621',
#       'https://www.wikipedia.org/wiki/Haifa'],
#      'latitude': '32.794421',
#      'longitude': '34.990340'},
#     'countryNow': {'en': 'Israel',
#      'no': 'Israel',
#      'se': 'Israel',
#      'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#      'latitude': '31.000000',
#      'longitude': '35.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Haifa, British Protectorate of Palestine (now Israel)',
#      'no': 'Haifa, British i Palestina (nå Israel)',
#      'se': 'Haifa, British Protectorate of Palestine (nu Israel)'}}},
#   'wikipedia': {'slug': 'Aaron_Ciechanover',
#    'english': 'https://en.wikipedia.org/wiki/Aaron_Ciechanover'},
#   'wikidata': {'id': 'Q233205',
#    'url': 'https://www.wikidata.org/wiki/Q233205'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q233205',
#    'https://en.wikipedia.org/wiki/Aaron_Ciechanover'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/779',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/779',
#     'title': 'Aaron Ciechanover - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2004',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '2004-10-06',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for the discovery of ubiquitin-mediated protein degradation',
#      'se': 'för upptäckten av ubiquitinmedierad proteinnedbrytning'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 14874529,
#     'affiliations': [{'name': {'en': 'Technion - Israel Institute of Technology',
#        'no': 'Technion - Israel Institute of Technology',
#        'se': 'Technion - Israel Institute of Technology'},
#       'nameNow': {'en': 'Technion - Israel Institute of Technology'},
#       'city': {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'},
#       'country': {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'},
#       'cityNow': {'en': 'Haifa',
#        'no': 'Haifa',
#        'se': 'Haifa',
#        'sameAs': ['https://www.wikidata.org/wiki/Q41621',
#         'https://www.wikipedia.org/wiki/Haifa'],
#        'latitude': '32.794421',
#        'longitude': '34.990340'},
#       'countryNow': {'en': 'Israel',
#        'no': 'Israel',
#        'se': 'Israel',
#        'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#        'latitude': '31.000000',
#        'longitude': '35.000000'},
#       'continent': {'en': 'Asia'},
#       'locationString': {'en': 'Haifa, Israel',
#        'no': 'Haifa, Israel',
#        'se': 'Haifa, Israel'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/2004',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2004/ciechanover/facts/',
#       'title': 'Aaron Ciechanover - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2004/summary/',
#       'title': 'The Nobel Prize in Chemistry 2004',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '259',
#   'knownName': {'en': 'Aaron Klug', 'se': 'Aaron Klug'},
#   'givenName': {'en': 'Aaron', 'se': 'Aaron'},
#   'familyName': {'en': 'Klug', 'se': 'Klug'},
#   'fullName': {'en': 'Aaron Klug', 'se': 'Aaron Klug'},
#   'fileName': 'klug',
#   'gender': 'male',
#   'birth': {'date': '1926-08-11',
#    'place': {'city': {'en': 'Zelvas', 'no': 'Zelvas', 'se': 'Zelvas'},
#     'country': {'en': 'Lithuania', 'no': 'Litauen', 'se': 'Litauen'},
#     'cityNow': {'en': 'Zelvas',
#      'no': 'Zelvas',
#      'se': 'Zelvas',
#      'sameAs': ['https://www.wikidata.org/wiki/Q691679',
#       'https://www.wikipedia.org/wiki/%C5%BDelva'],
#      'latitude': '53.148256',
#      'longitude': '24.816515'},
#     'countryNow': {'en': 'Lithuania',
#      'no': 'Litauen',
#      'se': 'Litauen',
#      'sameAs': ['https://www.wikidata.org/wiki/Q37'],
#      'latitude': '55.200000',
#      'longitude': '24.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Zelvas, Lithuania',
#      'no': 'Zelvas, Litauen',
#      'se': 'Zelvas, Litauen'}}},
#   'death': {'date': '2018-11-20',
#    'place': {'locationString': {'en': '', 'no': '', 'se': ''}}},
#   'wikipedia': {'slug': 'Aaron_Klug',
#    'english': 'https://en.wikipedia.org/wiki/Aaron_Klug'},
#   'wikidata': {'id': 'Q190626',
#    'url': 'https://www.wikidata.org/wiki/Q190626'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q190626',
#    'https://en.wikipedia.org/wiki/Aaron_Klug'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/259',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/259',
#     'title': 'Aaron Klug - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1982',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '1982-10-18',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his development of crystallographic electron microscopy and his structural elucidation of biologically important nucleic acid-protein complexes',
#      'se': 'för hans utveckling av kristallografisk elektronmikroskopi och hans klarläggande av strukturen hos biologiskt viktiga nukleinsyra-proteinkomplex'},
#     'prizeAmount': 1150000,
#     'prizeAmountAdjusted': 3923237,
#     'affiliations': [{'name': {'en': 'MRC Laboratory of Molecular Biology',
#        'no': 'MRC Laboratory of Molecular Biology',
#        'se': 'MRC Laboratory of Molecular Biology'},
#       'nameNow': {'en': 'MRC Laboratory of Molecular Biology'},
#       'city': {'en': 'Cambridge', 'no': 'Cambridge', 'se': 'Cambridge'},
#       'country': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien'},
#       'cityNow': {'en': 'Cambridge',
#        'no': 'Cambridge',
#        'se': 'Cambridge',
#        'sameAs': ['https://www.wikidata.org/wiki/Q350',
#         'https://www.wikipedia.org/wiki/Cambridge'],
#        'latitude': '52.194605',
#        'longitude': '0.135092'},
#       'countryNow': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#        'latitude': '54.600000',
#        'longitude': '-2.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Cambridge, United Kingdom',
#        'no': 'Cambridge, Storbritannia',
#        'se': 'Cambridge, Storbritannien'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/1982',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/1982/klug/facts/',
#       'title': 'Aaron Klug - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/1982/summary/',
#       'title': 'The Nobel Prize in Chemistry 1982',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '1004',
#   'knownName': {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak Gurnah'},
#   'givenName': {'en': 'Abdulrazak', 'se': 'Abdulrazak'},
#   'familyName': {'en': 'Gurnah', 'se': 'Gurnah'},
#   'fullName': {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak Gurnah'},
#   'fileName': 'gurnah',
#   'gender': 'male',
#   'birth': {'date': '1948-00-00'},
#   'wikipedia': {'slug': 'Abdulrazak_Gurnah',
#    'english': 'https://en.wikipedia.org/wiki/Abdulrazak_Gurnah'},
#   'wikidata': {'id': 'Q317877',
#    'url': 'https://www.wikidata.org/wiki/Q317877'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q317877',
#    'https://en.wikipedia.org/wiki/Abdulrazak_Gurnah'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/1004',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/1004',
#     'title': 'Abdulrazak Gurnah - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2021',
#     'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'},
#     'categoryFullName': {'en': 'The Nobel Prize in Literature',
#      'no': 'Nobelprisen i litteratur',
#      'se': 'Nobelpriset i litteratur'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '2021-10-07',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his uncompromising and compassionate penetration of the effects of colonialism and the fate of the refugee in the gulf between cultures and continents'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 12096939,
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/lit/2021',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/2021/gurnah/facts/',
#       'title': 'Abdulrazak Gurnah - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/2021/summary/',
#       'title': 'The Nobel Prize in Literature 2021',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '114',
#   'knownName': {'en': 'Abdus Salam', 'se': 'Abdus Salam'},
#   'givenName': {'en': 'Abdus', 'se': 'Abdus'},
#   'familyName': {'en': 'Salam', 'se': 'Salam'},
#   'fullName': {'en': 'Abdus Salam', 'se': 'Abdus Salam'},
#   'fileName': 'salam',
#   'gender': 'male',
#   'birth': {'date': '1926-01-29',
#    'place': {'city': {'en': 'Jhang Maghiāna',
#      'no': 'Jhang Maghiāna',
#      'se': 'Jhang Maghiāna'},
#     'country': {'en': 'India', 'no': 'India', 'se': 'Indien'},
#     'cityNow': {'en': 'Jhang Maghiāna',
#      'no': 'Jhang Maghiāna',
#      'se': 'Jhang Maghiāna',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1026616',
#       'https://www.wikipedia.org/wiki/Jhang'],
#      'latitude': '31.268056',
#      'longitude': '72.318056'},
#     'countryNow': {'en': 'Pakistan',
#      'no': 'Pakistan',
#      'se': 'Pakistan',
#      'sameAs': ['https://www.wikidata.org/wiki/Q843'],
#      'latitude': '30.000000',
#      'longitude': '71.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Jhang Maghiāna, India (now Pakistan)',
#      'no': 'Jhang Maghiāna, India (nå Pakistan)',
#      'se': 'Jhang Maghiāna, Indien (nu Pakistan)'}}},
#   'death': {'date': '1996-11-21',
#    'place': {'city': {'en': 'Oxford', 'no': 'Oxford', 'se': 'Oxford'},
#     'country': {'en': 'United Kingdom',
#      'no': 'Storbritannia',
#      'se': 'Storbritannien',
#      'sameAs': 'https://www.wikidata.org/wiki/Q145'},
#     'cityNow': {'en': 'Oxford',
#      'no': 'Oxford',
#      'se': 'Oxford',
#      'sameAs': ['https://www.wikidata.org/wiki/Q34217',
#       'https://www.wikipedia.org/wiki/Oxford'],
#      'latitude': '51.753363',
#      'longitude': '-1.260979'},
#     'countryNow': {'en': 'United Kingdom',
#      'no': 'Storbritannia',
#      'se': 'Storbritannien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#      'latitude': '54.600000',
#      'longitude': '-2.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Oxford, United Kingdom',
#      'no': 'Oxford, Storbritannia',
#      'se': 'Oxford, Storbritannien'}}},
#   'wikipedia': {'slug': 'Abdus_Salam',
#    'english': 'https://en.wikipedia.org/wiki/Abdus_Salam'},
#   'wikidata': {'id': 'Q28189', 'url': 'https://www.wikidata.org/wiki/Q28189'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q28189',
#    'https://en.wikipedia.org/wiki/Abdus_Salam'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/114',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/114',
#     'title': 'Abdus Salam - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1979',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '2',
#     'portion': '1/3',
#     'dateAwarded': '1979-10-15',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their contributions to the theory of the unified weak and electromagnetic interaction between elementary particles, including, inter alia, the prediction of the weak neutral current',
#      'se': 'för deras insatser inom teorin för förenad svag och elektromagnetisk växelverkan mellan elementar partiklar, innefattande bl.a. förutsägelsen av den svaga neutrala strömmen'},
#     'prizeAmount': 800000,
#     'prizeAmountAdjusted': 3778486,
#     'affiliations': [{'name': {'en': 'International Centre for Theoretical Physics',
#        'no': 'International Centre for Theoretical Physics',
#        'se': 'International Centre for Theoretical Physics'},
#       'nameNow': {'en': 'International Centre for Theoretical Physics'},
#       'city': {'en': 'Trieste', 'no': 'Trieste', 'se': 'Trieste'},
#       'country': {'en': 'Italy', 'no': 'Italia', 'se': 'Italien'},
#       'cityNow': {'en': 'Trieste',
#        'no': 'Trieste',
#        'se': 'Trieste',
#        'sameAs': ['https://www.wikidata.org/wiki/Q546',
#         'https://www.wikipedia.org/wiki/Trieste'],
#        'latitude': '45.649433',
#        'longitude': '13.776623'},
#       'countryNow': {'en': 'Italy',
#        'no': 'Italia',
#        'se': 'Italien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q38'],
#        'latitude': '42.500000',
#        'longitude': '12.500000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Trieste, Italy',
#        'no': 'Trieste, Italia',
#        'se': 'Trieste, Italien'}},
#      {'name': {'en': 'Imperial College',
#        'no': 'Imperial College',
#        'se': 'Imperial College'},
#       'nameNow': {'en': 'Imperial College'},
#       'city': {'en': 'London', 'no': 'London', 'se': 'London'},
#       'country': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien'},
#       'cityNow': {'en': 'London',
#        'no': 'London',
#        'se': 'London',
#        'sameAs': ['https://www.wikidata.org/wiki/Q84',
#         'https://www.wikipedia.org/wiki/London'],
#        'latitude': '51.510235',
#        'longitude': '-0.120852'},
#       'countryNow': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#        'latitude': '54.600000',
#        'longitude': '-2.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'London, United Kingdom',
#        'no': 'London, Storbritannia',
#        'se': 'London, Storbritannien'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1979',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1979/salam/facts/',
#       'title': 'Abdus Salam - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1979/summary/',
#       'title': 'The Nobel Prize in Physics 1979',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '982',
#   'knownName': {'en': 'Abhijit Banerjee', 'se': 'Abhijit Banerjee'},
#   'givenName': {'en': 'Abhijit', 'se': 'Abhijit'},
#   'familyName': {'en': 'Banerjee', 'se': 'Banerjee'},
#   'fullName': {'en': 'Abhijit Banerjee', 'se': 'Abhijit Banerjee'},
#   'fileName': 'banerjee',
#   'gender': 'male',
#   'birth': {'date': '1961-02-21',
#    'place': {'city': {'en': 'Mumbai', 'no': 'Mumbai', 'se': 'Mumbai'},
#     'country': {'en': 'India', 'no': 'India', 'se': 'Indien'},
#     'cityNow': {'en': 'Mumbai',
#      'no': 'Mumbai',
#      'se': 'Mumbai',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1156',
#       'https://www.wikipedia.org/wiki/Mumbai'],
#      'latitude': '19.075833',
#      'longitude': '72.877500'},
#     'countryNow': {'en': 'India',
#      'no': 'India',
#      'se': 'Indien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q668'],
#      'latitude': '22.800000',
#      'longitude': '83.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Mumbai, India',
#      'no': 'Mumbai, India',
#      'se': 'Mumbai, Indien'}}},
#   'wikipedia': {'slug': 'Abhijit_Banerjee',
#    'english': 'https://en.wikipedia.org/wiki/Abhijit_Banerjee'},
#   'wikidata': {'id': 'Q320578',
#    'url': 'https://www.wikidata.org/wiki/Q320578'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q320578',
#    'https://en.wikipedia.org/wiki/Abhijit_Banerjee'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/982',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/982',
#     'title': 'Abhijit Banerjee - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2019',
#     'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#     'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#      'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#      'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '2019-10-14',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their experimental approach to alleviating global poverty',
#      'se': 'för deras experimentella ansats för att mildra global fattigdom'},
#     'prizeAmount': 9000000,
#     'prizeAmountAdjusted': 11178104,
#     'affiliations': [{'name': {'en': 'Massachusetts Institute of Technology (MIT)',
#        'no': 'Massachusetts Institute of Technology (MIT)',
#        'se': 'Massachusetts Institute of Technology (MIT)'},
#       'nameNow': {'en': 'Massachusetts Institute of Technology (MIT)'},
#       'city': {'en': 'Cambridge, MA',
#        'no': 'Cambridge, MA',
#        'se': 'Cambridge, MA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Cambridge, MA',
#        'no': 'Cambridge, MA',
#        'se': 'Cambridge, MA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q49111',
#         'https://www.wikipedia.org/wiki/Cambridge,_Massachusetts'],
#        'latitude': '42.374024',
#        'longitude': '-71.107306'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Cambridge, MA, USA',
#        'no': 'Cambridge, MA, USA',
#        'se': 'Cambridge, MA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2019',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2019/banerjee/facts/',
#       'title': 'Abhijit Banerjee - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2019/summary/',
#       'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2019',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '981',
#   'knownName': {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'},
#   'givenName': {'en': 'Abiy', 'se': 'Abiy'},
#   'familyName': {'en': 'Ahmed Ali', 'se': 'Ahmed Ali'},
#   'fullName': {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'},
#   'fileName': 'abiy',
#   'gender': 'male',
#   'birth': {'date': '1976-08-15',
#    'place': {'city': {'en': 'Beshasha', 'no': 'Beshasha', 'se': 'Beshasha'},
#     'country': {'en': 'Ethiopia', 'no': 'Etiopia', 'se': 'Etiopien'},
#     'cityNow': {'en': 'Beshasha',
#      'no': 'Beshasha',
#      'se': 'Beshasha',
#      'sameAs': ['https://www.wikidata.org/wiki/Q2899862',
#       'https://www.wikipedia.org/wiki/Beshasha'],
#      'latitude': '7.795864',
#      'longitude': '36.477062'},
#     'countryNow': {'en': 'Ethiopia',
#      'no': 'Etiopia',
#      'se': 'Etiopien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q115'],
#      'latitude': '9.000000',
#      'longitude': '40.000000'},
#     'continent': {'en': 'Africa', 'no': 'Afrika', 'se': 'Afrika'},
#     'locationString': {'en': 'Beshasha, Ethiopia',
#      'no': 'Beshasha, Etiopia',
#      'se': 'Beshasha, Etiopien'}}},
#   'wikipedia': {'slug': 'Abiy_Ahmed',
#    'english': 'https://en.wikipedia.org/wiki/Abiy_Ahmed'},
#   'wikidata': {'id': 'Q50365049',
#    'url': 'https://www.wikidata.org/wiki/Q50365049'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q50365049',
#    'https://en.wikipedia.org/wiki/Abiy_Ahmed'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/981',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/981',
#     'title': 'Abiy Ahmed Ali - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2019',
#     'category': {'en': 'Peace', 'no': 'Fred', 'se': 'Fred'},
#     'categoryFullName': {'en': 'The Nobel Peace Prize',
#      'no': 'Nobels fredspris',
#      'se': 'Nobels fredspris'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '2019-10-11',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his efforts to achieve peace and international cooperation, and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea',
#      'no': 'for hans innsats for fred og mellomstatlig samarbeid, og da særlig for hans avgjørande initiativ for å løsa grensekonflikten med nabolandet Eritrea'},
#     'prizeAmount': 9000000,
#     'prizeAmountAdjusted': 11178104,
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/pea/2019',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/peace/2019/abiy/facts/',
#       'title': 'Abiy Ahmed Ali - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/peace/2019/summary/',
#       'title': 'The Nobel Peace Prize 2019',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '843',
#   'knownName': {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'},
#   'givenName': {'en': 'Ada E.', 'se': 'Ada E.'},
#   'familyName': {'en': 'Yonath', 'se': 'Yonath'},
#   'fullName': {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'},
#   'fileName': 'yonath',
#   'gender': 'female',
#   'birth': {'date': '1939-06-22',
#    'place': {'city': {'en': 'Jerusalem', 'no': 'Jerusalem', 'se': 'Jerusalem'},
#     'country': {'en': 'British Mandate of Palestine',
#      'no': 'Palestinamandatet',
#      'se': 'Brittiska Palestinamandatet'},
#     'cityNow': {'en': 'Jerusalem',
#      'no': 'Jerusalem',
#      'se': 'Jerusalem',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1218',
#       'https://www.wikipedia.org/wiki/Jerusalem'],
#      'latitude': '31.767983',
#      'longitude': '35.213809'},
#     'countryNow': {'en': 'Israel',
#      'no': 'Israel',
#      'se': 'Israel',
#      'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#      'latitude': '31.000000',
#      'longitude': '35.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Jerusalem, British Mandate of Palestine (now Israel)',
#      'no': 'Jerusalem, Palestinamandatet (nå Israel)',
#      'se': 'Jerusalem, Brittiska Palestinamandatet (nu Israel)'}}},
#   'wikipedia': {'slug': 'Ada_Yonath',
#    'english': 'https://en.wikipedia.org/wiki/Ada_Yonath'},
#   'wikidata': {'id': 'Q7426', 'url': 'https://www.wikidata.org/wiki/Q7426'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q7426',
#    'https://en.wikipedia.org/wiki/Ada_Yonath'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/843',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/843',
#     'title': 'Ada E. Yonath - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2009',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '3',
#     'portion': '1/3',
#     'dateAwarded': '2009-10-07',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for studies of the structure and function of the ribosome',
#      'se': 'för studier av ribosomens struktur och funktion'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 13857393,
#     'affiliations': [{'name': {'en': 'Weizmann Institute of Science',
#        'no': 'Weizmann Institute of Science',
#        'se': 'Weizmann Institute of Science'},
#       'nameNow': {'en': 'Weizmann Institute of Science'},
#       'city': {'en': 'Rehovot', 'no': 'Rehovot', 'se': 'Rehovot'},
#       'country': {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'},
#       'cityNow': {'en': 'Rehovot',
#        'no': 'Rehovot',
#        'se': 'Rehovot',
#        'sameAs': ['https://www.wikidata.org/wiki/Q207350',
#         'https://www.wikipedia.org/wiki/Rehovot'],
#        'latitude': '31.892773',
#        'longitude': '34.811272'},
#       'countryNow': {'en': 'Israel',
#        'no': 'Israel',
#        'se': 'Israel',
#        'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#        'latitude': '31.000000',
#        'longitude': '35.000000'},
#       'continent': {'en': 'Asia'},
#       'locationString': {'en': 'Rehovot, Israel',
#        'no': 'Rehovot, Israel',
#        'se': 'Rehovot, Israel'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/2009',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2009/yonath/facts/',
#       'title': 'Ada E. Yonath - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2009/summary/',
#       'title': 'The Nobel Prize in Chemistry 2009',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '866',
#   'knownName': {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'},
#   'givenName': {'en': 'Adam G.', 'se': 'Adam G.'},
#   'familyName': {'en': 'Riess', 'se': 'Riess'},
#   'fullName': {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'},
#   'fileName': 'riess',
#   'gender': 'male',
#   'birth': {'date': '1969-12-16',
#    'place': {'city': {'en': 'Washington, D.C.',
#      'no': 'Washington, D.C.',
#      'se': 'Washington, D.C.'},
#     'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#     'cityNow': {'en': 'Washington, D.C.',
#      'no': 'Washington, D.C.',
#      'se': 'Washington, D.C.',
#      'sameAs': ['https://www.wikidata.org/wiki/Q61',
#       'https://www.wikipedia.org/wiki/Washington,_D.C.'],
#      'latitude': '38.899065',
#      'longitude': '-77.036523'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Washington, D.C., USA',
#      'no': 'Washington, D.C., USA',
#      'se': 'Washington, D.C., USA'}}},
#   'wikipedia': {'slug': 'Adam_Riess',
#    'english': 'https://en.wikipedia.org/wiki/Adam_Riess'},
#   'wikidata': {'id': 'Q106454',
#    'url': 'https://www.wikidata.org/wiki/Q106454'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q106454',
#    'https://en.wikipedia.org/wiki/Adam_Riess'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/866',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/866',
#     'title': 'Adam G. Riess - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2011',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '3',
#     'portion': '1/4',
#     'dateAwarded': '2011-10-04',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for the discovery of the accelerating expansion of the Universe through observations of distant supernovae',
#      'se': 'för upptäckten av universums accelererande expansion genom observationer av avlägsna supernovor'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 13335208,
#     'affiliations': [{'name': {'en': 'Johns Hopkins University',
#        'no': 'Johns Hopkins University',
#        'se': 'Johns Hopkins University'},
#       'nameNow': {'en': 'Johns Hopkins University'},
#       'city': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD',
#        'sameAs': ['https://www.wikidata.org/wiki/Q5092',
#         'https://www.wikipedia.org/wiki/Baltimore'],
#        'latitude': '39.291586',
#        'longitude': '-76.625305'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Baltimore, MD, USA',
#        'no': 'Baltimore, MD, USA',
#        'se': 'Baltimore, MD, USA'}},
#      {'name': {'en': 'Space Telescope Science Institute',
#        'no': 'Space Telescope Science Institute',
#        'se': 'Space Telescope Science Institute'},
#       'nameNow': {'en': 'Space Telescope Science Institute'},
#       'city': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD',
#        'sameAs': ['https://www.wikidata.org/wiki/Q5092',
#         'https://www.wikipedia.org/wiki/Baltimore'],
#        'latitude': '39.291586',
#        'longitude': '-76.625305'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Baltimore, MD, USA',
#        'no': 'Baltimore, MD, USA',
#        'se': 'Baltimore, MD, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/2011',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/2011/riess/facts/',
#       'title': 'Adam G. Riess - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/2011/summary/',
#       'title': 'The Nobel Prize in Physics 2011',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '199',
#   'knownName': {'en': 'Adolf Butenandt', 'se': 'Adolf Butenandt'},
#   'givenName': {'en': 'Adolf', 'se': 'Adolf'},
#   'familyName': {'en': 'Butenandt', 'se': 'Butenandt'},
#   'fullName': {'en': 'Adolf Friedrich Johann Butenandt',
#    'se': 'Adolf Friedrich Johann Butenandt'},
#   'fileName': 'butenandt',
#   'gender': 'male',
#   'birth': {'date': '1903-03-24',
#    'place': {'city': {'en': 'Bremerhaven-Lehe',
#      'no': 'Bremerhaven-Lehe',
#      'se': 'Bremerhaven-Lehe'},
#     'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#     'cityNow': {'en': 'Bremerhaven-Lehe',
#      'no': 'Bremerhaven-Lehe',
#      'se': 'Bremerhaven-Lehe',
#      'sameAs': ['https://www.wikidata.org/wiki/Q2706',
#       'https://www.wikipedia.org/wiki/Bremerhaven'],
#      'latitude': '53.550000',
#      'longitude': '8.583333'},
#     'countryNow': {'en': 'Germany',
#      'no': 'Tyskland',
#      'se': 'Tyskland',
#      'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#      'latitude': '51.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Bremerhaven-Lehe, Germany',
#      'no': 'Bremerhaven-Lehe, Tyskland',
#      'se': 'Bremerhaven-Lehe, Tyskland'}}},
#   'death': {'date': '1995-01-18',
#    'place': {'city': {'en': 'Munich', 'no': 'München', 'se': 'München'},
#     'country': {'en': 'Germany',
#      'no': 'Tyskland',
#      'se': 'Tyskland',
#      'sameAs': 'https://www.wikidata.org/wiki/Q183'},
#     'cityNow': {'en': 'Munich',
#      'no': 'München',
#      'se': 'München',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1726',
#       'https://www.wikipedia.org/wiki/Munich'],
#      'latitude': '48.134703',
#      'longitude': '11.581995'},
#     'countryNow': {'en': 'Germany',
#      'no': 'Tyskland',
#      'se': 'Tyskland',
#      'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#      'latitude': '51.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Munich, Germany',
#      'no': 'München, Tyskland',
#      'se': 'München, Tyskland'}}},
#   'wikipedia': {'slug': 'Adolf_Butenandt',
#    'english': 'https://en.wikipedia.org/wiki/Adolf_Butenandt'},
#   'wikidata': {'id': 'Q5327', 'url': 'https://www.wikidata.org/wiki/Q5327'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q5327',
#    'https://en.wikipedia.org/wiki/Adolf_Butenandt'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/199',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/199',
#     'title': 'Adolf Butenandt - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1939',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '1',
#     'portion': '1/2',
#     'dateAwarded': '1939-11-09',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his work on sex hormones',
#      'se': 'för hans arbeten över sexualhormoner'},
#     'prizeAmount': 148822,
#     'prizeAmountAdjusted': 5346318,
#     'affiliations': [{'name': {'en': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#        'no': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#        'se': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie'},
#       'nameNow': {'en': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie'},
#       'city': {'en': 'Berlin-Dahlem',
#        'no': 'Berlin-Dahlem',
#        'se': 'Berlin-Dahlem'},
#       'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#       'cityNow': {'en': 'Berlin-Dahlem',
#        'no': 'Berlin-Dahlem',
#        'se': 'Berlin-Dahlem',
#        'sameAs': ['https://www.wikidata.org/wiki/Q700541',
#         'https://www.wikipedia.org/wiki/Dahlem_(Berlin)'],
#        'latitude': '52.453739',
#        'longitude': '13.293130'},
#       'countryNow': {'en': 'Germany',
#        'no': 'Tyskland',
#        'se': 'Tyskland',
#        'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#        'latitude': '51.000000',
#        'longitude': '10.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Berlin-Dahlem, Germany',
#        'no': 'Berlin-Dahlem, Tyskland',
#        'se': 'Berlin-Dahlem, Tyskland'}},
#      {'name': {'en': 'Berlin University',
#        'no': 'Berlin University',
#        'se': 'Berlin University'},
#       'nameNow': {'en': 'Berlin University'},
#       'city': {'en': 'Berlin', 'no': 'Berlin', 'se': 'Berlin'},
#       'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#       'cityNow': {'en': 'Berlin',
#        'no': 'Berlin',
#        'se': 'Berlin',
#        'sameAs': ['https://www.wikidata.org/wiki/Q64',
#         'https://www.wikipedia.org/wiki/Berlin'],
#        'latitude': '52.522265',
#        'longitude': '13.406852'},
#       'countryNow': {'en': 'Germany',
#        'no': 'Tyskland',
#        'se': 'Tyskland',
#        'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#        'latitude': '51.000000',
#        'longitude': '10.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Berlin, Germany',
#        'no': 'Berlin, Tyskland',
#        'se': 'Berlin, Tyskland'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/1939',
# ...
#      'se': 'för upptäckten och utvecklandet av ledande polymerer'},
#     'prizeAmount': 9000000,
#     'prizeAmountAdjusted': 14331095,
#     'affiliations': [{'name': {'en': 'University of Pennsylvania',
#        'no': 'University of Pennsylvania',
#        'se': 'University of Pennsylvania'},
#       'nameNow': {'en': 'University of Pennsylvania'},
#       'city': {'en': 'Philadelphia, PA',
#        'no': 'Philadelphia, PA',
#        'se': 'Philadelphia, PA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Philadelphia, PA',
#        'no': 'Philadelphia, PA',
#        'se': 'Philadelphia, PA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q1345',
#         'https://www.wikipedia.org/wiki/Philadelphia'],
#        'latitude': '39.957132',
#        'longitude': '-75.174342'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Philadelphia, PA, USA',
#        'no': 'Philadelphia, PA, USA',
#        'se': 'Philadelphia, PA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/2000',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2000/macdiarmid/facts/',
#       'title': 'Alan MacDiarmid - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2000/summary/',
#       'title': 'The Nobel Prize in Chemistry 2000',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '11',
#   'knownName': {'en': 'Albert A. Michelson', 'se': 'Albert A. Michelson'},
#   'givenName': {'en': 'Albert A.', 'se': 'Albert A.'},
#   'familyName': {'en': 'Michelson', 'se': 'Michelson'},
#   'fullName': {'en': 'Albert Abraham Michelson',
#    'se': 'Albert Abraham Michelson'},
#   'fileName': 'michelson',
#   'gender': 'male',
#   'birth': {'date': '1852-12-19',
#    'place': {'city': {'en': 'Strelno', 'no': 'Strelno', 'se': 'Strelno'},
#     'country': {'en': 'Prussia', 'no': 'Preussen', 'se': 'Preussen'},
#     'cityNow': {'en': 'Strzelno',
#      'no': 'Strzelno',
#      'se': 'Strzelno',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1005414',
#       'https://www.wikipedia.org/wiki/Strzelno'],
#      'latitude': '52.629444',
#      'longitude': '18.170000'},
#     'countryNow': {'en': 'Poland',
#      'no': 'Polen',
#      'se': 'Polen',
#      'sameAs': ['https://www.wikidata.org/wiki/Q36'],
#      'latitude': '52.000000',
#      'longitude': '19.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Strelno, Prussia (now Strzelno, Poland)',
#      'no': 'Strelno, Preussen (nå Strzelno, Polen)',
#      'se': 'Strelno, Preussen (nu Strzelno, Polen)'}}},
#   'death': {'date': '1931-05-09',
#    'place': {'city': {'en': 'Pasadena, CA',
#      'no': 'Pasadena, CA',
#      'se': 'Pasadena, CA'},
#     'country': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': 'https://www.wikidata.org/wiki/Q30'},
#     'cityNow': {'en': 'Pasadena, CA',
#      'no': 'Pasadena, CA',
#      'se': 'Pasadena, CA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q485176',
#       'https://www.wikipedia.org/wiki/Pasadena,_California'],
#      'latitude': '34.150071',
#      'longitude': '-118.142111'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Pasadena, CA, USA',
#      'no': 'Pasadena, CA, USA',
#      'se': 'Pasadena, CA, USA'}}},
#   'wikipedia': {'slug': 'Albert_Abraham_Michelson',
#    'english': 'https://en.wikipedia.org/wiki/Albert_Abraham_Michelson'},
#   'wikidata': {'id': 'Q127234',
#    'url': 'https://www.wikidata.org/wiki/Q127234'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q127234',
#    'https://en.wikipedia.org/wiki/Albert_Abraham_Michelson'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/11',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/11',
#     'title': 'Albert A. Michelson - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1907',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '1907-11-12',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his optical precision instruments and the spectroscopic and metrological investigations carried out with their aid',
#      'se': 'för hans optiska precisionsinstrument och hans därmed utförda spektroskopiska och metrologiska undersökningar'},
#     'prizeAmount': 138796,
#     'prizeAmountAdjusted': 8894198,
#     'affiliations': [{'name': {'en': 'University of Chicago',
#        'no': 'University of Chicago',
#        'se': 'University of Chicago'},
#       'nameNow': {'en': 'University of Chicago'},
#       'city': {'en': 'Chicago, IL', 'no': 'Chicago, IL', 'se': 'Chicago, IL'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Chicago, IL',
#        'no': 'Chicago, IL',
#        'se': 'Chicago, IL',
#        'sameAs': ['https://www.wikidata.org/wiki/Q1297',
#         'https://www.wikipedia.org/wiki/Chicago'],
#        'latitude': '41.876228',
#        'longitude': '-87.638416'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Chicago, IL, USA',
#        'no': 'Chicago, IL, USA',
#        'se': 'Chicago, IL, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1907',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1907/michelson/facts/',
#       'title': 'Albert A. Michelson - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1907/summary/',
#       'title': 'The Nobel Prize in Physics 1907',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '628',
#   'knownName': {'en': 'Albert Camus', 'se': 'Albert Camus'},
#   'givenName': {'en': 'Albert', 'se': 'Albert'},
#   'familyName': {'en': 'Camus', 'se': 'Camus'},
#   'fullName': {'en': 'Albert Camus', 'se': 'Albert Camus'},
#   'fileName': 'camus',
#   'gender': 'male',
#   'birth': {'date': '1913-11-07',
#    'place': {'city': {'en': 'Mondovi', 'no': 'Mondovi', 'se': 'Mondovi'},
#     'country': {'en': 'French Algeria',
#      'no': 'fransk Algerie',
#      'se': 'Franska Algeriet'},
#     'cityNow': {'en': 'Mondovi',
#      'no': 'Mondovi',
#      'se': 'Mondovi',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1924629',
#       'https://www.wikipedia.org/wiki/Dr%C3%A9an'],
#      'latitude': '44.395064',
#      'longitude': '7.819452'},
#     'countryNow': {'en': 'Algeria',
#      'no': 'Algerie',
#      'se': 'Algeriet',
#      'sameAs': ['https://www.wikidata.org/wiki/Q262'],
#      'latitude': '28.000000',
#      'longitude': '1.000000'},
#     'continent': {'en': 'Africa', 'no': 'Afrika', 'se': 'Afrika'},
#     'locationString': {'en': 'Mondovi, French Algeria (now Algeria)',
#      'no': 'Mondovi, fransk Algerie (nå Algerie)',
#      'se': 'Mondovi, Franska Algeriet (nu Algeriet)'}}},
#   'death': {'date': '1960-01-04',
#    'place': {'city': {'en': 'Sens', 'no': 'Sens', 'se': 'Sens'},
#     'country': {'en': 'France',
#      'no': 'Frankrike',
#      'se': 'Frankrike',
#      'sameAs': 'https://www.wikidata.org/wiki/Q142'},
#     'cityNow': {'en': 'Sens',
#      'no': 'Sens',
#      'se': 'Sens',
#      'sameAs': ['https://www.wikidata.org/wiki/Q212420',
#       'https://www.wikipedia.org/wiki/Sens'],
#      'latitude': '48.197222',
#      'longitude': '3.283333'},
#     'countryNow': {'en': 'France',
#      'no': 'Frankrike',
#      'se': 'Frankrike',
#      'sameAs': ['https://www.wikidata.org/wiki/Q142'],
#      'latitude': '47.000000',
#      'longitude': '2.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Sens, France',
#      'no': 'Sens, Frankrike',
#      'se': 'Sens, Frankrike'}}},
#   'wikipedia': {'slug': 'Albert_Camus',
#    'english': 'https://en.wikipedia.org/wiki/Albert_Camus'},
#   'wikidata': {'id': 'Q34670', 'url': 'https://www.wikidata.org/wiki/Q34670'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q34670',
#    'https://en.wikipedia.org/wiki/Albert_Camus'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/628',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/628',
#     'title': 'Albert Camus - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1957',
#     'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'},
#     'categoryFullName': {'en': 'The Nobel Prize in Literature',
#      'no': 'Nobelprisen i litteratur',
#      'se': 'Nobelpriset i litteratur'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '1957-10-17',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his important literary production, which with clear-sighted earnestness illuminates the problems of the human conscience in our times',
#      'se': 'för hans betydelsefulla författarskap, som med skarpsynt allvar belyser mänskliga samvetsproblem i vår tid'},
#     'prizeAmount': 208629,
#     'prizeAmountAdjusted': 3411444,
#     'residences': [{'country': {'en': 'France',
#        'no': 'Frankrike',
#        'se': 'Frankrike'},
#       'countryNow': {'en': 'France', 'no': 'Frankrike', 'se': 'Frankrike'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'France',
#        'no': 'Frankrike',
#        'se': 'Frankrike'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/lit/1957',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/1957/camus/facts/',
#       'title': 'Albert Camus - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/1957/summary/',
#       'title': 'The Nobel Prize in Literature 1957',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '403',
#   'knownName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#   'givenName': {'en': 'Albert', 'se': 'Albert'},
#   'familyName': {'en': 'Claude', 'se': 'Claude'},
#   'fullName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#   'fileName': 'claude',
#   'gender': 'male',
#   'birth': {'date': '1898-08-24',
#    'place': {'city': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#     'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#     'cityNow': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#     'countryNow': {'en': 'Belgium',
#      'no': 'Belgia',
#      'se': 'Belgien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#      'latitude': '50.641111',
#      'longitude': '4.668056'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Longlier, Belgium',
#      'no': 'Longlier, Belgia',
#      'se': 'Longlier, Belgien'}}},
#   'death': {'date': '1983-05-22',
#    'place': {'city': {'en': 'Brussels', 'no': 'Brussel', 'se': 'Bryssel'},
#     'country': {'en': 'Belgium',
#      'no': 'Belgia',
#      'se': 'Belgien',
#      'sameAs': 'https://www.wikidata.org/wiki/Q31'},
#     'cityNow': {'en': 'Brussels',
#      'no': 'Brussel',
#      'se': 'Bryssel',
#      'sameAs': ['https://www.wikidata.org/wiki/Q239',
#       'https://www.wikipedia.org/wiki/City_of_Brussels'],
#      'latitude': '50.849243',
#      'longitude': '4.354815'},
#     'countryNow': {'en': 'Belgium',
#      'no': 'Belgia',
#      'se': 'Belgien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#      'latitude': '50.641111',
#      'longitude': '4.668056'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Brussels, Belgium',
#      'no': 'Brussel, Belgia',
#      'se': 'Bryssel, Belgien'}}},
#   'wikipedia': {'slug': 'Albert_Claude',
#    'english': 'https://en.wikipedia.org/wiki/Albert_Claude'},
#   'wikidata': {'id': 'Q233943',
#    'url': 'https://www.wikidata.org/wiki/Q233943'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q233943',
#    'https://en.wikipedia.org/wiki/Albert_Claude'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/403',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/403',
#     'title': 'Albert Claude - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1974',
#     'category': {'en': 'Physiology or Medicine',
#      'no': 'Fysiologi eller medisin',
#      'se': 'Fysiologi eller medicin'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physiology or Medicine',
#      'no': 'Nobelprisen i fysiologi eller medisin',
#      'se': 'Nobelpriset i fysiologi eller medicin'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '1974-10-10',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their discoveries concerning the structural and functional organization of the cell',
#      'se': 'för deras upptäckter rörande cellens strukturella och funktionella organisation'},
#     'prizeAmount': 550000,
#     'prizeAmountAdjusted': 4126741,
#     'affiliations': [{'name': {'en': 'Université Catholique de Louvain',
#        'no': 'Université Catholique de Louvain',
#        'se': 'Université Catholique de Louvain'},
#       'nameNow': {'en': 'Université Catholique de Louvain'},
#       'city': {'en': 'Louvain', 'no': 'Louvain', 'se': 'Louvain'},
#       'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#       'cityNow': {'en': 'Louvain',
#        'no': 'Louvain',
#        'se': 'Louvain',
#        'sameAs': ['https://www.wikidata.org/wiki/Q118958',
#         'https://www.wikipedia.org/wiki/Leuven'],
#        'latitude': '50.883029',
#        'longitude': '4.713949'},
#       'countryNow': {'en': 'Belgium',
#        'no': 'Belgia',
#        'se': 'Belgien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#        'latitude': '50.641111',
#        'longitude': '4.668056'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Louvain, Belgium',
#        'no': 'Louvain, Belgia',
#        'se': 'Louvain, Belgien'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/med/1974',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/medicine/1974/claude/facts/',
#       'title': 'Albert Claude - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/medicine/1974/summary/',
#       'title': 'The Nobel Prize in Physiology or Medicine 1974',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]}]

# %%
response_laureates['laureates']
# Out:
# [{'id': '745',
#   'knownName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#   'givenName': {'en': 'A. Michael', 'se': 'A. Michael'},
#   'familyName': {'en': 'Spence', 'se': 'Spence'},
#   'fullName': {'en': 'A. Michael Spence', 'se': 'A. Michael Spence'},
#   'fileName': 'spence',
#   'gender': 'male',
#   'birth': {'date': '1943-00-00',
#    'place': {'city': {'en': 'Montclair, NJ',
#      'no': 'Montclair, NJ',
#      'se': 'Montclair, NJ'},
#     'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#     'cityNow': {'en': 'Montclair, NJ',
#      'no': 'Montclair, NJ',
#      'se': 'Montclair, NJ',
#      'sameAs': ['https://www.wikidata.org/wiki/Q678437',
#       'https://www.wikipedia.org/wiki/Montclair,_New_Jersey'],
#      'latitude': '40.825930',
#      'longitude': '-74.209030'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Montclair, NJ, USA',
#      'no': 'Montclair, NJ, USA',
#      'se': 'Montclair, NJ, USA'}}},
#   'wikipedia': {'slug': 'Michael_Spence',
#    'english': 'https://en.wikipedia.org/wiki/Michael_Spence'},
#   'wikidata': {'id': 'Q157245',
#    'url': 'https://www.wikidata.org/wiki/Q157245'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q157245',
#    'https://en.wikipedia.org/wiki/Michael_Spence'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/745',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/745',
#     'title': 'A. Michael Spence - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2001',
#     'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#     'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#      'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#      'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#     'sortOrder': '2',
#     'portion': '1/3',
#     'dateAwarded': '2001-10-10',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their analyses of markets with asymmetric information',
#      'se': 'för deras analys av marknader med assymetrisk informations'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 15547541,
#     'affiliations': [{'name': {'en': 'Stanford University',
#        'no': 'Stanford University',
#        'se': 'Stanford University'},
#       'nameNow': {'en': 'Stanford University'},
#       'city': {'en': 'Stanford, CA',
#        'no': 'Stanford, CA',
#        'se': 'Stanford, CA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Stanford, CA',
#        'no': 'Stanford, CA',
#        'se': 'Stanford, CA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q173813',
#         'https://www.wikipedia.org/wiki/Stanford,_California'],
#        'latitude': '37.424734',
#        'longitude': '-122.163858'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Stanford, CA, USA',
#        'no': 'Stanford, CA, USA',
#        'se': 'Stanford, CA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2001',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/spence/facts/',
#       'title': 'A. Michael Spence - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2001/summary/',
#       'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2001',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '102',
#   'knownName': {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'},
#   'givenName': {'en': 'Aage N.', 'se': 'Aage N.'},
#   'familyName': {'en': 'Bohr', 'se': 'Bohr'},
#   'fullName': {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bohr'},
#   'fileName': 'bohr',
#   'gender': 'male',
#   'birth': {'date': '1922-06-19',
#    'place': {'city': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn'},
#     'country': {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danmark'},
#     'cityNow': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#       'https://www.wikipedia.org/wiki/Copenhagen'],
#      'latitude': '55.678127',
#      'longitude': '12.572532'},
#     'countryNow': {'en': 'Denmark',
#      'no': 'Danmark',
#      'se': 'Danmark',
#      'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#      'latitude': '56.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Copenhagen, Denmark',
#      'no': 'København, Danmark',
#      'se': 'Köpenhamn, Danmark'}}},
#   'death': {'date': '2009-09-08',
#    'place': {'city': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn'},
#     'country': {'en': 'Denmark',
#      'no': 'Danmark',
#      'se': 'Danmark',
#      'sameAs': 'https://www.wikidata.org/wiki/Q35'},
#     'cityNow': {'en': 'Copenhagen',
#      'no': 'København',
#      'se': 'Köpenhamn',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#       'https://www.wikipedia.org/wiki/Copenhagen'],
#      'latitude': '55.678127',
#      'longitude': '12.572532'},
#     'countryNow': {'en': 'Denmark',
#      'no': 'Danmark',
#      'se': 'Danmark',
#      'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#      'latitude': '56.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Copenhagen, Denmark',
#      'no': 'København, Danmark',
#      'se': 'Köpenhamn, Danmark'}}},
#   'wikipedia': {'slug': 'Aage_Bohr',
#    'english': 'https://en.wikipedia.org/wiki/Aage_Bohr'},
#   'wikidata': {'id': 'Q103854',
#    'url': 'https://www.wikidata.org/wiki/Q103854'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q103854',
#    'https://en.wikipedia.org/wiki/Aage_Bohr'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/102',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/102',
#     'title': 'Aage N. Bohr - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1975',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '1975-10-17',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for the discovery of the connection between collective motion and particle motion in atomic nuclei and the development of the theory of the structure of the atomic nucleus based on this connection',
#      'se': 'för upptäckten av sambandet mellan kollektiva rörelser och partikelrörelser i atomkärnor, samt den därpå baserade utvecklingen av teorien för atomkärnans struktur'},
#     'prizeAmount': 630000,
#     'prizeAmountAdjusted': 4304697,
#     'affiliations': [{'name': {'en': 'Niels Bohr Institute',
#        'no': 'Niels Bohr Institute',
#        'se': 'Niels Bohr Institute'},
#       'nameNow': {'en': 'Niels Bohr Institute'},
#       'city': {'en': 'Copenhagen', 'no': 'København', 'se': 'Köpenhamn'},
#       'country': {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danmark'},
#       'cityNow': {'en': 'Copenhagen',
#        'no': 'København',
#        'se': 'Köpenhamn',
#        'sameAs': ['https://www.wikidata.org/wiki/Q1748',
#         'https://www.wikipedia.org/wiki/Copenhagen'],
#        'latitude': '55.678127',
#        'longitude': '12.572532'},
#       'countryNow': {'en': 'Denmark',
#        'no': 'Danmark',
#        'se': 'Danmark',
#        'sameAs': ['https://www.wikidata.org/wiki/Q35'],
#        'latitude': '56.000000',
#        'longitude': '10.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Copenhagen, Denmark',
#        'no': 'København, Danmark',
#        'se': 'Köpenhamn, Danmark'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1975',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1975/bohr/facts/',
#       'title': 'Aage N. Bohr - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1975/summary/',
#       'title': 'The Nobel Prize in Physics 1975',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '779',
#   'knownName': {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciechanover'},
#   'givenName': {'en': 'Aaron', 'se': 'Aaron'},
#   'familyName': {'en': 'Ciechanover', 'se': 'Ciechanover'},
#   'fullName': {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciechanover'},
#   'fileName': 'ciechanover',
#   'gender': 'male',
#   'birth': {'date': '1947-10-01',
#    'place': {'city': {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'},
#     'country': {'en': 'British Protectorate of Palestine',
#      'no': 'British i Palestina',
#      'se': 'British Protectorate of Palestine'},
#     'cityNow': {'en': 'Haifa',
#      'no': 'Haifa',
#      'se': 'Haifa',
#      'sameAs': ['https://www.wikidata.org/wiki/Q41621',
#       'https://www.wikipedia.org/wiki/Haifa'],
#      'latitude': '32.794421',
#      'longitude': '34.990340'},
#     'countryNow': {'en': 'Israel',
#      'no': 'Israel',
#      'se': 'Israel',
#      'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#      'latitude': '31.000000',
#      'longitude': '35.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Haifa, British Protectorate of Palestine (now Israel)',
#      'no': 'Haifa, British i Palestina (nå Israel)',
#      'se': 'Haifa, British Protectorate of Palestine (nu Israel)'}}},
#   'wikipedia': {'slug': 'Aaron_Ciechanover',
#    'english': 'https://en.wikipedia.org/wiki/Aaron_Ciechanover'},
#   'wikidata': {'id': 'Q233205',
#    'url': 'https://www.wikidata.org/wiki/Q233205'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q233205',
#    'https://en.wikipedia.org/wiki/Aaron_Ciechanover'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/779',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/779',
#     'title': 'Aaron Ciechanover - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2004',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '2004-10-06',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for the discovery of ubiquitin-mediated protein degradation',
#      'se': 'för upptäckten av ubiquitinmedierad proteinnedbrytning'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 14874529,
#     'affiliations': [{'name': {'en': 'Technion - Israel Institute of Technology',
#        'no': 'Technion - Israel Institute of Technology',
#        'se': 'Technion - Israel Institute of Technology'},
#       'nameNow': {'en': 'Technion - Israel Institute of Technology'},
#       'city': {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'},
#       'country': {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'},
#       'cityNow': {'en': 'Haifa',
#        'no': 'Haifa',
#        'se': 'Haifa',
#        'sameAs': ['https://www.wikidata.org/wiki/Q41621',
#         'https://www.wikipedia.org/wiki/Haifa'],
#        'latitude': '32.794421',
#        'longitude': '34.990340'},
#       'countryNow': {'en': 'Israel',
#        'no': 'Israel',
#        'se': 'Israel',
#        'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#        'latitude': '31.000000',
#        'longitude': '35.000000'},
#       'continent': {'en': 'Asia'},
#       'locationString': {'en': 'Haifa, Israel',
#        'no': 'Haifa, Israel',
#        'se': 'Haifa, Israel'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/2004',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2004/ciechanover/facts/',
#       'title': 'Aaron Ciechanover - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2004/summary/',
#       'title': 'The Nobel Prize in Chemistry 2004',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '259',
#   'knownName': {'en': 'Aaron Klug', 'se': 'Aaron Klug'},
#   'givenName': {'en': 'Aaron', 'se': 'Aaron'},
#   'familyName': {'en': 'Klug', 'se': 'Klug'},
#   'fullName': {'en': 'Aaron Klug', 'se': 'Aaron Klug'},
#   'fileName': 'klug',
#   'gender': 'male',
#   'birth': {'date': '1926-08-11',
#    'place': {'city': {'en': 'Zelvas', 'no': 'Zelvas', 'se': 'Zelvas'},
#     'country': {'en': 'Lithuania', 'no': 'Litauen', 'se': 'Litauen'},
#     'cityNow': {'en': 'Zelvas',
#      'no': 'Zelvas',
#      'se': 'Zelvas',
#      'sameAs': ['https://www.wikidata.org/wiki/Q691679',
#       'https://www.wikipedia.org/wiki/%C5%BDelva'],
#      'latitude': '53.148256',
#      'longitude': '24.816515'},
#     'countryNow': {'en': 'Lithuania',
#      'no': 'Litauen',
#      'se': 'Litauen',
#      'sameAs': ['https://www.wikidata.org/wiki/Q37'],
#      'latitude': '55.200000',
#      'longitude': '24.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Zelvas, Lithuania',
#      'no': 'Zelvas, Litauen',
#      'se': 'Zelvas, Litauen'}}},
#   'death': {'date': '2018-11-20',
#    'place': {'locationString': {'en': '', 'no': '', 'se': ''}}},
#   'wikipedia': {'slug': 'Aaron_Klug',
#    'english': 'https://en.wikipedia.org/wiki/Aaron_Klug'},
#   'wikidata': {'id': 'Q190626',
#    'url': 'https://www.wikidata.org/wiki/Q190626'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q190626',
#    'https://en.wikipedia.org/wiki/Aaron_Klug'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/259',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/259',
#     'title': 'Aaron Klug - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1982',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '1982-10-18',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his development of crystallographic electron microscopy and his structural elucidation of biologically important nucleic acid-protein complexes',
#      'se': 'för hans utveckling av kristallografisk elektronmikroskopi och hans klarläggande av strukturen hos biologiskt viktiga nukleinsyra-proteinkomplex'},
#     'prizeAmount': 1150000,
#     'prizeAmountAdjusted': 3923237,
#     'affiliations': [{'name': {'en': 'MRC Laboratory of Molecular Biology',
#        'no': 'MRC Laboratory of Molecular Biology',
#        'se': 'MRC Laboratory of Molecular Biology'},
#       'nameNow': {'en': 'MRC Laboratory of Molecular Biology'},
#       'city': {'en': 'Cambridge', 'no': 'Cambridge', 'se': 'Cambridge'},
#       'country': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien'},
#       'cityNow': {'en': 'Cambridge',
#        'no': 'Cambridge',
#        'se': 'Cambridge',
#        'sameAs': ['https://www.wikidata.org/wiki/Q350',
#         'https://www.wikipedia.org/wiki/Cambridge'],
#        'latitude': '52.194605',
#        'longitude': '0.135092'},
#       'countryNow': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#        'latitude': '54.600000',
#        'longitude': '-2.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Cambridge, United Kingdom',
#        'no': 'Cambridge, Storbritannia',
#        'se': 'Cambridge, Storbritannien'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/1982',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/1982/klug/facts/',
#       'title': 'Aaron Klug - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/1982/summary/',
#       'title': 'The Nobel Prize in Chemistry 1982',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '1004',
#   'knownName': {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak Gurnah'},
#   'givenName': {'en': 'Abdulrazak', 'se': 'Abdulrazak'},
#   'familyName': {'en': 'Gurnah', 'se': 'Gurnah'},
#   'fullName': {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak Gurnah'},
#   'fileName': 'gurnah',
#   'gender': 'male',
#   'birth': {'date': '1948-00-00'},
#   'wikipedia': {'slug': 'Abdulrazak_Gurnah',
#    'english': 'https://en.wikipedia.org/wiki/Abdulrazak_Gurnah'},
#   'wikidata': {'id': 'Q317877',
#    'url': 'https://www.wikidata.org/wiki/Q317877'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q317877',
#    'https://en.wikipedia.org/wiki/Abdulrazak_Gurnah'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/1004',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/1004',
#     'title': 'Abdulrazak Gurnah - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2021',
#     'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'},
#     'categoryFullName': {'en': 'The Nobel Prize in Literature',
#      'no': 'Nobelprisen i litteratur',
#      'se': 'Nobelpriset i litteratur'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '2021-10-07',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his uncompromising and compassionate penetration of the effects of colonialism and the fate of the refugee in the gulf between cultures and continents'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 12096939,
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/lit/2021',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/2021/gurnah/facts/',
#       'title': 'Abdulrazak Gurnah - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/2021/summary/',
#       'title': 'The Nobel Prize in Literature 2021',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '114',
#   'knownName': {'en': 'Abdus Salam', 'se': 'Abdus Salam'},
#   'givenName': {'en': 'Abdus', 'se': 'Abdus'},
#   'familyName': {'en': 'Salam', 'se': 'Salam'},
#   'fullName': {'en': 'Abdus Salam', 'se': 'Abdus Salam'},
#   'fileName': 'salam',
#   'gender': 'male',
#   'birth': {'date': '1926-01-29',
#    'place': {'city': {'en': 'Jhang Maghiāna',
#      'no': 'Jhang Maghiāna',
#      'se': 'Jhang Maghiāna'},
#     'country': {'en': 'India', 'no': 'India', 'se': 'Indien'},
#     'cityNow': {'en': 'Jhang Maghiāna',
#      'no': 'Jhang Maghiāna',
#      'se': 'Jhang Maghiāna',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1026616',
#       'https://www.wikipedia.org/wiki/Jhang'],
#      'latitude': '31.268056',
#      'longitude': '72.318056'},
#     'countryNow': {'en': 'Pakistan',
#      'no': 'Pakistan',
#      'se': 'Pakistan',
#      'sameAs': ['https://www.wikidata.org/wiki/Q843'],
#      'latitude': '30.000000',
#      'longitude': '71.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Jhang Maghiāna, India (now Pakistan)',
#      'no': 'Jhang Maghiāna, India (nå Pakistan)',
#      'se': 'Jhang Maghiāna, Indien (nu Pakistan)'}}},
#   'death': {'date': '1996-11-21',
#    'place': {'city': {'en': 'Oxford', 'no': 'Oxford', 'se': 'Oxford'},
#     'country': {'en': 'United Kingdom',
#      'no': 'Storbritannia',
#      'se': 'Storbritannien',
#      'sameAs': 'https://www.wikidata.org/wiki/Q145'},
#     'cityNow': {'en': 'Oxford',
#      'no': 'Oxford',
#      'se': 'Oxford',
#      'sameAs': ['https://www.wikidata.org/wiki/Q34217',
#       'https://www.wikipedia.org/wiki/Oxford'],
#      'latitude': '51.753363',
#      'longitude': '-1.260979'},
#     'countryNow': {'en': 'United Kingdom',
#      'no': 'Storbritannia',
#      'se': 'Storbritannien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#      'latitude': '54.600000',
#      'longitude': '-2.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Oxford, United Kingdom',
#      'no': 'Oxford, Storbritannia',
#      'se': 'Oxford, Storbritannien'}}},
#   'wikipedia': {'slug': 'Abdus_Salam',
#    'english': 'https://en.wikipedia.org/wiki/Abdus_Salam'},
#   'wikidata': {'id': 'Q28189', 'url': 'https://www.wikidata.org/wiki/Q28189'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q28189',
#    'https://en.wikipedia.org/wiki/Abdus_Salam'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/114',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/114',
#     'title': 'Abdus Salam - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1979',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '2',
#     'portion': '1/3',
#     'dateAwarded': '1979-10-15',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their contributions to the theory of the unified weak and electromagnetic interaction between elementary particles, including, inter alia, the prediction of the weak neutral current',
#      'se': 'för deras insatser inom teorin för förenad svag och elektromagnetisk växelverkan mellan elementar partiklar, innefattande bl.a. förutsägelsen av den svaga neutrala strömmen'},
#     'prizeAmount': 800000,
#     'prizeAmountAdjusted': 3778486,
#     'affiliations': [{'name': {'en': 'International Centre for Theoretical Physics',
#        'no': 'International Centre for Theoretical Physics',
#        'se': 'International Centre for Theoretical Physics'},
#       'nameNow': {'en': 'International Centre for Theoretical Physics'},
#       'city': {'en': 'Trieste', 'no': 'Trieste', 'se': 'Trieste'},
#       'country': {'en': 'Italy', 'no': 'Italia', 'se': 'Italien'},
#       'cityNow': {'en': 'Trieste',
#        'no': 'Trieste',
#        'se': 'Trieste',
#        'sameAs': ['https://www.wikidata.org/wiki/Q546',
#         'https://www.wikipedia.org/wiki/Trieste'],
#        'latitude': '45.649433',
#        'longitude': '13.776623'},
#       'countryNow': {'en': 'Italy',
#        'no': 'Italia',
#        'se': 'Italien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q38'],
#        'latitude': '42.500000',
#        'longitude': '12.500000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Trieste, Italy',
#        'no': 'Trieste, Italia',
#        'se': 'Trieste, Italien'}},
#      {'name': {'en': 'Imperial College',
#        'no': 'Imperial College',
#        'se': 'Imperial College'},
#       'nameNow': {'en': 'Imperial College'},
#       'city': {'en': 'London', 'no': 'London', 'se': 'London'},
#       'country': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien'},
#       'cityNow': {'en': 'London',
#        'no': 'London',
#        'se': 'London',
#        'sameAs': ['https://www.wikidata.org/wiki/Q84',
#         'https://www.wikipedia.org/wiki/London'],
#        'latitude': '51.510235',
#        'longitude': '-0.120852'},
#       'countryNow': {'en': 'United Kingdom',
#        'no': 'Storbritannia',
#        'se': 'Storbritannien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q145'],
#        'latitude': '54.600000',
#        'longitude': '-2.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'London, United Kingdom',
#        'no': 'London, Storbritannia',
#        'se': 'London, Storbritannien'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1979',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1979/salam/facts/',
#       'title': 'Abdus Salam - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1979/summary/',
#       'title': 'The Nobel Prize in Physics 1979',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '982',
#   'knownName': {'en': 'Abhijit Banerjee', 'se': 'Abhijit Banerjee'},
#   'givenName': {'en': 'Abhijit', 'se': 'Abhijit'},
#   'familyName': {'en': 'Banerjee', 'se': 'Banerjee'},
#   'fullName': {'en': 'Abhijit Banerjee', 'se': 'Abhijit Banerjee'},
#   'fileName': 'banerjee',
#   'gender': 'male',
#   'birth': {'date': '1961-02-21',
#    'place': {'city': {'en': 'Mumbai', 'no': 'Mumbai', 'se': 'Mumbai'},
#     'country': {'en': 'India', 'no': 'India', 'se': 'Indien'},
#     'cityNow': {'en': 'Mumbai',
#      'no': 'Mumbai',
#      'se': 'Mumbai',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1156',
#       'https://www.wikipedia.org/wiki/Mumbai'],
#      'latitude': '19.075833',
#      'longitude': '72.877500'},
#     'countryNow': {'en': 'India',
#      'no': 'India',
#      'se': 'Indien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q668'],
#      'latitude': '22.800000',
#      'longitude': '83.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Mumbai, India',
#      'no': 'Mumbai, India',
#      'se': 'Mumbai, Indien'}}},
#   'wikipedia': {'slug': 'Abhijit_Banerjee',
#    'english': 'https://en.wikipedia.org/wiki/Abhijit_Banerjee'},
#   'wikidata': {'id': 'Q320578',
#    'url': 'https://www.wikidata.org/wiki/Q320578'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q320578',
#    'https://en.wikipedia.org/wiki/Abhijit_Banerjee'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/982',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/982',
#     'title': 'Abhijit Banerjee - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2019',
#     'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'},
#     'categoryFullName': {'en': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#      'no': 'Sveriges Riksbanks pris i økonomisk vitenskap til minne om Alfred Nobel',
#      'se': 'Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '2019-10-14',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their experimental approach to alleviating global poverty',
#      'se': 'för deras experimentella ansats för att mildra global fattigdom'},
#     'prizeAmount': 9000000,
#     'prizeAmountAdjusted': 11178104,
#     'affiliations': [{'name': {'en': 'Massachusetts Institute of Technology (MIT)',
#        'no': 'Massachusetts Institute of Technology (MIT)',
#        'se': 'Massachusetts Institute of Technology (MIT)'},
#       'nameNow': {'en': 'Massachusetts Institute of Technology (MIT)'},
#       'city': {'en': 'Cambridge, MA',
#        'no': 'Cambridge, MA',
#        'se': 'Cambridge, MA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Cambridge, MA',
#        'no': 'Cambridge, MA',
#        'se': 'Cambridge, MA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q49111',
#         'https://www.wikipedia.org/wiki/Cambridge,_Massachusetts'],
#        'latitude': '42.374024',
#        'longitude': '-71.107306'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Cambridge, MA, USA',
#        'no': 'Cambridge, MA, USA',
#        'se': 'Cambridge, MA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/eco/2019',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2019/banerjee/facts/',
#       'title': 'Abhijit Banerjee - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/economic-sciences/2019/summary/',
#       'title': 'The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2019',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '981',
#   'knownName': {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'},
#   'givenName': {'en': 'Abiy', 'se': 'Abiy'},
#   'familyName': {'en': 'Ahmed Ali', 'se': 'Ahmed Ali'},
#   'fullName': {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'},
#   'fileName': 'abiy',
#   'gender': 'male',
#   'birth': {'date': '1976-08-15',
#    'place': {'city': {'en': 'Beshasha', 'no': 'Beshasha', 'se': 'Beshasha'},
#     'country': {'en': 'Ethiopia', 'no': 'Etiopia', 'se': 'Etiopien'},
#     'cityNow': {'en': 'Beshasha',
#      'no': 'Beshasha',
#      'se': 'Beshasha',
#      'sameAs': ['https://www.wikidata.org/wiki/Q2899862',
#       'https://www.wikipedia.org/wiki/Beshasha'],
#      'latitude': '7.795864',
#      'longitude': '36.477062'},
#     'countryNow': {'en': 'Ethiopia',
#      'no': 'Etiopia',
#      'se': 'Etiopien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q115'],
#      'latitude': '9.000000',
#      'longitude': '40.000000'},
#     'continent': {'en': 'Africa', 'no': 'Afrika', 'se': 'Afrika'},
#     'locationString': {'en': 'Beshasha, Ethiopia',
#      'no': 'Beshasha, Etiopia',
#      'se': 'Beshasha, Etiopien'}}},
#   'wikipedia': {'slug': 'Abiy_Ahmed',
#    'english': 'https://en.wikipedia.org/wiki/Abiy_Ahmed'},
#   'wikidata': {'id': 'Q50365049',
#    'url': 'https://www.wikidata.org/wiki/Q50365049'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q50365049',
#    'https://en.wikipedia.org/wiki/Abiy_Ahmed'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/981',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/981',
#     'title': 'Abiy Ahmed Ali - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2019',
#     'category': {'en': 'Peace', 'no': 'Fred', 'se': 'Fred'},
#     'categoryFullName': {'en': 'The Nobel Peace Prize',
#      'no': 'Nobels fredspris',
#      'se': 'Nobels fredspris'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '2019-10-11',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his efforts to achieve peace and international cooperation, and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea',
#      'no': 'for hans innsats for fred og mellomstatlig samarbeid, og da særlig for hans avgjørande initiativ for å løsa grensekonflikten med nabolandet Eritrea'},
#     'prizeAmount': 9000000,
#     'prizeAmountAdjusted': 11178104,
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/pea/2019',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/peace/2019/abiy/facts/',
#       'title': 'Abiy Ahmed Ali - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/peace/2019/summary/',
#       'title': 'The Nobel Peace Prize 2019',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '843',
#   'knownName': {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'},
#   'givenName': {'en': 'Ada E.', 'se': 'Ada E.'},
#   'familyName': {'en': 'Yonath', 'se': 'Yonath'},
#   'fullName': {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'},
#   'fileName': 'yonath',
#   'gender': 'female',
#   'birth': {'date': '1939-06-22',
#    'place': {'city': {'en': 'Jerusalem', 'no': 'Jerusalem', 'se': 'Jerusalem'},
#     'country': {'en': 'British Mandate of Palestine',
#      'no': 'Palestinamandatet',
#      'se': 'Brittiska Palestinamandatet'},
#     'cityNow': {'en': 'Jerusalem',
#      'no': 'Jerusalem',
#      'se': 'Jerusalem',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1218',
#       'https://www.wikipedia.org/wiki/Jerusalem'],
#      'latitude': '31.767983',
#      'longitude': '35.213809'},
#     'countryNow': {'en': 'Israel',
#      'no': 'Israel',
#      'se': 'Israel',
#      'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#      'latitude': '31.000000',
#      'longitude': '35.000000'},
#     'continent': {'en': 'Asia', 'no': 'Asia', 'se': 'Asien'},
#     'locationString': {'en': 'Jerusalem, British Mandate of Palestine (now Israel)',
#      'no': 'Jerusalem, Palestinamandatet (nå Israel)',
#      'se': 'Jerusalem, Brittiska Palestinamandatet (nu Israel)'}}},
#   'wikipedia': {'slug': 'Ada_Yonath',
#    'english': 'https://en.wikipedia.org/wiki/Ada_Yonath'},
#   'wikidata': {'id': 'Q7426', 'url': 'https://www.wikidata.org/wiki/Q7426'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q7426',
#    'https://en.wikipedia.org/wiki/Ada_Yonath'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/843',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/843',
#     'title': 'Ada E. Yonath - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2009',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '3',
#     'portion': '1/3',
#     'dateAwarded': '2009-10-07',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for studies of the structure and function of the ribosome',
#      'se': 'för studier av ribosomens struktur och funktion'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 13857393,
#     'affiliations': [{'name': {'en': 'Weizmann Institute of Science',
#        'no': 'Weizmann Institute of Science',
#        'se': 'Weizmann Institute of Science'},
#       'nameNow': {'en': 'Weizmann Institute of Science'},
#       'city': {'en': 'Rehovot', 'no': 'Rehovot', 'se': 'Rehovot'},
#       'country': {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'},
#       'cityNow': {'en': 'Rehovot',
#        'no': 'Rehovot',
#        'se': 'Rehovot',
#        'sameAs': ['https://www.wikidata.org/wiki/Q207350',
#         'https://www.wikipedia.org/wiki/Rehovot'],
#        'latitude': '31.892773',
#        'longitude': '34.811272'},
#       'countryNow': {'en': 'Israel',
#        'no': 'Israel',
#        'se': 'Israel',
#        'sameAs': ['https://www.wikidata.org/wiki/Q801'],
#        'latitude': '31.000000',
#        'longitude': '35.000000'},
#       'continent': {'en': 'Asia'},
#       'locationString': {'en': 'Rehovot, Israel',
#        'no': 'Rehovot, Israel',
#        'se': 'Rehovot, Israel'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/2009',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2009/yonath/facts/',
#       'title': 'Ada E. Yonath - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2009/summary/',
#       'title': 'The Nobel Prize in Chemistry 2009',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '866',
#   'knownName': {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'},
#   'givenName': {'en': 'Adam G.', 'se': 'Adam G.'},
#   'familyName': {'en': 'Riess', 'se': 'Riess'},
#   'fullName': {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'},
#   'fileName': 'riess',
#   'gender': 'male',
#   'birth': {'date': '1969-12-16',
#    'place': {'city': {'en': 'Washington, D.C.',
#      'no': 'Washington, D.C.',
#      'se': 'Washington, D.C.'},
#     'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#     'cityNow': {'en': 'Washington, D.C.',
#      'no': 'Washington, D.C.',
#      'se': 'Washington, D.C.',
#      'sameAs': ['https://www.wikidata.org/wiki/Q61',
#       'https://www.wikipedia.org/wiki/Washington,_D.C.'],
#      'latitude': '38.899065',
#      'longitude': '-77.036523'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Washington, D.C., USA',
#      'no': 'Washington, D.C., USA',
#      'se': 'Washington, D.C., USA'}}},
#   'wikipedia': {'slug': 'Adam_Riess',
#    'english': 'https://en.wikipedia.org/wiki/Adam_Riess'},
#   'wikidata': {'id': 'Q106454',
#    'url': 'https://www.wikidata.org/wiki/Q106454'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q106454',
#    'https://en.wikipedia.org/wiki/Adam_Riess'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/866',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/866',
#     'title': 'Adam G. Riess - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '2011',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '3',
#     'portion': '1/4',
#     'dateAwarded': '2011-10-04',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for the discovery of the accelerating expansion of the Universe through observations of distant supernovae',
#      'se': 'för upptäckten av universums accelererande expansion genom observationer av avlägsna supernovor'},
#     'prizeAmount': 10000000,
#     'prizeAmountAdjusted': 13335208,
#     'affiliations': [{'name': {'en': 'Johns Hopkins University',
#        'no': 'Johns Hopkins University',
#        'se': 'Johns Hopkins University'},
#       'nameNow': {'en': 'Johns Hopkins University'},
#       'city': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD',
#        'sameAs': ['https://www.wikidata.org/wiki/Q5092',
#         'https://www.wikipedia.org/wiki/Baltimore'],
#        'latitude': '39.291586',
#        'longitude': '-76.625305'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Baltimore, MD, USA',
#        'no': 'Baltimore, MD, USA',
#        'se': 'Baltimore, MD, USA'}},
#      {'name': {'en': 'Space Telescope Science Institute',
#        'no': 'Space Telescope Science Institute',
#        'se': 'Space Telescope Science Institute'},
#       'nameNow': {'en': 'Space Telescope Science Institute'},
#       'city': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Baltimore, MD',
#        'no': 'Baltimore, MD',
#        'se': 'Baltimore, MD',
#        'sameAs': ['https://www.wikidata.org/wiki/Q5092',
#         'https://www.wikipedia.org/wiki/Baltimore'],
#        'latitude': '39.291586',
#        'longitude': '-76.625305'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Baltimore, MD, USA',
#        'no': 'Baltimore, MD, USA',
#        'se': 'Baltimore, MD, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/2011',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/2011/riess/facts/',
#       'title': 'Adam G. Riess - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/2011/summary/',
#       'title': 'The Nobel Prize in Physics 2011',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '199',
#   'knownName': {'en': 'Adolf Butenandt', 'se': 'Adolf Butenandt'},
#   'givenName': {'en': 'Adolf', 'se': 'Adolf'},
#   'familyName': {'en': 'Butenandt', 'se': 'Butenandt'},
#   'fullName': {'en': 'Adolf Friedrich Johann Butenandt',
#    'se': 'Adolf Friedrich Johann Butenandt'},
#   'fileName': 'butenandt',
#   'gender': 'male',
#   'birth': {'date': '1903-03-24',
#    'place': {'city': {'en': 'Bremerhaven-Lehe',
#      'no': 'Bremerhaven-Lehe',
#      'se': 'Bremerhaven-Lehe'},
#     'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#     'cityNow': {'en': 'Bremerhaven-Lehe',
#      'no': 'Bremerhaven-Lehe',
#      'se': 'Bremerhaven-Lehe',
#      'sameAs': ['https://www.wikidata.org/wiki/Q2706',
#       'https://www.wikipedia.org/wiki/Bremerhaven'],
#      'latitude': '53.550000',
#      'longitude': '8.583333'},
#     'countryNow': {'en': 'Germany',
#      'no': 'Tyskland',
#      'se': 'Tyskland',
#      'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#      'latitude': '51.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Bremerhaven-Lehe, Germany',
#      'no': 'Bremerhaven-Lehe, Tyskland',
#      'se': 'Bremerhaven-Lehe, Tyskland'}}},
#   'death': {'date': '1995-01-18',
#    'place': {'city': {'en': 'Munich', 'no': 'München', 'se': 'München'},
#     'country': {'en': 'Germany',
#      'no': 'Tyskland',
#      'se': 'Tyskland',
#      'sameAs': 'https://www.wikidata.org/wiki/Q183'},
#     'cityNow': {'en': 'Munich',
#      'no': 'München',
#      'se': 'München',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1726',
#       'https://www.wikipedia.org/wiki/Munich'],
#      'latitude': '48.134703',
#      'longitude': '11.581995'},
#     'countryNow': {'en': 'Germany',
#      'no': 'Tyskland',
#      'se': 'Tyskland',
#      'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#      'latitude': '51.000000',
#      'longitude': '10.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Munich, Germany',
#      'no': 'München, Tyskland',
#      'se': 'München, Tyskland'}}},
#   'wikipedia': {'slug': 'Adolf_Butenandt',
#    'english': 'https://en.wikipedia.org/wiki/Adolf_Butenandt'},
#   'wikidata': {'id': 'Q5327', 'url': 'https://www.wikidata.org/wiki/Q5327'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q5327',
#    'https://en.wikipedia.org/wiki/Adolf_Butenandt'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/199',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/199',
#     'title': 'Adolf Butenandt - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1939',
#     'category': {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'},
#     'categoryFullName': {'en': 'The Nobel Prize in Chemistry',
#      'no': 'Nobelprisen i kjemi',
#      'se': 'Nobelpriset i kemi'},
#     'sortOrder': '1',
#     'portion': '1/2',
#     'dateAwarded': '1939-11-09',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his work on sex hormones',
#      'se': 'för hans arbeten över sexualhormoner'},
#     'prizeAmount': 148822,
#     'prizeAmountAdjusted': 5346318,
#     'affiliations': [{'name': {'en': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#        'no': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie',
#        'se': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie'},
#       'nameNow': {'en': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Biochemie'},
#       'city': {'en': 'Berlin-Dahlem',
#        'no': 'Berlin-Dahlem',
#        'se': 'Berlin-Dahlem'},
#       'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#       'cityNow': {'en': 'Berlin-Dahlem',
#        'no': 'Berlin-Dahlem',
#        'se': 'Berlin-Dahlem',
#        'sameAs': ['https://www.wikidata.org/wiki/Q700541',
#         'https://www.wikipedia.org/wiki/Dahlem_(Berlin)'],
#        'latitude': '52.453739',
#        'longitude': '13.293130'},
#       'countryNow': {'en': 'Germany',
#        'no': 'Tyskland',
#        'se': 'Tyskland',
#        'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#        'latitude': '51.000000',
#        'longitude': '10.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Berlin-Dahlem, Germany',
#        'no': 'Berlin-Dahlem, Tyskland',
#        'se': 'Berlin-Dahlem, Tyskland'}},
#      {'name': {'en': 'Berlin University',
#        'no': 'Berlin University',
#        'se': 'Berlin University'},
#       'nameNow': {'en': 'Berlin University'},
#       'city': {'en': 'Berlin', 'no': 'Berlin', 'se': 'Berlin'},
#       'country': {'en': 'Germany', 'no': 'Tyskland', 'se': 'Tyskland'},
#       'cityNow': {'en': 'Berlin',
#        'no': 'Berlin',
#        'se': 'Berlin',
#        'sameAs': ['https://www.wikidata.org/wiki/Q64',
#         'https://www.wikipedia.org/wiki/Berlin'],
#        'latitude': '52.522265',
#        'longitude': '13.406852'},
#       'countryNow': {'en': 'Germany',
#        'no': 'Tyskland',
#        'se': 'Tyskland',
#        'sameAs': ['https://www.wikidata.org/wiki/Q183'],
#        'latitude': '51.000000',
#        'longitude': '10.000000'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Berlin, Germany',
#        'no': 'Berlin, Tyskland',
#        'se': 'Berlin, Tyskland'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/1939',
# ...
#      'se': 'för upptäckten och utvecklandet av ledande polymerer'},
#     'prizeAmount': 9000000,
#     'prizeAmountAdjusted': 14331095,
#     'affiliations': [{'name': {'en': 'University of Pennsylvania',
#        'no': 'University of Pennsylvania',
#        'se': 'University of Pennsylvania'},
#       'nameNow': {'en': 'University of Pennsylvania'},
#       'city': {'en': 'Philadelphia, PA',
#        'no': 'Philadelphia, PA',
#        'se': 'Philadelphia, PA'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Philadelphia, PA',
#        'no': 'Philadelphia, PA',
#        'se': 'Philadelphia, PA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q1345',
#         'https://www.wikipedia.org/wiki/Philadelphia'],
#        'latitude': '39.957132',
#        'longitude': '-75.174342'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Philadelphia, PA, USA',
#        'no': 'Philadelphia, PA, USA',
#        'se': 'Philadelphia, PA, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/che/2000',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2000/macdiarmid/facts/',
#       'title': 'Alan MacDiarmid - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/chemistry/2000/summary/',
#       'title': 'The Nobel Prize in Chemistry 2000',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '11',
#   'knownName': {'en': 'Albert A. Michelson', 'se': 'Albert A. Michelson'},
#   'givenName': {'en': 'Albert A.', 'se': 'Albert A.'},
#   'familyName': {'en': 'Michelson', 'se': 'Michelson'},
#   'fullName': {'en': 'Albert Abraham Michelson',
#    'se': 'Albert Abraham Michelson'},
#   'fileName': 'michelson',
#   'gender': 'male',
#   'birth': {'date': '1852-12-19',
#    'place': {'city': {'en': 'Strelno', 'no': 'Strelno', 'se': 'Strelno'},
#     'country': {'en': 'Prussia', 'no': 'Preussen', 'se': 'Preussen'},
#     'cityNow': {'en': 'Strzelno',
#      'no': 'Strzelno',
#      'se': 'Strzelno',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1005414',
#       'https://www.wikipedia.org/wiki/Strzelno'],
#      'latitude': '52.629444',
#      'longitude': '18.170000'},
#     'countryNow': {'en': 'Poland',
#      'no': 'Polen',
#      'se': 'Polen',
#      'sameAs': ['https://www.wikidata.org/wiki/Q36'],
#      'latitude': '52.000000',
#      'longitude': '19.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Strelno, Prussia (now Strzelno, Poland)',
#      'no': 'Strelno, Preussen (nå Strzelno, Polen)',
#      'se': 'Strelno, Preussen (nu Strzelno, Polen)'}}},
#   'death': {'date': '1931-05-09',
#    'place': {'city': {'en': 'Pasadena, CA',
#      'no': 'Pasadena, CA',
#      'se': 'Pasadena, CA'},
#     'country': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': 'https://www.wikidata.org/wiki/Q30'},
#     'cityNow': {'en': 'Pasadena, CA',
#      'no': 'Pasadena, CA',
#      'se': 'Pasadena, CA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q485176',
#       'https://www.wikipedia.org/wiki/Pasadena,_California'],
#      'latitude': '34.150071',
#      'longitude': '-118.142111'},
#     'countryNow': {'en': 'USA',
#      'no': 'USA',
#      'se': 'USA',
#      'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#      'latitude': '39.828175',
#      'longitude': '-98.579500'},
#     'continent': {'en': 'North America',
#      'no': 'Nord-Amerika',
#      'se': 'Nordamerika'},
#     'locationString': {'en': 'Pasadena, CA, USA',
#      'no': 'Pasadena, CA, USA',
#      'se': 'Pasadena, CA, USA'}}},
#   'wikipedia': {'slug': 'Albert_Abraham_Michelson',
#    'english': 'https://en.wikipedia.org/wiki/Albert_Abraham_Michelson'},
#   'wikidata': {'id': 'Q127234',
#    'url': 'https://www.wikidata.org/wiki/Q127234'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q127234',
#    'https://en.wikipedia.org/wiki/Albert_Abraham_Michelson'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/11',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/11',
#     'title': 'Albert A. Michelson - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1907',
#     'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physics',
#      'no': 'Nobelprisen i fysikk',
#      'se': 'Nobelpriset i fysik'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '1907-11-12',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his optical precision instruments and the spectroscopic and metrological investigations carried out with their aid',
#      'se': 'för hans optiska precisionsinstrument och hans därmed utförda spektroskopiska och metrologiska undersökningar'},
#     'prizeAmount': 138796,
#     'prizeAmountAdjusted': 8894198,
#     'affiliations': [{'name': {'en': 'University of Chicago',
#        'no': 'University of Chicago',
#        'se': 'University of Chicago'},
#       'nameNow': {'en': 'University of Chicago'},
#       'city': {'en': 'Chicago, IL', 'no': 'Chicago, IL', 'se': 'Chicago, IL'},
#       'country': {'en': 'USA', 'no': 'USA', 'se': 'USA'},
#       'cityNow': {'en': 'Chicago, IL',
#        'no': 'Chicago, IL',
#        'se': 'Chicago, IL',
#        'sameAs': ['https://www.wikidata.org/wiki/Q1297',
#         'https://www.wikipedia.org/wiki/Chicago'],
#        'latitude': '41.876228',
#        'longitude': '-87.638416'},
#       'countryNow': {'en': 'USA',
#        'no': 'USA',
#        'se': 'USA',
#        'sameAs': ['https://www.wikidata.org/wiki/Q30'],
#        'latitude': '39.828175',
#        'longitude': '-98.579500'},
#       'continent': {'en': 'North America'},
#       'locationString': {'en': 'Chicago, IL, USA',
#        'no': 'Chicago, IL, USA',
#        'se': 'Chicago, IL, USA'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/phy/1907',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1907/michelson/facts/',
#       'title': 'Albert A. Michelson - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/physics/1907/summary/',
#       'title': 'The Nobel Prize in Physics 1907',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '628',
#   'knownName': {'en': 'Albert Camus', 'se': 'Albert Camus'},
#   'givenName': {'en': 'Albert', 'se': 'Albert'},
#   'familyName': {'en': 'Camus', 'se': 'Camus'},
#   'fullName': {'en': 'Albert Camus', 'se': 'Albert Camus'},
#   'fileName': 'camus',
#   'gender': 'male',
#   'birth': {'date': '1913-11-07',
#    'place': {'city': {'en': 'Mondovi', 'no': 'Mondovi', 'se': 'Mondovi'},
#     'country': {'en': 'French Algeria',
#      'no': 'fransk Algerie',
#      'se': 'Franska Algeriet'},
#     'cityNow': {'en': 'Mondovi',
#      'no': 'Mondovi',
#      'se': 'Mondovi',
#      'sameAs': ['https://www.wikidata.org/wiki/Q1924629',
#       'https://www.wikipedia.org/wiki/Dr%C3%A9an'],
#      'latitude': '44.395064',
#      'longitude': '7.819452'},
#     'countryNow': {'en': 'Algeria',
#      'no': 'Algerie',
#      'se': 'Algeriet',
#      'sameAs': ['https://www.wikidata.org/wiki/Q262'],
#      'latitude': '28.000000',
#      'longitude': '1.000000'},
#     'continent': {'en': 'Africa', 'no': 'Afrika', 'se': 'Afrika'},
#     'locationString': {'en': 'Mondovi, French Algeria (now Algeria)',
#      'no': 'Mondovi, fransk Algerie (nå Algerie)',
#      'se': 'Mondovi, Franska Algeriet (nu Algeriet)'}}},
#   'death': {'date': '1960-01-04',
#    'place': {'city': {'en': 'Sens', 'no': 'Sens', 'se': 'Sens'},
#     'country': {'en': 'France',
#      'no': 'Frankrike',
#      'se': 'Frankrike',
#      'sameAs': 'https://www.wikidata.org/wiki/Q142'},
#     'cityNow': {'en': 'Sens',
#      'no': 'Sens',
#      'se': 'Sens',
#      'sameAs': ['https://www.wikidata.org/wiki/Q212420',
#       'https://www.wikipedia.org/wiki/Sens'],
#      'latitude': '48.197222',
#      'longitude': '3.283333'},
#     'countryNow': {'en': 'France',
#      'no': 'Frankrike',
#      'se': 'Frankrike',
#      'sameAs': ['https://www.wikidata.org/wiki/Q142'],
#      'latitude': '47.000000',
#      'longitude': '2.000000'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Sens, France',
#      'no': 'Sens, Frankrike',
#      'se': 'Sens, Frankrike'}}},
#   'wikipedia': {'slug': 'Albert_Camus',
#    'english': 'https://en.wikipedia.org/wiki/Albert_Camus'},
#   'wikidata': {'id': 'Q34670', 'url': 'https://www.wikidata.org/wiki/Q34670'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q34670',
#    'https://en.wikipedia.org/wiki/Albert_Camus'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/628',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/628',
#     'title': 'Albert Camus - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1957',
#     'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'},
#     'categoryFullName': {'en': 'The Nobel Prize in Literature',
#      'no': 'Nobelprisen i litteratur',
#      'se': 'Nobelpriset i litteratur'},
#     'sortOrder': '1',
#     'portion': '1',
#     'dateAwarded': '1957-10-17',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for his important literary production, which with clear-sighted earnestness illuminates the problems of the human conscience in our times',
#      'se': 'för hans betydelsefulla författarskap, som med skarpsynt allvar belyser mänskliga samvetsproblem i vår tid'},
#     'prizeAmount': 208629,
#     'prizeAmountAdjusted': 3411444,
#     'residences': [{'country': {'en': 'France',
#        'no': 'Frankrike',
#        'se': 'Frankrike'},
#       'countryNow': {'en': 'France', 'no': 'Frankrike', 'se': 'Frankrike'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'France',
#        'no': 'Frankrike',
#        'se': 'Frankrike'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/lit/1957',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/1957/camus/facts/',
#       'title': 'Albert Camus - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/literature/1957/summary/',
#       'title': 'The Nobel Prize in Literature 1957',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]},
#  {'id': '403',
#   'knownName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#   'givenName': {'en': 'Albert', 'se': 'Albert'},
#   'familyName': {'en': 'Claude', 'se': 'Claude'},
#   'fullName': {'en': 'Albert Claude', 'se': 'Albert Claude'},
#   'fileName': 'claude',
#   'gender': 'male',
#   'birth': {'date': '1898-08-24',
#    'place': {'city': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#     'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#     'cityNow': {'en': 'Longlier', 'no': 'Longlier', 'se': 'Longlier'},
#     'countryNow': {'en': 'Belgium',
#      'no': 'Belgia',
#      'se': 'Belgien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#      'latitude': '50.641111',
#      'longitude': '4.668056'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Longlier, Belgium',
#      'no': 'Longlier, Belgia',
#      'se': 'Longlier, Belgien'}}},
#   'death': {'date': '1983-05-22',
#    'place': {'city': {'en': 'Brussels', 'no': 'Brussel', 'se': 'Bryssel'},
#     'country': {'en': 'Belgium',
#      'no': 'Belgia',
#      'se': 'Belgien',
#      'sameAs': 'https://www.wikidata.org/wiki/Q31'},
#     'cityNow': {'en': 'Brussels',
#      'no': 'Brussel',
#      'se': 'Bryssel',
#      'sameAs': ['https://www.wikidata.org/wiki/Q239',
#       'https://www.wikipedia.org/wiki/City_of_Brussels'],
#      'latitude': '50.849243',
#      'longitude': '4.354815'},
#     'countryNow': {'en': 'Belgium',
#      'no': 'Belgia',
#      'se': 'Belgien',
#      'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#      'latitude': '50.641111',
#      'longitude': '4.668056'},
#     'continent': {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'},
#     'locationString': {'en': 'Brussels, Belgium',
#      'no': 'Brussel, Belgia',
#      'se': 'Bryssel, Belgien'}}},
#   'wikipedia': {'slug': 'Albert_Claude',
#    'english': 'https://en.wikipedia.org/wiki/Albert_Claude'},
#   'wikidata': {'id': 'Q233943',
#    'url': 'https://www.wikidata.org/wiki/Q233943'},
#   'sameAs': ['https://www.wikidata.org/wiki/Q233943',
#    'https://en.wikipedia.org/wiki/Albert_Claude'],
#   'links': [{'rel': 'laureate',
#     'href': 'https://api.nobelprize.org/2/laureate/403',
#     'action': 'GET',
#     'types': 'application/json'},
#    {'rel': 'external',
#     'href': 'https://www.nobelprize.org/laureate/403',
#     'title': 'Albert Claude - Facts',
#     'action': 'GET',
#     'types': 'text/html',
#     'class': ['laureate facts']}],
#   'nobelPrizes': [{'awardYear': '1974',
#     'category': {'en': 'Physiology or Medicine',
#      'no': 'Fysiologi eller medisin',
#      'se': 'Fysiologi eller medicin'},
#     'categoryFullName': {'en': 'The Nobel Prize in Physiology or Medicine',
#      'no': 'Nobelprisen i fysiologi eller medisin',
#      'se': 'Nobelpriset i fysiologi eller medicin'},
#     'sortOrder': '1',
#     'portion': '1/3',
#     'dateAwarded': '1974-10-10',
#     'prizeStatus': 'received',
#     'motivation': {'en': 'for their discoveries concerning the structural and functional organization of the cell',
#      'se': 'för deras upptäckter rörande cellens strukturella och funktionella organisation'},
#     'prizeAmount': 550000,
#     'prizeAmountAdjusted': 4126741,
#     'affiliations': [{'name': {'en': 'Université Catholique de Louvain',
#        'no': 'Université Catholique de Louvain',
#        'se': 'Université Catholique de Louvain'},
#       'nameNow': {'en': 'Université Catholique de Louvain'},
#       'city': {'en': 'Louvain', 'no': 'Louvain', 'se': 'Louvain'},
#       'country': {'en': 'Belgium', 'no': 'Belgia', 'se': 'Belgien'},
#       'cityNow': {'en': 'Louvain',
#        'no': 'Louvain',
#        'se': 'Louvain',
#        'sameAs': ['https://www.wikidata.org/wiki/Q118958',
#         'https://www.wikipedia.org/wiki/Leuven'],
#        'latitude': '50.883029',
#        'longitude': '4.713949'},
#       'countryNow': {'en': 'Belgium',
#        'no': 'Belgia',
#        'se': 'Belgien',
#        'sameAs': ['https://www.wikidata.org/wiki/Q31'],
#        'latitude': '50.641111',
#        'longitude': '4.668056'},
#       'continent': {'en': 'Europe'},
#       'locationString': {'en': 'Louvain, Belgium',
#        'no': 'Louvain, Belgia',
#        'se': 'Louvain, Belgien'}}],
#     'links': [{'rel': 'nobelPrize',
#       'href': 'https://api.nobelprize.org/2/nobelPrize/med/1974',
#       'action': 'GET',
#       'types': 'application/json'},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/medicine/1974/claude/facts/',
#       'title': 'Albert Claude - Facts',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['laureate facts']},
#      {'rel': 'external',
#       'href': 'https://www.nobelprize.org/prizes/medicine/1974/summary/',
#       'title': 'The Nobel Prize in Physiology or Medicine 1974',
#       'action': 'GET',
#       'types': 'text/html',
#       'class': ['prize summary']}]}]}]

# %%
data_read
# Out:
#       id                                          knownName  \
# 0    745  {'en': 'A. Michael Spence', 'se': 'A. Michael ...
# 1    102       {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'}
# 2    779  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...
# 3    259           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}
# 4   1004  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...
# 5    114         {'en': 'Abdus Salam', 'se': 'Abdus Salam'}
# 6    982  {'en': 'Abhijit Banerjee', 'se': 'Abhijit Bane...
# 7    981   {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'}
# 8    843     {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'}
# 9    866     {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'}
# 10   199  {'en': 'Adolf Butenandt', 'se': 'Adolf Butenan...
# 11   164  {'en': 'Adolf von Baeyer', 'se': 'Adolf von Ba...
# 12   185     {'en': 'Adolf Windaus', 'se': 'Adolf Windaus'}
# 13   541  {'en': 'Adolfo Pérez Esquivel', 'se': 'Adolfo ...
# 14   292       {'en': 'Ahmed Zewail', 'se': 'Ahmed Zewail'}
# 15   853       {'en': 'Akira Suzuki', 'se': 'Akira Suzuki'}
# 16   978     {'en': 'Akira Yoshino', 'se': 'Akira Yoshino'}
# 17   819                 {'en': 'Al Gore', 'se': 'Al Gore'}
# 18  1012       {'en': 'Alain Aspect', 'se': 'Alain Aspect'}
# 19   729         {'en': 'Alan Heeger', 'se': 'Alan Heeger'}
# 20   376       {'en': 'Alan Hodgkin', 'se': 'Alan Hodgkin'}
# 21   730  {'en': 'Alan MacDiarmid', 'se': 'Alan MacDiarm...
# 22    11  {'en': 'Albert A. Michelson', 'se': 'Albert A....
# 23   628       {'en': 'Albert Camus', 'se': 'Albert Camus'}
# 24   403     {'en': 'Albert Claude', 'se': 'Albert Claude'}
#
#                                    givenName  \
# 0   {'en': 'A. Michael', 'se': 'A. Michael'}
# 1         {'en': 'Aage N.', 'se': 'Aage N.'}
# 2             {'en': 'Aaron', 'se': 'Aaron'}
# 3             {'en': 'Aaron', 'se': 'Aaron'}
# 4   {'en': 'Abdulrazak', 'se': 'Abdulrazak'}
# 5             {'en': 'Abdus', 'se': 'Abdus'}
# 6         {'en': 'Abhijit', 'se': 'Abhijit'}
# 7               {'en': 'Abiy', 'se': 'Abiy'}
# 8           {'en': 'Ada E.', 'se': 'Ada E.'}
# 9         {'en': 'Adam G.', 'se': 'Adam G.'}
# 10            {'en': 'Adolf', 'se': 'Adolf'}
# 11            {'en': 'Adolf', 'se': 'Adolf'}
# 12            {'en': 'Adolf', 'se': 'Adolf'}
# 13          {'en': 'Adolfo', 'se': 'Adolfo'}
# 14            {'en': 'Ahmed', 'se': 'Ahmed'}
# 15            {'en': 'Akira', 'se': 'Akira'}
# 16            {'en': 'Akira', 'se': 'Akira'}
# 17                  {'en': 'Al', 'se': 'Al'}
# 18            {'en': 'Alain', 'se': 'Alain'}
# 19              {'en': 'Alan', 'se': 'Alan'}
# 20              {'en': 'Alan', 'se': 'Alan'}
# 21              {'en': 'Alan', 'se': 'Alan'}
# 22    {'en': 'Albert A.', 'se': 'Albert A.'}
# 23          {'en': 'Albert', 'se': 'Albert'}
# 24          {'en': 'Albert', 'se': 'Albert'}
#
#                                           familyName  \
# 0                   {'en': 'Spence', 'se': 'Spence'}
# 1                       {'en': 'Bohr', 'se': 'Bohr'}
# 2         {'en': 'Ciechanover', 'se': 'Ciechanover'}
# 3                       {'en': 'Klug', 'se': 'Klug'}
# 4                   {'en': 'Gurnah', 'se': 'Gurnah'}
# 5                     {'en': 'Salam', 'se': 'Salam'}
# 6               {'en': 'Banerjee', 'se': 'Banerjee'}
# 7             {'en': 'Ahmed Ali', 'se': 'Ahmed Ali'}
# 8                   {'en': 'Yonath', 'se': 'Yonath'}
# 9                     {'en': 'Riess', 'se': 'Riess'}
# 10            {'en': 'Butenandt', 'se': 'Butenandt'}
# 11          {'en': 'von Baeyer', 'se': 'von Baeyer'}
# 12                {'en': 'Windaus', 'se': 'Windaus'}
# 13  {'en': 'Pérez Esquivel', 'se': 'Pérez Esquivel'}
# 14                  {'en': 'Zewail', 'se': 'Zewail'}
# 15                  {'en': 'Suzuki', 'se': 'Suzuki'}
# 16                {'en': 'Yoshino', 'se': 'Yoshino'}
# 17                      {'en': 'Gore', 'se': 'Gore'}
# 18                  {'en': 'Aspect', 'se': 'Aspect'}
# 19                  {'en': 'Heeger', 'se': 'Heeger'}
# 20                {'en': 'Hodgkin', 'se': 'Hodgkin'}
# 21          {'en': 'MacDiarmid', 'se': 'MacDiarmid'}
# 22            {'en': 'Michelson', 'se': 'Michelson'}
# 23                    {'en': 'Camus', 'se': 'Camus'}
# 24                  {'en': 'Claude', 'se': 'Claude'}
#
#                                              fullName     fileName  gender  \
# 0   {'en': 'A. Michael Spence', 'se': 'A. Michael ...       spence    male
# 1   {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bo...         bohr    male
# 2   {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...  ciechanover    male
# 3            {'en': 'Aaron Klug', 'se': 'Aaron Klug'}         klug    male
# 4   {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...       gurnah    male
# 5          {'en': 'Abdus Salam', 'se': 'Abdus Salam'}        salam    male
# 6   {'en': 'Abhijit Banerjee', 'se': 'Abhijit Bane...     banerjee    male
# 7    {'en': 'Abiy Ahmed Ali', 'se': 'Abiy Ahmed Ali'}         abiy    male
# 8      {'en': 'Ada E. Yonath', 'se': 'Ada E. Yonath'}       yonath  female
# 9      {'en': 'Adam G. Riess', 'se': 'Adam G. Riess'}        riess    male
# 10  {'en': 'Adolf Friedrich Johann Butenandt', 'se...    butenandt    male
# 11  {'en': 'Johann Friedrich Wilhelm Adolf von Bae...       baeyer    male
# 12  {'en': 'Adolf Otto Reinhold Windaus', 'se': 'A...      windaus    male
# 13  {'en': 'Adolfo Pérez Esquivel', 'se': 'Adolfo ...     esquivel    male
# 14  {'en': 'Ahmed H. Zewail', 'se': 'Ahmed H. Zewa...       zewail    male
# 15       {'en': 'Akira Suzuki', 'se': 'Akira Suzuki'}       suzuki    male
# 16     {'en': 'Akira Yoshino', 'se': 'Akira Yoshino'}      yoshino    male
# 17  {'en': 'Albert Arnold (Al) Gore  Jr.', 'se': '...         gore    male
# 18       {'en': 'Alain Aspect', 'se': 'Alain Aspect'}       aspect    male
# 19   {'en': 'Alan J. Heeger', 'se': 'Alan J. Heeger'}       heeger    male
# 20  {'en': 'Alan Lloyd Hodgkin', 'se': 'Alan Lloyd...      hodgkin    male
# 21  {'en': 'Alan G. MacDiarmid', 'se': 'Alan G. Ma...   macdiarmid    male
# 22  {'en': 'Albert Abraham Michelson', 'se': 'Albe...    michelson    male
# 23       {'en': 'Albert Camus', 'se': 'Albert Camus'}        camus    male
# 24     {'en': 'Albert Claude', 'se': 'Albert Claude'}       claude    male
#
#                                                 birth  \
# 0   {'date': '1943-00-00', 'place': {'city': {'en'...
# 1   {'date': '1922-06-19', 'place': {'city': {'en'...
# 2   {'date': '1947-10-01', 'place': {'city': {'en'...
# 3   {'date': '1926-08-11', 'place': {'city': {'en'...
# 4                              {'date': '1948-00-00'}
# 5   {'date': '1926-01-29', 'place': {'city': {'en'...
# 6   {'date': '1961-02-21', 'place': {'city': {'en'...
# 7   {'date': '1976-08-15', 'place': {'city': {'en'...
# 8   {'date': '1939-06-22', 'place': {'city': {'en'...
# 9   {'date': '1969-12-16', 'place': {'city': {'en'...
# 10  {'date': '1903-03-24', 'place': {'city': {'en'...
# 11  {'date': '1835-10-31', 'place': {'city': {'en'...
# 12  {'date': '1876-12-25', 'place': {'city': {'en'...
# 13  {'date': '1931-11-26', 'place': {'city': {'en'...
# 14  {'date': '1946-02-26', 'place': {'city': {'en'...
# 15  {'date': '1930-09-12', 'place': {'city': {'en'...
# 16  {'date': '1948-01-30', 'place': {'city': {'en'...
# 17  {'date': '1948-03-31', 'place': {'city': {'en'...
# 18  {'date': '1947-06-15', 'place': {'city': {'en'...
# 19  {'date': '1936-01-22', 'place': {'city': {'en'...
# 20  {'date': '1914-02-05', 'place': {'city': {'en'...
# 21  {'date': '1927-04-14', 'place': {'city': {'en'...
# 22  {'date': '1852-12-19', 'place': {'city': {'en'...
# 23  {'date': '1913-11-07', 'place': {'city': {'en'...
# 24  {'date': '1898-08-24', 'place': {'city': {'en'...
#
#                                             wikipedia  \
# 0   {'slug': 'Michael_Spence', 'english': 'https:/...
# 1   {'slug': 'Aage_Bohr', 'english': 'https://en.w...
# 2   {'slug': 'Aaron_Ciechanover', 'english': 'http...
# 3   {'slug': 'Aaron_Klug', 'english': 'https://en....
# 4   {'slug': 'Abdulrazak_Gurnah', 'english': 'http...
# 5   {'slug': 'Abdus_Salam', 'english': 'https://en...
# 6   {'slug': 'Abhijit_Banerjee', 'english': 'https...
# 7   {'slug': 'Abiy_Ahmed', 'english': 'https://en....
# 8   {'slug': 'Ada_Yonath', 'english': 'https://en....
# 9   {'slug': 'Adam_Riess', 'english': 'https://en....
# 10  {'slug': 'Adolf_Butenandt', 'english': 'https:...
# 11  {'slug': 'Adolf_von_Baeyer', 'english': 'https...
# 12  {'slug': 'Adolf_Otto_Reinhold_Windaus', 'engli...
# 13  {'slug': 'Adolfo_Pérez_Esquivel', 'english': '...
# 14  {'slug': 'Ahmed_Zewail', 'english': 'https://e...
# 15  {'slug': 'Akira_Suzuki_(chemist)', 'english': ...
# 16  {'slug': 'Akira_Yoshino', 'english': 'https://...
# 17  {'slug': 'Al_Gore', 'english': 'https://en.wik...
# 18  {'slug': 'Alain_Aspect', 'english': 'https://e...
# 19  {'slug': 'Alan_J._Heeger', 'english': 'https:/...
# 20  {'slug': 'Alan_Lloyd_Hodgkin', 'english': 'htt...
# 21  {'slug': 'Alan_MacDiarmid', 'english': 'https:...
# 22  {'slug': 'Albert_Abraham_Michelson', 'english'...
# 23  {'slug': 'Albert_Camus', 'english': 'https://e...
# 24  {'slug': 'Albert_Claude', 'english': 'https://...
#
#                                              wikidata  \
# 0   {'id': 'Q157245', 'url': 'https://www.wikidata...
# 1   {'id': 'Q103854', 'url': 'https://www.wikidata...
# 2   {'id': 'Q233205', 'url': 'https://www.wikidata...
# 3   {'id': 'Q190626', 'url': 'https://www.wikidata...
# 4   {'id': 'Q317877', 'url': 'https://www.wikidata...
# 5   {'id': 'Q28189', 'url': 'https://www.wikidata....
# 6   {'id': 'Q320578', 'url': 'https://www.wikidata...
# 7   {'id': 'Q50365049', 'url': 'https://www.wikida...
# 8   {'id': 'Q7426', 'url': 'https://www.wikidata.o...
# 9   {'id': 'Q106454', 'url': 'https://www.wikidata...
# 10  {'id': 'Q5327', 'url': 'https://www.wikidata.o...
# 11  {'id': 'Q57078', 'url': 'https://www.wikidata....
# 12  {'id': 'Q77142', 'url': 'https://www.wikidata....
# 13  {'id': 'Q206505', 'url': 'https://www.wikidata...
# 14  {'id': 'Q106624', 'url': 'https://www.wikidata...
# 15  {'id': 'Q105949', 'url': 'https://www.wikidata...
# 16  {'id': 'Q4701206', 'url': 'https://www.wikidat...
# 17  {'id': 'Q19673', 'url': 'https://www.wikidata....
# 18  {'id': 'Q364997', 'url': 'https://www.wikidata...
# 19  {'id': 'Q106751', 'url': 'https://www.wikidata...
# 20  {'id': 'Q193650', 'url': 'https://www.wikidata...
# 21  {'id': 'Q110942', 'url': 'https://www.wikidata...
# 22  {'id': 'Q127234', 'url': 'https://www.wikidata...
# 23  {'id': 'Q34670', 'url': 'https://www.wikidata....
# 24  {'id': 'Q233943', 'url': 'https://www.wikidata...
#
#                                                sameAs  \
# 0   [https://www.wikidata.org/wiki/Q157245, https:...
# 1   [https://www.wikidata.org/wiki/Q103854, https:...
# 2   [https://www.wikidata.org/wiki/Q233205, https:...
# 3   [https://www.wikidata.org/wiki/Q190626, https:...
# 4   [https://www.wikidata.org/wiki/Q317877, https:...
# 5   [https://www.wikidata.org/wiki/Q28189, https:/...
# 6   [https://www.wikidata.org/wiki/Q320578, https:...
# 7   [https://www.wikidata.org/wiki/Q50365049, http...
# 8   [https://www.wikidata.org/wiki/Q7426, https://...
# 9   [https://www.wikidata.org/wiki/Q106454, https:...
# 10  [https://www.wikidata.org/wiki/Q5327, https://...
# 11  [https://www.wikidata.org/wiki/Q57078, https:/...
# 12  [https://www.wikidata.org/wiki/Q77142, https:/...
# 13  [https://www.wikidata.org/wiki/Q206505, https:...
# 14  [https://www.wikidata.org/wiki/Q106624, https:...
# 15  [https://www.wikidata.org/wiki/Q105949, https:...
# 16  [https://www.wikidata.org/wiki/Q4701206, https...
# 17  [https://www.wikidata.org/wiki/Q19673, https:/...
# 18  [https://www.wikidata.org/wiki/Q364997, https:...
# 19  [https://www.wikidata.org/wiki/Q106751, https:...
# 20  [https://www.wikidata.org/wiki/Q193650, https:...
# 21  [https://www.wikidata.org/wiki/Q110942, https:...
# 22  [https://www.wikidata.org/wiki/Q127234, https:...
# 23  [https://www.wikidata.org/wiki/Q34670, https:/...
# 24  [https://www.wikidata.org/wiki/Q233943, https:...
#
#                                                 links  \
# 0   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 1   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 2   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 3   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 4   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 5   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 6   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 7   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 8   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 9   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 10  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 11  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 12  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 13  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 14  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 15  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 16  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 17  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 18  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 19  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 20  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 21  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 22  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 23  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 24  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                           nobelPrizes  \
# 0   [{'awardYear': '2001', 'category': {'en': 'Eco...
# 1   [{'awardYear': '1975', 'category': {'en': 'Phy...
# 2   [{'awardYear': '2004', 'category': {'en': 'Che...
# 3   [{'awardYear': '1982', 'category': {'en': 'Che...
# 4   [{'awardYear': '2021', 'category': {'en': 'Lit...
# 5   [{'awardYear': '1979', 'category': {'en': 'Phy...
# 6   [{'awardYear': '2019', 'category': {'en': 'Eco...
# 7   [{'awardYear': '2019', 'category': {'en': 'Pea...
# 8   [{'awardYear': '2009', 'category': {'en': 'Che...
# 9   [{'awardYear': '2011', 'category': {'en': 'Phy...
# 10  [{'awardYear': '1939', 'category': {'en': 'Che...
# 11  [{'awardYear': '1905', 'category': {'en': 'Che...
# 12  [{'awardYear': '1928', 'category': {'en': 'Che...
# 13  [{'awardYear': '1980', 'category': {'en': 'Pea...
# 14  [{'awardYear': '1999', 'category': {'en': 'Che...
# 15  [{'awardYear': '2010', 'category': {'en': 'Che...
# 16  [{'awardYear': '2019', 'category': {'en': 'Che...
# 17  [{'awardYear': '2007', 'category': {'en': 'Pea...
# 18  [{'awardYear': '2022', 'category': {'en': 'Phy...
# 19  [{'awardYear': '2000', 'category': {'en': 'Che...
# 20  [{'awardYear': '1963', 'category': {'en': 'Phy...
# 21  [{'awardYear': '2000', 'category': {'en': 'Che...
# 22  [{'awardYear': '1907', 'category': {'en': 'Phy...
# 23  [{'awardYear': '1957', 'category': {'en': 'Lit...
# 24  [{'awardYear': '1974', 'category': {'en': 'Phy...
#
#                                                 death
# 0                                                 NaN
# 1   {'date': '2009-09-08', 'place': {'city': {'en'...
# 2                                                 NaN
# 3   {'date': '2018-11-20', 'place': {'locationStri...
# 4                                                 NaN
# 5   {'date': '1996-11-21', 'place': {'city': {'en'...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'date': '1995-01-18', 'place': {'city': {'en'...
# 11  {'date': '1917-08-20', 'place': {'city': {'en'...
# 12  {'date': '1959-06-09', 'place': {'city': {'en'...
# 13                                                NaN
# 14  {'date': '2016-08-02', 'place': {'city': {'en'...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  {'date': '1998-12-20', 'place': {'city': {'en'...
# 21  {'date': '2007-02-07', 'place': {'city': {'en'...
# 22  {'date': '1931-05-09', 'place': {'city': {'en'...
# 23  {'date': '1960-01-04', 'place': {'city': {'en'...
# 24  {'date': '1983-05-22', 'place': {'city': {'en'...

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# #### Loading completed data into Pandas Data Frame

# %%
all_laureates_data=pd.read_json('all_laureates.json')

# %%
all_laureates_data.head()
# Out:
#      id                                          knownName  \
# 0   745  {'en': 'A. Michael Spence', 'se': 'A. Michael ...
# 1   102       {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'}
# 2   779  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...
# 3   259           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}
# 4  1004  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...
#
#                                   givenName  \
# 0  {'en': 'A. Michael', 'se': 'A. Michael'}
# 1        {'en': 'Aage N.', 'se': 'Aage N.'}
# 2            {'en': 'Aaron', 'se': 'Aaron'}
# 3            {'en': 'Aaron', 'se': 'Aaron'}
# 4  {'en': 'Abdulrazak', 'se': 'Abdulrazak'}
#
#                                    familyName  \
# 0            {'en': 'Spence', 'se': 'Spence'}
# 1                {'en': 'Bohr', 'se': 'Bohr'}
# 2  {'en': 'Ciechanover', 'se': 'Ciechanover'}
# 3                {'en': 'Klug', 'se': 'Klug'}
# 4            {'en': 'Gurnah', 'se': 'Gurnah'}
#
#                                             fullName     fileName gender  \
# 0  {'en': 'A. Michael Spence', 'se': 'A. Michael ...       spence   male
# 1  {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bo...         bohr   male
# 2  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...  ciechanover   male
# 3           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}         klug   male
# 4  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...       gurnah   male
#
#                                                birth  \
# 0  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4                             {'date': '1948-00-00'}
#
#                                            wikipedia  \
# 0  {'slug': 'Michael_Spence', 'english': 'https:/...
# 1  {'slug': 'Aage_Bohr', 'english': 'https://en.w...
# 2  {'slug': 'Aaron_Ciechanover', 'english': 'http...
# 3  {'slug': 'Aaron_Klug', 'english': 'https://en....
# 4  {'slug': 'Abdulrazak_Gurnah', 'english': 'http...
#
#                                             wikidata  ...  \
# 0  {'id': 'Q157245', 'url': 'https://www.wikidata...  ...
# 1  {'id': 'Q103854', 'url': 'https://www.wikidata...  ...
# 2  {'id': 'Q233205', 'url': 'https://www.wikidata...  ...
# 3  {'id': 'Q190626', 'url': 'https://www.wikidata...  ...
# 4  {'id': 'Q317877', 'url': 'https://www.wikidata...  ...
#
#                                                death orgName acronym founded  \
# 0                                                NaN     NaN     NaN     NaN
# 1  {'date': '2009-09-08', 'place': {'city': {'en'...     NaN     NaN     NaN
# 2                                                NaN     NaN     NaN     NaN
# 3  {'date': '2018-11-20', 'place': {'locationStri...     NaN     NaN     NaN
# 4                                                NaN     NaN     NaN     NaN
#
#   nativeName penName penNameOf foundedCountry foundedCountryNow  \
# 0        NaN     NaN       NaN            NaN               NaN
# 1        NaN     NaN       NaN            NaN               NaN
# 2        NaN     NaN       NaN            NaN               NaN
# 3        NaN     NaN       NaN            NaN               NaN
# 4        NaN     NaN       NaN            NaN               NaN
#
#   foundedContinent
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 23 columns]

# %%
# No. of Laureates 
print(len(all_laureates_data))
# Out:
# 1004

# %%
all_laureates_data.columns
# Out:
# Index(['id', 'knownName', 'givenName', 'familyName', 'fullName', 'fileName',
#        'gender', 'birth', 'wikipedia', 'wikidata', 'sameAs', 'links',
#        'nobelPrizes', 'death', 'orgName', 'acronym', 'founded', 'nativeName',
#        'penName', 'penNameOf', 'foundedCountry', 'foundedCountryNow',
#        'foundedContinent'],
#       dtype='object')

# %%
all_laureates_data['orgName'].apply(pd.Series)['en'].unique()
# Out:
# array([nan, 'American Friends Service Committee', 'Amnesty International',
#        'Center for Civil Liberties', 'Doctors Without Borders',
#        'European Union', 'Friends Service Council', 'Grameen Bank',
#        'Institute of International Law',
#        'Intergovernmental Panel on Climate Change',
#        'International Atomic Energy Agency',
#        'International Campaign to Abolish Nuclear Weapons',
#        'International Campaign to Ban Landmines',
#        'International Committee of the Red Cross',
#        'International Labour Organization',
#        'International Physicians for the Prevention of Nuclear War',
#        'League of Red Cross Societies', 'Memorial',
#        'Nansen International Office for Refugees',
#        'National Dialogue Quartet', 'Nihon Hidankyo',
#        'Office of the United Nations High Commissioner for Refugees',
#        'Organisation for the Prohibition of Chemical Weapons',
#        'Permanent International Peace Bureau',
#        'Pugwash Conferences on Science and World Affairs',
#        'United Nations', "United Nations Children's Fund",
#        'United Nations Peacekeeping Forces', 'World Food Programme'],
#       dtype=object)

# %%
# Creating a column name laureate_type to show if it's been a individual or an organization. 
all_laureates_data['laureate_type']=np.where(all_laureates_data['orgName'].isnull(),'Individual','Organization')
all_laureates_data.head()
# Out:
#      id                                          knownName  \
# 0   745  {'en': 'A. Michael Spence', 'se': 'A. Michael ...
# 1   102       {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'}
# 2   779  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...
# 3   259           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}
# 4  1004  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...
#
#                                   givenName  \
# 0  {'en': 'A. Michael', 'se': 'A. Michael'}
# 1        {'en': 'Aage N.', 'se': 'Aage N.'}
# 2            {'en': 'Aaron', 'se': 'Aaron'}
# 3            {'en': 'Aaron', 'se': 'Aaron'}
# 4  {'en': 'Abdulrazak', 'se': 'Abdulrazak'}
#
#                                    familyName  \
# 0            {'en': 'Spence', 'se': 'Spence'}
# 1                {'en': 'Bohr', 'se': 'Bohr'}
# 2  {'en': 'Ciechanover', 'se': 'Ciechanover'}
# 3                {'en': 'Klug', 'se': 'Klug'}
# 4            {'en': 'Gurnah', 'se': 'Gurnah'}
#
#                                             fullName     fileName gender  \
# 0  {'en': 'A. Michael Spence', 'se': 'A. Michael ...       spence   male
# 1  {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bo...         bohr   male
# 2  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...  ciechanover   male
# 3           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}         klug   male
# 4  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...       gurnah   male
#
#                                                birth  \
# 0  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4                             {'date': '1948-00-00'}
#
#                                            wikipedia  \
# 0  {'slug': 'Michael_Spence', 'english': 'https:/...
# 1  {'slug': 'Aage_Bohr', 'english': 'https://en.w...
# 2  {'slug': 'Aaron_Ciechanover', 'english': 'http...
# 3  {'slug': 'Aaron_Klug', 'english': 'https://en....
# 4  {'slug': 'Abdulrazak_Gurnah', 'english': 'http...
#
#                                             wikidata  ... orgName acronym  \
# 0  {'id': 'Q157245', 'url': 'https://www.wikidata...  ...     NaN     NaN
# 1  {'id': 'Q103854', 'url': 'https://www.wikidata...  ...     NaN     NaN
# 2  {'id': 'Q233205', 'url': 'https://www.wikidata...  ...     NaN     NaN
# 3  {'id': 'Q190626', 'url': 'https://www.wikidata...  ...     NaN     NaN
# 4  {'id': 'Q317877', 'url': 'https://www.wikidata...  ...     NaN     NaN
#
#   founded nativeName penName penNameOf foundedCountry foundedCountryNow  \
# 0     NaN        NaN     NaN       NaN            NaN               NaN
# 1     NaN        NaN     NaN       NaN            NaN               NaN
# 2     NaN        NaN     NaN       NaN            NaN               NaN
# 3     NaN        NaN     NaN       NaN            NaN               NaN
# 4     NaN        NaN     NaN       NaN            NaN               NaN
#
#   foundedContinent laureate_type
# 0              NaN    Individual
# 1              NaN    Individual
# 2              NaN    Individual
# 3              NaN    Individual
# 4              NaN    Individual
#
# [5 rows x 24 columns]

# %%
# Expanding the birth column 
birth_data=all_laureates_data['birth'].apply(pd.Series)
# Expanding the birth place column 
new_birth_data_place=birth_data['place'].apply(pd.Series)
# Getting the city column 
birth_city_data=new_birth_data_place[['city','country']]['city'].apply(pd.Series)[['en']].rename(columns={'en':'birth_city'})
# Getting the country column
birth_country_data=new_birth_data_place[['city','country']]['country'].apply(pd.Series)[['en']].rename(columns={'en':'birth_country'})

# %%
birth_city_data.head()
# Out:
#       birth_city
# 0  Montclair, NJ
# 1     Copenhagen
# 2          Haifa
# 3         Zelvas
# 4            NaN

# %%
birth_country_data.head()
# Out:
#                        birth_country
# 0                                USA
# 1                            Denmark
# 2  British Protectorate of Palestine
# 3                          Lithuania
# 4                                NaN

# %%
birth_date_data=birth_data[['date']]

# %%
# Adding the three columns to the main dataframe
# Adding birth_country_data, birth_city_data, birth_date_data
all_laureates_data=pd.concat([all_laureates_data,birth_city_data,birth_country_data,birth_date_data],axis=1)
all_laureates_data.head()
# Out:
#      id                                          knownName  \
# 0   745  {'en': 'A. Michael Spence', 'se': 'A. Michael ...
# 1   102       {'en': 'Aage N. Bohr', 'se': 'Aage N. Bohr'}
# 2   779  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...
# 3   259           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}
# 4  1004  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...
#
#                                   givenName  \
# 0  {'en': 'A. Michael', 'se': 'A. Michael'}
# 1        {'en': 'Aage N.', 'se': 'Aage N.'}
# 2            {'en': 'Aaron', 'se': 'Aaron'}
# 3            {'en': 'Aaron', 'se': 'Aaron'}
# 4  {'en': 'Abdulrazak', 'se': 'Abdulrazak'}
#
#                                    familyName  \
# 0            {'en': 'Spence', 'se': 'Spence'}
# 1                {'en': 'Bohr', 'se': 'Bohr'}
# 2  {'en': 'Ciechanover', 'se': 'Ciechanover'}
# 3                {'en': 'Klug', 'se': 'Klug'}
# 4            {'en': 'Gurnah', 'se': 'Gurnah'}
#
#                                             fullName     fileName gender  \
# 0  {'en': 'A. Michael Spence', 'se': 'A. Michael ...       spence   male
# 1  {'en': 'Aage Niels Bohr', 'se': 'Aage Niels Bo...         bohr   male
# 2  {'en': 'Aaron Ciechanover', 'se': 'Aaron Ciech...  ciechanover   male
# 3           {'en': 'Aaron Klug', 'se': 'Aaron Klug'}         klug   male
# 4  {'en': 'Abdulrazak Gurnah', 'se': 'Abdulrazak ...       gurnah   male
#
#                                                birth  \
# 0  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4                             {'date': '1948-00-00'}
#
#                                            wikipedia  \
# 0  {'slug': 'Michael_Spence', 'english': 'https:/...
# 1  {'slug': 'Aage_Bohr', 'english': 'https://en.w...
# 2  {'slug': 'Aaron_Ciechanover', 'english': 'http...
# 3  {'slug': 'Aaron_Klug', 'english': 'https://en....
# 4  {'slug': 'Abdulrazak_Gurnah', 'english': 'http...
#
#                                             wikidata  ... nativeName penName  \
# 0  {'id': 'Q157245', 'url': 'https://www.wikidata...  ...        NaN     NaN
# 1  {'id': 'Q103854', 'url': 'https://www.wikidata...  ...        NaN     NaN
# 2  {'id': 'Q233205', 'url': 'https://www.wikidata...  ...        NaN     NaN
# 3  {'id': 'Q190626', 'url': 'https://www.wikidata...  ...        NaN     NaN
# 4  {'id': 'Q317877', 'url': 'https://www.wikidata...  ...        NaN     NaN
#
#   penNameOf foundedCountry foundedCountryNow foundedContinent laureate_type  \
# 0       NaN            NaN               NaN              NaN    Individual
# 1       NaN            NaN               NaN              NaN    Individual
# 2       NaN            NaN               NaN              NaN    Individual
# 3       NaN            NaN               NaN              NaN    Individual
# 4       NaN            NaN               NaN              NaN    Individual
#
#       birth_city                      birth_country        date
# 0  Montclair, NJ                                USA  1943-00-00
# 1     Copenhagen                            Denmark  1922-06-19
# 2          Haifa  British Protectorate of Palestine  1947-10-01
# 3         Zelvas                          Lithuania  1926-08-11
# 4            NaN                                NaN  1948-00-00
#
# [5 rows x 27 columns]

# %%
all_laureates_data.columns
# Out:
# Index(['id', 'knownName', 'givenName', 'familyName', 'fullName', 'fileName',
#        'gender', 'birth', 'wikipedia', 'wikidata', 'sameAs', 'links',
#        'nobelPrizes', 'death', 'orgName', 'acronym', 'founded', 'nativeName',
#        'penName', 'penNameOf', 'foundedCountry', 'foundedCountryNow',
#        'foundedContinent', 'laureate_type', 'birth_city', 'birth_country',
#        'date'],
#       dtype='object')

# %%
# Now removing the birth column from this data set 
#all_laureates_data.drop('birth',axis=1)

# %%
# Birth data is removed from this dataset.
all_laureates_data.columns
# Out:
# Index(['id', 'knownName', 'givenName', 'familyName', 'fullName', 'fileName',
#        'gender', 'birth', 'wikipedia', 'wikidata', 'sameAs', 'links',
#        'nobelPrizes', 'death', 'orgName', 'acronym', 'founded', 'nativeName',
#        'penName', 'penNameOf', 'foundedCountry', 'foundedCountryNow',
#        'foundedContinent', 'laureate_type', 'birth_city', 'birth_country',
#        'date'],
#       dtype='object')

# %%
# Expanding the dataset based on fullname
full_name_data=all_laureates_data['fullName'].apply(pd.Series)[['en']]
# Renaming the column
full_name_data.rename(columns={'en':'Fullname'},inplace=True)
full_name_data
# Out:
#                Fullname
# 0     A. Michael Spence
# 1       Aage Niels Bohr
# 2     Aaron Ciechanover
# 3            Aaron Klug
# 4     Abdulrazak Gurnah
# ...                 ...
# 999      Yoichiro Nambu
# 1000   Yoshinori Ohsumi
# 1001        Yuan T. Lee
# 1002       Yves Chauvin
# 1003  Zhores I. Alferov
#
# [1004 rows x 1 columns]

# %%
# Adding this data to the dataset
all_laureates_data=pd.concat([all_laureates_data,full_name_data],axis=1)
all_laureates_data.columns
# Out:
# Index(['id', 'knownName', 'givenName', 'familyName', 'fullName', 'fileName',
#        'gender', 'birth', 'wikipedia', 'wikidata', 'sameAs', 'links',
#        'nobelPrizes', 'death', 'orgName', 'acronym', 'founded', 'nativeName',
#        'penName', 'penNameOf', 'foundedCountry', 'foundedCountryNow',
#        'foundedContinent', 'laureate_type', 'birth_city', 'birth_country',
#        'date', 'Fullname'],
#       dtype='object')

# %%
# Deleting the knownName,familyName,givenName,fullName,fileName from the dataset 
all_laureates_data.drop(['knownName','familyName','givenName','fullName','fileName'],axis=1,inplace=True)
all_laureates_data.head()
# Out:
#      id gender                                              birth  \
# 0   745   male  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1   102   male  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2   779   male  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3   259   male  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4  1004   male                             {'date': '1948-00-00'}
#
#                                            wikipedia  \
# 0  {'slug': 'Michael_Spence', 'english': 'https:/...
# 1  {'slug': 'Aage_Bohr', 'english': 'https://en.w...
# 2  {'slug': 'Aaron_Ciechanover', 'english': 'http...
# 3  {'slug': 'Aaron_Klug', 'english': 'https://en....
# 4  {'slug': 'Abdulrazak_Gurnah', 'english': 'http...
#
#                                             wikidata  \
# 0  {'id': 'Q157245', 'url': 'https://www.wikidata...
# 1  {'id': 'Q103854', 'url': 'https://www.wikidata...
# 2  {'id': 'Q233205', 'url': 'https://www.wikidata...
# 3  {'id': 'Q190626', 'url': 'https://www.wikidata...
# 4  {'id': 'Q317877', 'url': 'https://www.wikidata...
#
#                                               sameAs  \
# 0  [https://www.wikidata.org/wiki/Q157245, https:...
# 1  [https://www.wikidata.org/wiki/Q103854, https:...
# 2  [https://www.wikidata.org/wiki/Q233205, https:...
# 3  [https://www.wikidata.org/wiki/Q190626, https:...
# 4  [https://www.wikidata.org/wiki/Q317877, https:...
#
#                                                links  \
# 0  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 1  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 2  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 3  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 4  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                          nobelPrizes  \
# 0  [{'awardYear': '2001', 'category': {'en': 'Eco...
# 1  [{'awardYear': '1975', 'category': {'en': 'Phy...
# 2  [{'awardYear': '2004', 'category': {'en': 'Che...
# 3  [{'awardYear': '1982', 'category': {'en': 'Che...
# 4  [{'awardYear': '2021', 'category': {'en': 'Lit...
#
#                                                death orgName  ... penName  \
# 0                                                NaN     NaN  ...     NaN
# 1  {'date': '2009-09-08', 'place': {'city': {'en'...     NaN  ...     NaN
# 2                                                NaN     NaN  ...     NaN
# 3  {'date': '2018-11-20', 'place': {'locationStri...     NaN  ...     NaN
# 4                                                NaN     NaN  ...     NaN
#
#   penNameOf foundedCountry foundedCountryNow foundedContinent laureate_type  \
# 0       NaN            NaN               NaN              NaN    Individual
# 1       NaN            NaN               NaN              NaN    Individual
# 2       NaN            NaN               NaN              NaN    Individual
# 3       NaN            NaN               NaN              NaN    Individual
# 4       NaN            NaN               NaN              NaN    Individual
#
#       birth_city                      birth_country        date  \
# 0  Montclair, NJ                                USA  1943-00-00
# 1     Copenhagen                            Denmark  1922-06-19
# 2          Haifa  British Protectorate of Palestine  1947-10-01
# 3         Zelvas                          Lithuania  1926-08-11
# 4            NaN                                NaN  1948-00-00
#
#             Fullname
# 0  A. Michael Spence
# 1    Aage Niels Bohr
# 2  Aaron Ciechanover
# 3         Aaron Klug
# 4  Abdulrazak Gurnah
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Expanding the nobel_Prizes Column

# %%
# Now expanding the nobelPrizes Column 
nobel_Prizes_Data=all_laureates_data['nobelPrizes'].apply(pd.Series)
nobel_Prizes_Data[0].apply(pd.Series).head()
# Out:
#   awardYear                                           category  \
# 0      2001  {'en': 'Economic Sciences', 'no': 'Økonomi', '...
# 1      1975   {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'}
# 2      2004   {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'}
# 3      1982   {'en': 'Chemistry', 'no': 'Kjemi', 'se': 'Kemi'}
# 4      2021  {'en': 'Literature', 'no': 'Litteratur', 'se':...
#
#                                     categoryFullName sortOrder portion  \
# 0  {'en': 'The Sveriges Riksbank Prize in Economi...         2     1/3
# 1  {'en': 'The Nobel Prize in Physics', 'no': 'No...         1     1/3
# 2  {'en': 'The Nobel Prize in Chemistry', 'no': '...         1     1/3
# 3  {'en': 'The Nobel Prize in Chemistry', 'no': '...         1       1
# 4  {'en': 'The Nobel Prize in Literature', 'no': ...         1       1
#
#   dateAwarded prizeStatus                                         motivation  \
# 0  2001-10-10    received  {'en': 'for their analyses of markets with asy...
# 1  1975-10-17    received  {'en': 'for the discovery of the connection be...
# 2  2004-10-06    received  {'en': 'for the discovery of ubiquitin-mediate...
# 3  1982-10-18    received  {'en': 'for his development of crystallographi...
# 4  2021-10-07    received  {'en': 'for his uncompromising and compassiona...
#
#    prizeAmount  prizeAmountAdjusted  \
# 0     10000000             15547541
# 1       630000              4304697
# 2     10000000             14874529
# 3      1150000              3923237
# 4     10000000             12096939
#
#                                         affiliations  \
# 0  [{'name': {'en': 'Stanford University', 'no': ...
# 1  [{'name': {'en': 'Niels Bohr Institute', 'no':...
# 2  [{'name': {'en': 'Technion - Israel Institute ...
# 3  [{'name': {'en': 'MRC Laboratory of Molecular ...
# 4                                                NaN
#
#                                                links residences topMotivation
# 0  [{'rel': 'nobelPrize', 'href': 'https://api.no...        NaN           NaN
# 1  [{'rel': 'nobelPrize', 'href': 'https://api.no...        NaN           NaN
# 2  [{'rel': 'nobelPrize', 'href': 'https://api.no...        NaN           NaN
# 3  [{'rel': 'nobelPrize', 'href': 'https://api.no...        NaN           NaN
# 4  [{'rel': 'nobelPrize', 'href': 'https://api.no...        NaN           NaN

# %%
# awardYear,category,portion,dateAwarded,motivation,affiliation(organization_name,organization_city,organization_country),links(prize(title)

# %%
# Fetching the award year 
award_year_data=nobel_Prizes_Data[0].apply(pd.Series)[['awardYear']]
# Fetching the portion as prize_share
prize_share_data=nobel_Prizes_Data[0].apply(pd.Series)[['portion']]
# Fetching the dateAwarded column
date_Awarded_data=nobel_Prizes_Data[0].apply(pd.Series)[['dateAwarded']]

# %%
# Now, fetching the motivation column 
motivation_data=nobel_Prizes_Data[0].apply(pd.Series)['motivation'].apply(pd.Series)[['en']]
motivation_data.rename(columns={'en':'motivation'},inplace=True)
motivation_data.head()
# Out:
#                                           motivation
# 0  for their analyses of markets with asymmetric ...
# 1  for the discovery of the connection between co...
# 2  for the discovery of ubiquitin-mediated protei...
# 3  for his development of crystallographic electr...
# 4  for his uncompromising and compassionate penet...

# %% [markdown]
# #### Do not run this cell

# %%
# Now fetching the category column 
# Do not run this cell
category_data=nobel_Prizes_Data[0].apply(pd.Series).head()[['category']]['category'].apply(pd.Series)[['en']]
category_data.rename(columns={'en':'category'},inplace=True)
category_data['category'].head()
# Out:
# 0    Economic Sciences
# 1              Physics
# 2            Chemistry
# 3            Chemistry
# 4           Literature
# Name: category, dtype: object

# %%
# Not all category is present
# Rechecking again

# %%
category_data_new=nobel_Prizes_Data[0].apply(pd.Series)['category'].apply(pd.Series)[['en']]
category_data_new['en'].unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Literature', 'Peace',
#        'Physiology or Medicine'], dtype=object)

# %%
category_data_new.rename(columns={'en':'category'},inplace=True)

# %%
category_data_new.tail()
# Out:
#                     category
# 999                  Physics
# 1000  Physiology or Medicine
# 1001               Chemistry
# 1002               Chemistry
# 1003                 Physics

# %%
# Expanding the links column to get the title 
# Then again the 3rd column
# Extracting the title column 
prize_title_data=nobel_Prizes_Data[0].apply(pd.Series)['links'].apply(pd.Series)[[2]][2].apply(pd.Series)[['title']]
prize_title_data.rename(columns={'title':'Prize'},inplace=True)
prize_title_data.head()
# Out:
#                                                Prize
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021

# %%
# Now expanding the affiliations column 
organization_data=nobel_Prizes_Data[0].apply(pd.Series)[['affiliations']]['affiliations'].apply(pd.Series)[0].apply(pd.Series)
organization_data.head()
# Out:
#                                                 name  \
# 0  {'en': 'Stanford University', 'no': 'Stanford ...
# 1  {'en': 'Niels Bohr Institute', 'no': 'Niels Bo...
# 2  {'en': 'Technion - Israel Institute of Technol...
# 3  {'en': 'MRC Laboratory of Molecular Biology', ...
# 4                                                NaN
#
#                                              nameNow  \
# 0                      {'en': 'Stanford University'}
# 1                     {'en': 'Niels Bohr Institute'}
# 2  {'en': 'Technion - Israel Institute of Technol...
# 3      {'en': 'MRC Laboratory of Molecular Biology'}
# 4                                                NaN
#
#                                                 city  \
# 0  {'en': 'Stanford, CA', 'no': 'Stanford, CA', '...
# 1  {'en': 'Copenhagen', 'no': 'København', 'se': ...
# 2      {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa'}
# 3  {'en': 'Cambridge', 'no': 'Cambridge', 'se': '...
# 4                                                NaN
#
#                                              country  \
# 0            {'en': 'USA', 'no': 'USA', 'se': 'USA'}
# 1  {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danm...
# 2   {'en': 'Israel', 'no': 'Israel', 'se': 'Israel'}
# 3  {'en': 'United Kingdom', 'no': 'Storbritannia'...
# 4                                                NaN
#
#                                              cityNow  \
# 0  {'en': 'Stanford, CA', 'no': 'Stanford, CA', '...
# 1  {'en': 'Copenhagen', 'no': 'København', 'se': ...
# 2  {'en': 'Haifa', 'no': 'Haifa', 'se': 'Haifa', ...
# 3  {'en': 'Cambridge', 'no': 'Cambridge', 'se': '...
# 4                                                NaN
#
#                                           countryNow                continent  \
# 0  {'en': 'USA', 'no': 'USA', 'se': 'USA', 'sameA...  {'en': 'North America'}
# 1  {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danm...         {'en': 'Europe'}
# 2  {'en': 'Israel', 'no': 'Israel', 'se': 'Israel...           {'en': 'Asia'}
# 3  {'en': 'United Kingdom', 'no': 'Storbritannia'...         {'en': 'Europe'}
# 4                                                NaN                      NaN
#
#                                       locationString   0 nativeName
# 0  {'en': 'Stanford, CA, USA', 'no': 'Stanford, C... NaN        NaN
# 1  {'en': 'Copenhagen, Denmark', 'no': 'København... NaN        NaN
# 2  {'en': 'Haifa, Israel', 'no': 'Haifa, Israel',... NaN        NaN
# 3  {'en': 'Cambridge, United Kingdom', 'no': 'Cam... NaN        NaN
# 4                                                NaN NaN        NaN

# %%
organization_name=organization_data['nameNow'].apply(pd.Series)[['en']].rename(columns={'en':'organization_name'})
organization_name.head()
# Out:
#                            organization_name
# 0                        Stanford University
# 1                       Niels Bohr Institute
# 2  Technion - Israel Institute of Technology
# 3        MRC Laboratory of Molecular Biology
# 4                                        NaN

# %%
# Extracting the cityNow column
organization_city=organization_data['cityNow'].apply(pd.Series)[['en']]
organization_city=organization_city.rename(columns={'en':'organization_city'})
organization_city.head()
# Out:
#   organization_city
# 0      Stanford, CA
# 1        Copenhagen
# 2             Haifa
# 3         Cambridge
# 4               NaN

# %%
organization_city['organization_city'].unique()
# Out:
# array(['Stanford, CA', 'Copenhagen', 'Haifa', 'Cambridge', nan, 'Trieste',
#        'Cambridge, MA', 'Rehovot', 'Baltimore, MD', 'Berlin-Dahlem',
#        'Munich', 'Göttingen', 'Pasadena, CA', 'Sapporo', 'Tokyo', 'Paris',
#        'Santa Barbara, CA', 'Philadelphia, PA', 'Chicago, IL', 'Louvain',
#        'Berlin', 'Orsay', 'Szeged', 'Heidelberg', 'Moscow',
#        'New York, NY', 'Argonne, IL', 'Long Island, New York, NY',
#        'Dallas, TX', 'Zurich', 'Medford, MA', 'Uppsala', 'Manchester',
#        'Los Angeles, CA', 'London', 'New Orleans, LA', 'Princeton, NJ',
#        'Lund', 'Urbana, IL', 'Vienna', 'La Jolla, CA', 'Holmdel, NJ',
#        'Kingston', 'Helsinki', 'Gothenburg', 'Chapel Hill, NC',
#        'Cold Spring Harbor, NY', 'Nedlands', 'Boston, MA',
#        'Washington, D.C.', 'Stockholm', 'Mülheim an der Ruhr',
#        'Groningen', 'Buenos Aires', 'Hamilton, Ontario', 'Weston Creek',
#        'Pavia', 'St. Louis, MO', 'Boulder, CO', 'Geneva', 'Bristol',
#        'Sèvres', 'Edinburgh', 'Wilmington, DE', 'Harlow', 'Tunis',
#        'Utrecht', 'Bethesda, MD', 'Tübingen', 'San Diego, CA', 'Ghent',
#        'Worcester, MA', 'Evanston, IL', 'Rome', 'Berkeley, CA',
#        'Seattle, WA', 'San Francisco, CA', 'Ithaca, NY', 'Waterloo',
#        'Oxford', 'Nashville, TN', 'Trondheim', 'Rochester, MN',
#        'Tempe, AZ', 'Lisbon', 'West Lafayette, IN', 'Bloomington, IN',
#        'Marburg', 'Ashburn, VA', 'Dublin', 'Irvine, CA', 'Strasbourg',
#        'Garching', 'Houston, TX', 'Pittsburgh, PA', 'Brussels',
#        'Cleveland, OH', 'Toronto', 'Graz', 'Bar Harbor, ME',
#        'New Haven, CT', 'Murray Hill, NJ', 'Research Triangle Park, NC',
#        'Rochester, NY', 'Columbia', 'Basel', 'Palaiseau', 'Rüschlikon',
#        'Munster', 'Ottawa', 'Milan', 'Lidingö, Stockholm', 'Halle',
#        'Madison, WI', 'Sheffield', 'Breisgau', 'Frankfurt-on-the-Main',
#        'Leiden', 'Buffalo, NY', 'Tsukuba', 'Nagoya', 'Schenectady, NY',
#        'St. Petersburg', 'Providence, RI', 'Lausanne', 'Liverpool',
#        'Fairfax, VA', 'Rotterdam', 'Prague', 'Toulouse', 'Maine, ME',
#        'Aarhus', 'Amsterdam', 'Greifswald', 'Richmond, VA', 'Austin, TX',
#        'Greenbelt, MD', 'Walnut Creek, CA', 'Harwell, Berkshire',
#        'Brighton', 'Beckenham', 'Kyoto', 'Hamburg', 'Stuttgart',
#        'Altenberg; Grünau im Almtal', 'Cologne', 'Yorktown Heights, NY',
#        'Batavia, IL', 'Minneapolis, MN', 'Grenoble', 'Salt Lake City, UT',
#        'Mountain View, CA', 'Edmonton', 'Waltham, MA', 'Vancouver',
#        'Greenwich, CT', 'Birmingham', 'Oslo', 'Woods Hole, MA', 'Kiel',
#        'Mainz', 'Durham, NC', 'Memphis, TN', 'Jülich', 'Bodmin',
#        'Columbus, OH', 'Bonn', 'Beverly, MA', 'Bucksburn (Scotland)',
#        'Brooklyn, NY', 'Martinsried', 'Jerusalem', 'Bronx, NY', 'Madrid',
#        'New Brunswick, NJ', 'Calcutta', 'Melbourne', 'Canberra',
#        'Cardiff', 'Nottingham', 'Leipzig', 'Kashiwa', 'Bern',
#        'College Park, MD', 'Hertfordshire', 'Beijing', 'Innsbruck',
#        'Nancy', 'Würzburg', 'Madison, NJ', 'Gaithersburg, MD',
#        'Rueil-Malmaison'], dtype=object)

# %%
# Extracting the countryNow column 
organization_country=organization_data['countryNow'].apply(pd.Series)[['en']]
organization_country=organization_country.rename(columns={'en':'organization_country'})
organization_country.head()
# Out:
#   organization_country
# 0                  USA
# 1              Denmark
# 2               Israel
# 3       United Kingdom
# 4                  NaN

# %%
organization_country['organization_country'].unique()
# Out:
# array(['USA', 'Denmark', 'Israel', 'United Kingdom', nan, 'Italy',
#        'Germany', 'Japan', 'France', 'Belgium', 'Hungary', 'Russia',
#        'Switzerland', 'Sweden', 'Austria', 'Canada', 'Finland',
#        'Australia', 'the Netherlands', 'Argentina', 'Tunisia', 'Norway',
#        'Portugal', 'Ireland', 'Czech Republic', 'Spain', 'India', 'China'],
#       dtype=object)

# %% [markdown]
# #### Adding all new dataframe to the Original Dataframe

# %%
all_laureates_data=pd.concat([all_laureates_data,award_year_data,prize_share_data,date_Awarded_data,motivation_data,category_data_new,prize_title_data,organization_name,organization_city,organization_country],axis=1)

# %%
all_laureates_data.columns
# Out:
# Index(['id', 'gender', 'birth', 'wikipedia', 'wikidata', 'sameAs', 'links',
#        'nobelPrizes', 'death', 'orgName', 'acronym', 'founded', 'nativeName',
#        'penName', 'penNameOf', 'foundedCountry', 'foundedCountryNow',
#        'foundedContinent', 'laureate_type', 'birth_city', 'birth_country',
#        'date', 'Fullname', 'awardYear', 'portion', 'dateAwarded', 'motivation',
#        'category', 'Prize', 'organization_name', 'organization_city',
#        'organization_country'],
#       dtype='object')

# %%
# Removing the un-necessary columns
cols_to_drop=['wikipedia','links','wikidata','sameAs','nobelPrizes','orgName','acronym','founded','nativeName','penName','penNameOf','foundedCountry','foundedCountryNow','foundedContinent']
all_laureates_data.drop(cols_to_drop,axis=1,inplace=True)

# %%
# Printing out the dataframe 
all_laureates_data.head()
# Out:
#      id gender                                              birth  \
# 0   745   male  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1   102   male  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2   779   male  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3   259   male  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4  1004   male                             {'date': '1948-00-00'}
#
#                                                death laureate_type  \
# 0                                                NaN    Individual
# 1  {'date': '2009-09-08', 'place': {'city': {'en'...    Individual
# 2                                                NaN    Individual
# 3  {'date': '2018-11-20', 'place': {'locationStri...    Individual
# 4                                                NaN    Individual
#
#       birth_city                      birth_country        date  \
# 0  Montclair, NJ                                USA  1943-00-00
# 1     Copenhagen                            Denmark  1922-06-19
# 2          Haifa  British Protectorate of Palestine  1947-10-01
# 3         Zelvas                          Lithuania  1926-08-11
# 4            NaN                                NaN  1948-00-00
#
#             Fullname awardYear portion dateAwarded  \
# 0  A. Michael Spence      2001     1/3  2001-10-10
# 1    Aage Niels Bohr      1975     1/3  1975-10-17
# 2  Aaron Ciechanover      2004     1/3  2004-10-06
# 3         Aaron Klug      1982       1  1982-10-18
# 4  Abdulrazak Gurnah      2021       1  2021-10-07
#
#                                           motivation           category  \
# 0  for their analyses of markets with asymmetric ...  Economic Sciences
# 1  for the discovery of the connection between co...            Physics
# 2  for the discovery of ubiquitin-mediated protei...          Chemistry
# 3  for his development of crystallographic electr...          Chemistry
# 4  for his uncompromising and compassionate penet...         Literature
#
#                                                Prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                            organization_name organization_city  \
# 0                        Stanford University      Stanford, CA
# 1                       Niels Bohr Institute        Copenhagen
# 2  Technion - Israel Institute of Technology             Haifa
# 3        MRC Laboratory of Molecular Biology         Cambridge
# 4                                        NaN               NaN
#
#   organization_country
# 0                  USA
# 1              Denmark
# 2               Israel
# 3       United Kingdom
# 4                  NaN

# %%
# Expanding the death columns 
death_data=all_laureates_data['death'].apply(pd.Series)
death_date_data=death_data[['date']]
death_date_data=death_date_data.rename(columns={'date':'death_date'})
death_date_data.head()
# Out:
#    death_date
# 0         NaN
# 1  2009-09-08
# 2         NaN
# 3  2018-11-20
# 4         NaN

# %%
death_data_place=death_data[['place']].apply(pd.Series)['place'].apply(pd.Series)
death_data_place.head()
# Out:
#     0                                               city  \
# 0 NaN                                                NaN
# 1 NaN  {'en': 'Copenhagen', 'no': 'København', 'se': ...
# 2 NaN                                                NaN
# 3 NaN                                                NaN
# 4 NaN                                                NaN
#
#                                              country  \
# 0                                                NaN
# 1  {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danm...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              cityNow  \
# 0                                                NaN
# 1  {'en': 'Copenhagen', 'no': 'København', 'se': ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           countryNow  \
# 0                                                NaN
# 1  {'en': 'Denmark', 'no': 'Danmark', 'se': 'Danm...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           continent  \
# 0                                               NaN
# 1  {'en': 'Europe', 'no': 'Europa', 'se': 'Europa'}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#                                       locationString
# 0                                                NaN
# 1  {'en': 'Copenhagen, Denmark', 'no': 'København...
# 2                                                NaN
# 3                     {'en': '', 'no': '', 'se': ''}
# 4                                                NaN

# %%
death_city=death_data_place['city'].apply(pd.Series)[['en']].rename(columns={'en':'death_city'})
death_city.head()
# Out:
#    death_city
# 0         NaN
# 1  Copenhagen
# 2         NaN
# 3         NaN
# 4         NaN

# %%
death_country=death_data_place['country'].apply(pd.Series)[['en']].rename(columns={'en':'death_country'})
death_country.head()
# Out:
#   death_country
# 0           NaN
# 1       Denmark
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# Adding this death data to the original dataframe 
# Adding the death_city, death_country
all_laureates_data=pd.concat([all_laureates_data,death_city,death_country],axis=1)

# %%
# Adding death_date_data
all_laureates_data=pd.concat([all_laureates_data,death_date_data],axis=1)

# %%
all_laureates_data.head()
# Out:
#      id gender                                              birth  \
# 0   745   male  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1   102   male  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2   779   male  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3   259   male  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4  1004   male                             {'date': '1948-00-00'}
#
#                                                death laureate_type  \
# 0                                                NaN    Individual
# 1  {'date': '2009-09-08', 'place': {'city': {'en'...    Individual
# 2                                                NaN    Individual
# 3  {'date': '2018-11-20', 'place': {'locationStri...    Individual
# 4                                                NaN    Individual
#
#       birth_city                      birth_country        date  \
# 0  Montclair, NJ                                USA  1943-00-00
# 1     Copenhagen                            Denmark  1922-06-19
# 2          Haifa  British Protectorate of Palestine  1947-10-01
# 3         Zelvas                          Lithuania  1926-08-11
# 4            NaN                                NaN  1948-00-00
#
#             Fullname awardYear  ... dateAwarded  \
# 0  A. Michael Spence      2001  ...  2001-10-10
# 1    Aage Niels Bohr      1975  ...  1975-10-17
# 2  Aaron Ciechanover      2004  ...  2004-10-06
# 3         Aaron Klug      1982  ...  1982-10-18
# 4  Abdulrazak Gurnah      2021  ...  2021-10-07
#
#                                           motivation           category  \
# 0  for their analyses of markets with asymmetric ...  Economic Sciences
# 1  for the discovery of the connection between co...            Physics
# 2  for the discovery of ubiquitin-mediated protei...          Chemistry
# 3  for his development of crystallographic electr...          Chemistry
# 4  for his uncompromising and compassionate penet...         Literature
#
#                                                Prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                            organization_name organization_city  \
# 0                        Stanford University      Stanford, CA
# 1                       Niels Bohr Institute        Copenhagen
# 2  Technion - Israel Institute of Technology             Haifa
# 3        MRC Laboratory of Molecular Biology         Cambridge
# 4                                        NaN               NaN
#
#   organization_country  death_city death_country  death_date
# 0                  USA         NaN           NaN         NaN
# 1              Denmark  Copenhagen       Denmark  2009-09-08
# 2               Israel         NaN           NaN         NaN
# 3       United Kingdom         NaN           NaN  2018-11-20
# 4                  NaN         NaN           NaN         NaN
#
# [5 rows x 21 columns]

# %%
all_laureates_data.columns
# Out:
# Index(['id', 'gender', 'birth', 'death', 'laureate_type', 'birth_city',
#        'birth_country', 'date', 'Fullname', 'awardYear', 'portion',
#        'dateAwarded', 'motivation', 'category', 'Prize', 'organization_name',
#        'organization_city', 'organization_country', 'death_city',
#        'death_country', 'death_date'],
#       dtype='object')

# %%
all_laureates_data.drop('death',axis=1,inplace=True)

# %%
all_laureates_data.head()
# Out:
#      id gender                                              birth  \
# 0   745   male  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1   102   male  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2   779   male  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3   259   male  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4  1004   male                             {'date': '1948-00-00'}
#
#   laureate_type     birth_city                      birth_country        date  \
# 0    Individual  Montclair, NJ                                USA  1943-00-00
# 1    Individual     Copenhagen                            Denmark  1922-06-19
# 2    Individual          Haifa  British Protectorate of Palestine  1947-10-01
# 3    Individual         Zelvas                          Lithuania  1926-08-11
# 4    Individual            NaN                                NaN  1948-00-00
#
#             Fullname awardYear portion dateAwarded  \
# 0  A. Michael Spence      2001     1/3  2001-10-10
# 1    Aage Niels Bohr      1975     1/3  1975-10-17
# 2  Aaron Ciechanover      2004     1/3  2004-10-06
# 3         Aaron Klug      1982       1  1982-10-18
# 4  Abdulrazak Gurnah      2021       1  2021-10-07
#
#                                           motivation           category  \
# 0  for their analyses of markets with asymmetric ...  Economic Sciences
# 1  for the discovery of the connection between co...            Physics
# 2  for the discovery of ubiquitin-mediated protei...          Chemistry
# 3  for his development of crystallographic electr...          Chemistry
# 4  for his uncompromising and compassionate penet...         Literature
#
#                                                Prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                            organization_name organization_city  \
# 0                        Stanford University      Stanford, CA
# 1                       Niels Bohr Institute        Copenhagen
# 2  Technion - Israel Institute of Technology             Haifa
# 3        MRC Laboratory of Molecular Biology         Cambridge
# 4                                        NaN               NaN
#
#   organization_country  death_city death_country  death_date
# 0                  USA         NaN           NaN         NaN
# 1              Denmark  Copenhagen       Denmark  2009-09-08
# 2               Israel         NaN           NaN         NaN
# 3       United Kingdom         NaN           NaN  2018-11-20
# 4                  NaN         NaN           NaN         NaN

# %%
# Renaming the columns 
all_laureates_data=all_laureates_data.rename(columns={'id':'laureate_id','Fullname':'fullname','Prize':'prize'})

# %%
all_laureates_data.head()
# Out:
#    laureate_id gender                                              birth  \
# 0          745   male  {'date': '1943-00-00', 'place': {'city': {'en'...
# 1          102   male  {'date': '1922-06-19', 'place': {'city': {'en'...
# 2          779   male  {'date': '1947-10-01', 'place': {'city': {'en'...
# 3          259   male  {'date': '1926-08-11', 'place': {'city': {'en'...
# 4         1004   male                             {'date': '1948-00-00'}
#
#   laureate_type     birth_city                      birth_country        date  \
# 0    Individual  Montclair, NJ                                USA  1943-00-00
# 1    Individual     Copenhagen                            Denmark  1922-06-19
# 2    Individual          Haifa  British Protectorate of Palestine  1947-10-01
# 3    Individual         Zelvas                          Lithuania  1926-08-11
# 4    Individual            NaN                                NaN  1948-00-00
#
#             fullname awardYear portion dateAwarded  \
# 0  A. Michael Spence      2001     1/3  2001-10-10
# 1    Aage Niels Bohr      1975     1/3  1975-10-17
# 2  Aaron Ciechanover      2004     1/3  2004-10-06
# 3         Aaron Klug      1982       1  1982-10-18
# 4  Abdulrazak Gurnah      2021       1  2021-10-07
#
#                                           motivation           category  \
# 0  for their analyses of markets with asymmetric ...  Economic Sciences
# 1  for the discovery of the connection between co...            Physics
# 2  for the discovery of ubiquitin-mediated protei...          Chemistry
# 3  for his development of crystallographic electr...          Chemistry
# 4  for his uncompromising and compassionate penet...         Literature
#
#                                                prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                            organization_name organization_city  \
# 0                        Stanford University      Stanford, CA
# 1                       Niels Bohr Institute        Copenhagen
# 2  Technion - Israel Institute of Technology             Haifa
# 3        MRC Laboratory of Molecular Biology         Cambridge
# 4                                        NaN               NaN
#
#   organization_country  death_city death_country  death_date
# 0                  USA         NaN           NaN         NaN
# 1              Denmark  Copenhagen       Denmark  2009-09-08
# 2               Israel         NaN           NaN         NaN
# 3       United Kingdom         NaN           NaN  2018-11-20
# 4                  NaN         NaN           NaN         NaN

# %%
all_laureates_data.columns
# Out:
# Index(['laureate_id', 'gender', 'birth', 'laureate_type', 'birth_city',
#        'birth_country', 'date', 'fullname', 'awardYear', 'portion',
#        'dateAwarded', 'motivation', 'category', 'prize', 'organization_name',
#        'organization_city', 'organization_country', 'death_city',
#        'death_country', 'death_date'],
#       dtype='object')

# %%
# Reordering the columns 
new_order=['laureate_id','awardYear','category', 'prize','motivation','portion','laureate_type', 'fullname','gender', 'birth_city', 'birth_country',
       'date',  'dateAwarded', 'organization_name', 'organization_city','organization_country', 'death_city', 'death_country', 'death_date']

# %%
# Dataframe with reorded columns 
all_laureates_data=all_laureates_data.reindex(columns=new_order)
all_laureates_data.head()
# Out:
#    laureate_id awardYear           category  \
# 0          745      2001  Economic Sciences
# 1          102      1975            Physics
# 2          779      2004          Chemistry
# 3          259      1982          Chemistry
# 4         1004      2021         Literature
#
#                                                prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                                           motivation portion laureate_type  \
# 0  for their analyses of markets with asymmetric ...     1/3    Individual
# 1  for the discovery of the connection between co...     1/3    Individual
# 2  for the discovery of ubiquitin-mediated protei...     1/3    Individual
# 3  for his development of crystallographic electr...       1    Individual
# 4  for his uncompromising and compassionate penet...       1    Individual
#
#             fullname gender     birth_city                      birth_country  \
# 0  A. Michael Spence   male  Montclair, NJ                                USA
# 1    Aage Niels Bohr   male     Copenhagen                            Denmark
# 2  Aaron Ciechanover   male          Haifa  British Protectorate of Palestine
# 3         Aaron Klug   male         Zelvas                          Lithuania
# 4  Abdulrazak Gurnah   male            NaN                                NaN
#
#          date dateAwarded                          organization_name  \
# 0  1943-00-00  2001-10-10                        Stanford University
# 1  1922-06-19  1975-10-17                       Niels Bohr Institute
# 2  1947-10-01  2004-10-06  Technion - Israel Institute of Technology
# 3  1926-08-11  1982-10-18        MRC Laboratory of Molecular Biology
# 4  1948-00-00  2021-10-07                                        NaN
#
#   organization_city organization_country  death_city death_country  death_date
# 0      Stanford, CA                  USA         NaN           NaN         NaN
# 1        Copenhagen              Denmark  Copenhagen       Denmark  2009-09-08
# 2             Haifa               Israel         NaN           NaN         NaN
# 3         Cambridge       United Kingdom         NaN           NaN  2018-11-20
# 4               NaN                  NaN         NaN           NaN         NaN

# %%
all_laureates_data['laureate_id'].max()
# Out:
# 1046

# %%
all_laureates_data['laureate_id'].min()
# Out:
# 1

# %%
# Checking if our dataset contains any duplicated data or not
all_laureates_data[all_laureates_data['laureate_id'].duplicated()]
# No duplicated data is present
# Out:
# Empty DataFrame
# Columns: [laureate_id, awardYear, category, prize, motivation, portion, laureate_type, fullname, gender, birth_city, birth_country, date, dateAwarded, organization_name, organization_city, organization_country, death_city, death_country, death_date]
# Index: []

# %%
all_laureates_data
# Out:
#       laureate_id awardYear                category  \
# 0             745      2001       Economic Sciences
# 1             102      1975                 Physics
# 2             779      2004               Chemistry
# 3             259      1982               Chemistry
# 4            1004      2021              Literature
# ...           ...       ...                     ...
# 999           826      2008                 Physics
# 1000          927      2016  Physiology or Medicine
# 1001          265      1986               Chemistry
# 1002          794      2005               Chemistry
# 1003          726      2000                 Physics
#
#                                                   prize  \
# 0     The Sveriges Riksbank Prize in Economic Scienc...
# 1                       The Nobel Prize in Physics 1975
# 2                     The Nobel Prize in Chemistry 2004
# 3                     The Nobel Prize in Chemistry 1982
# 4                    The Nobel Prize in Literature 2021
# ...                                                 ...
# 999                     The Nobel Prize in Physics 2008
# 1000     The Nobel Prize in Physiology or Medicine 2016
# 1001                  The Nobel Prize in Chemistry 1986
# 1002                  The Nobel Prize in Chemistry 2005
# 1003                    The Nobel Prize in Physics 2000
#
#                                              motivation portion laureate_type  \
# 0     for their analyses of markets with asymmetric ...     1/3    Individual
# 1     for the discovery of the connection between co...     1/3    Individual
# 2     for the discovery of ubiquitin-mediated protei...     1/3    Individual
# 3     for his development of crystallographic electr...       1    Individual
# 4     for his uncompromising and compassionate penet...       1    Individual
# ...                                                 ...     ...           ...
# 999   for the discovery of the mechanism of spontane...     1/2    Individual
# 1000    for his discoveries of mechanisms for autophagy       1    Individual
# 1001  for their contributions concerning the dynamic...     1/3    Individual
# 1002  for the development of the metathesis method i...     1/3    Individual
# 1003  for developing semiconductor heterostructures ...     1/4    Individual
#
#                fullname gender           birth_city  \
# 0     A. Michael Spence   male        Montclair, NJ
# 1       Aage Niels Bohr   male           Copenhagen
# 2     Aaron Ciechanover   male                Haifa
# 3            Aaron Klug   male               Zelvas
# 4     Abdulrazak Gurnah   male                  NaN
# ...                 ...    ...                  ...
# 999      Yoichiro Nambu   male                Tokyo
# 1000   Yoshinori Ohsumi   male              Fukuoka
# 1001        Yuan T. Lee   male              Hsinchu
# 1002       Yves Chauvin   male                Menin
# 1003  Zhores I. Alferov   male  Vitebsk, Belorussia
#
#                           birth_country        date dateAwarded  \
# 0                                   USA  1943-00-00  2001-10-10
# 1                               Denmark  1922-06-19  1975-10-17
# 2     British Protectorate of Palestine  1947-10-01  2004-10-06
# 3                             Lithuania  1926-08-11  1982-10-18
# 4                                   NaN  1948-00-00  2021-10-07
# ...                                 ...         ...         ...
# 999                               Japan  1921-01-18  2008-10-07
# 1000                              Japan  1945-02-09  2016-10-03
# 1001                             Taiwan  1936-11-19  1986-10-15
# 1002                            Belgium  1930-10-10  2005-10-05
# 1003                               USSR  1930-03-15  2000-10-10
#
#                                   organization_name organization_city  \
# 0                               Stanford University      Stanford, CA
# 1                              Niels Bohr Institute        Copenhagen
# 2         Technion - Israel Institute of Technology             Haifa
# 3               MRC Laboratory of Molecular Biology         Cambridge
# 4                                               NaN               NaN
# ...                                             ...               ...
# 999   Enrico Fermi Institute, University of Chicago       Chicago, IL
# 1000                  Tokyo Institute of Technology             Tokyo
# 1001                       University of California      Berkeley, CA
# 1002                   Institut Français du Pétrole   Rueil-Malmaison
# 1003         A.F. Ioffe Physico-Technical Institute    St. Petersburg
#
#      organization_country      death_city death_country  death_date
# 0                     USA             NaN           NaN         NaN
# 1                 Denmark      Copenhagen       Denmark  2009-09-08
# 2                  Israel             NaN           NaN         NaN
# 3          United Kingdom             NaN           NaN  2018-11-20
# 4                     NaN             NaN           NaN         NaN
# ...                   ...             ...           ...         ...
# 999                   USA           Osaka         Japan  2015-07-05
# 1000                Japan             NaN           NaN         NaN
# 1001                  USA             NaN           NaN         NaN
# 1002               France           Tours        France  2015-01-27
# 1003               Russia  St. Petersburg        Russia  2019-03-01
#
# [1004 rows x 19 columns]

# %%
all_laureates_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   laureate_id           1004 non-null   int64
#  1   awardYear             1004 non-null   object
#  2   category              1004 non-null   object
#  3   prize                 1004 non-null   object
#  4   motivation            1004 non-null   object
#  5   portion               1004 non-null   object
#  6   laureate_type         1004 non-null   object
#  7   fullname              976 non-null    object
#  8   gender                976 non-null    object
#  9   birth_city            972 non-null    object
#  10  birth_country         974 non-null    object
#  11  date                  976 non-null    object
#  12  dateAwarded           1004 non-null   object
#  13  organization_name     741 non-null    object
#  14  organization_city     736 non-null    object
#  15  organization_country  738 non-null    object
#  16  death_city            659 non-null    object
#  17  death_country         665 non-null    object
#  18  death_date            680 non-null    object
# dtypes: int64(1), object(18)
# memory usage: 149.2+ KB

# %%
# We need to change the dtype of the awardYear,laureate_id  to int

# %%
all_laureates_data['awardYear'].astype('int')
all_laureates_data['laureate_id'].astype('int')
# Out:
# 0        745
# 1        102
# 2        779
# 3        259
# 4       1004
#         ...
# 999      826
# 1000     927
# 1001     265
# 1002     794
# 1003     726
# Name: laureate_id, Length: 1004, dtype: int32

# %%
all_laureates_data['category'].unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Literature', 'Peace',
#        'Physiology or Medicine'], dtype=object)

# %%
all_laureates_data.sort_values(by='awardYear')
# Out:
#      laureate_id awardYear                category  \
# 961            1      1901                 Physics
# 447          160      1901               Chemistry
# 235          293      1901  Physiology or Medicine
# 893          569      1901              Literature
# 286          463      1901                   Peace
# ..           ...       ...                     ...
# 306         1036      2024  Physiology or Medicine
# 943         1035      2024  Physiology or Medicine
# 186         1040      2024               Chemistry
# 451         1046      2024       Economic Sciences
# 856         1045      2024       Economic Sciences
#
#                                                  prize  \
# 961                    The Nobel Prize in Physics 1901
# 447                  The Nobel Prize in Chemistry 1901
# 235     The Nobel Prize in Physiology or Medicine 1901
# 893                 The Nobel Prize in Literature 1901
# 286                         The Nobel Peace Prize 1901
# ..                                                 ...
# 306     The Nobel Prize in Physiology or Medicine 2024
# 943     The Nobel Prize in Physiology or Medicine 2024
# 186                  The Nobel Prize in Chemistry 2024
# 451  The Sveriges Riksbank Prize in Economic Scienc...
# 856  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation portion laureate_type  \
# 961  in recognition of the extraordinary services h...       1    Individual
# 447  in recognition of the extraordinary services h...       1    Individual
# 235  for his work on serum therapy, especially its ...       1    Individual
# 893  in special recognition of his poetic compositi...       1    Individual
# 286  for his lifelong work for international peace ...     1/2    Individual
# ..                                                 ...     ...           ...
# 306  for the discovery of microRNA and its role in ...     1/2    Individual
# 943  for the discovery of microRNA and its role in ...     1/2    Individual
# 186                   for protein structure prediction     1/4    Individual
# 451  for studies of how institutions are formed and...     1/3    Individual
# 856  for studies of how institutions are formed and...     1/3    Individual
#
#                          fullname gender    birth_city    birth_country  \
# 961        Wilhelm Conrad Röntgen   male        Lennep          Prussia
# 447  Jacobus Henricus van 't Hoff   male     Rotterdam  the Netherlands
# 235        Emil Adolf von Behring   male      Hansdorf          Prussia
# 893               Sully Prudhomme   male         Paris           France
# 286                Frédéric Passy   male         Paris           France
# ..                            ...    ...           ...              ...
# 306                   Gary Ruvkun   male  Berkeley, CA              USA
# 943                 Victor Ambros   male   Hanover, NH              USA
# 186                Demis Hassabis   male        London   United Kingdom
# 451             James A. Robinson   male           NaN              NaN
# 856   Simon Henry Roberts Johnson   male     Sheffield   United Kingdom
#
#            date dateAwarded                            organization_name  \
# 961  1845-03-27  1901-11-12                            Munich University
# 447  1852-08-30  1901-11-12                            Berlin University
# 235  1854-03-15  1901-10-30                           Marburg University
# 893  1839-03-16  1901-11-14                                          NaN
# 286  1822-05-20  1901-12-10                                          NaN
# ..          ...         ...                                          ...
# 306  1952-00-00  2024-10-07               Massachusetts General Hospital
# 943  1953-12-01  2024-10-07                    UMass Chan Medical School
# 186  1976-07-27  2024-10-09                              Google DeepMind
# 451  1960-00-00  2024-10-14                        University of Chicago
# 856  1963-00-00  2024-10-14  Massachusetts Institute of Technology (MIT)
#
#     organization_city organization_country death_city death_country  \
# 961            Munich              Germany     Munich       Germany
# 447            Berlin              Germany     Berlin       Germany
# 235           Marburg              Germany    Marburg       Germany
# 893               NaN                  NaN   Châtenay        France
# 286               NaN                  NaN      Paris        France
# ..                ...                  ...        ...           ...
# 306        Boston, MA                  USA        NaN           NaN
# 943     Worcester, MA                  USA        NaN           NaN
# 186            London       United Kingdom        NaN           NaN
# 451       Chicago, IL                  USA        NaN           NaN
# 856     Cambridge, MA                  USA        NaN           NaN
#
#      death_date
# 961  1923-02-10
# 447  1911-03-01
# 235  1917-03-31
# 893  1907-09-07
# 286  1912-06-12
# ..          ...
# 306         NaN
# 943         NaN
# 186         NaN
# 451         NaN
# 856         NaN
#
# [1004 rows x 19 columns]

# %%
all_laureates_data['category'].unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Literature', 'Peace',
#        'Physiology or Medicine'], dtype=object)

# %%
all_laureates_data.head()
# Out:
#    laureate_id awardYear           category  \
# 0          745      2001  Economic Sciences
# 1          102      1975            Physics
# 2          779      2004          Chemistry
# 3          259      1982          Chemistry
# 4         1004      2021         Literature
#
#                                                prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                                           motivation portion laureate_type  \
# 0  for their analyses of markets with asymmetric ...     1/3    Individual
# 1  for the discovery of the connection between co...     1/3    Individual
# 2  for the discovery of ubiquitin-mediated protei...     1/3    Individual
# 3  for his development of crystallographic electr...       1    Individual
# 4  for his uncompromising and compassionate penet...       1    Individual
#
#             fullname gender     birth_city                      birth_country  \
# 0  A. Michael Spence   male  Montclair, NJ                                USA
# 1    Aage Niels Bohr   male     Copenhagen                            Denmark
# 2  Aaron Ciechanover   male          Haifa  British Protectorate of Palestine
# 3         Aaron Klug   male         Zelvas                          Lithuania
# 4  Abdulrazak Gurnah   male            NaN                                NaN
#
#          date dateAwarded                          organization_name  \
# 0  1943-00-00  2001-10-10                        Stanford University
# 1  1922-06-19  1975-10-17                       Niels Bohr Institute
# 2  1947-10-01  2004-10-06  Technion - Israel Institute of Technology
# 3  1926-08-11  1982-10-18        MRC Laboratory of Molecular Biology
# 4  1948-00-00  2021-10-07                                        NaN
#
#   organization_city organization_country  death_city death_country  death_date
# 0      Stanford, CA                  USA         NaN           NaN         NaN
# 1        Copenhagen              Denmark  Copenhagen       Denmark  2009-09-08
# 2             Haifa               Israel         NaN           NaN         NaN
# 3         Cambridge       United Kingdom         NaN           NaN  2018-11-20
# 4               NaN                  NaN         NaN           NaN         NaN

# %% [markdown]
# # Stage - Data Cleaning

# %% [markdown]
# ### Checking Individual Columns

# %% [markdown]
# #### Gender Column

# %%
all_laureates_data['gender'].unique()
# Out:
# array(['male', 'female', nan], dtype=object)

# %%
all_laureates_data[all_laureates_data['gender'].isnull()].head()
# Out:
#      laureate_id awardYear category                       prize  \
# 51           509      1947    Peace  The Nobel Peace Prize 1947
# 52           537      1977    Peace  The Nobel Peace Prize 1977
# 134         1020      2022    Peace  The Nobel Peace Prize 2022
# 195          568      1999    Peace  The Nobel Peace Prize 1999
# 261          881      2012    Peace  The Nobel Peace Prize 2012
#
#                                             motivation portion laureate_type  \
# 51   for their pioneering work in the international...     1/2  Organization
# 52              for worldwide respect for human rights       1  Organization
# 134  The Peace Prize laureates represent civil soci...     1/3  Organization
# 195  in recognition of the organisation's pioneerin...       1  Organization
# 261  for over six decades contributed to the advanc...       1  Organization
#
#     fullname gender birth_city birth_country date dateAwarded  \
# 51       NaN    NaN        NaN           NaN  NaN  1947-10-30
# 52       NaN    NaN        NaN           NaN  NaN  1977-10-10
# 134      NaN    NaN        NaN           NaN  NaN  2022-10-07
# 195      NaN    NaN        NaN           NaN  NaN  1999-10-15
# 261      NaN    NaN        NaN           NaN  NaN  2012-10-12
#
#     organization_name organization_city organization_country death_city  \
# 51                NaN               NaN                  NaN        NaN
# 52                NaN               NaN                  NaN        NaN
# 134               NaN               NaN                  NaN        NaN
# 195               NaN               NaN                  NaN        NaN
# 261               NaN               NaN                  NaN        NaN
#
#     death_country death_date
# 51            NaN        NaN
# 52            NaN        NaN
# 134           NaN        NaN
# 195           NaN        NaN
# 261           NaN        NaN

# %% [markdown]
# #### Counting Null Values in every columns

# %%
all_laureates_data.isnull().sum()
# Out:
# laureate_id               0
# awardYear                 0
# category                  0
# prize                     0
# motivation                0
# portion                   0
# laureate_type             0
# fullname                 28
# gender                   28
# birth_city               32
# birth_country            30
# date                     28
# dateAwarded               0
# organization_name       263
# organization_city       268
# organization_country    266
# death_city              345
# death_country           339
# death_date              324
# dtype: int64

# %%
# Renaming the date as birthdat
all_laureates_data.rename(columns={'date':'birth_date'},inplace=True)

# %%
all_laureates_data.head()
# Out:
#    laureate_id awardYear           category  \
# 0          745      2001  Economic Sciences
# 1          102      1975            Physics
# 2          779      2004          Chemistry
# 3          259      1982          Chemistry
# 4         1004      2021         Literature
#
#                                                prize  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...
# 1                    The Nobel Prize in Physics 1975
# 2                  The Nobel Prize in Chemistry 2004
# 3                  The Nobel Prize in Chemistry 1982
# 4                 The Nobel Prize in Literature 2021
#
#                                           motivation portion laureate_type  \
# 0  for their analyses of markets with asymmetric ...     1/3    Individual
# 1  for the discovery of the connection between co...     1/3    Individual
# 2  for the discovery of ubiquitin-mediated protei...     1/3    Individual
# 3  for his development of crystallographic electr...       1    Individual
# 4  for his uncompromising and compassionate penet...       1    Individual
#
#             fullname gender     birth_city                      birth_country  \
# 0  A. Michael Spence   male  Montclair, NJ                                USA
# 1    Aage Niels Bohr   male     Copenhagen                            Denmark
# 2  Aaron Ciechanover   male          Haifa  British Protectorate of Palestine
# 3         Aaron Klug   male         Zelvas                          Lithuania
# 4  Abdulrazak Gurnah   male            NaN                                NaN
#
#    birth_date dateAwarded                          organization_name  \
# 0  1943-00-00  2001-10-10                        Stanford University
# 1  1922-06-19  1975-10-17                       Niels Bohr Institute
# 2  1947-10-01  2004-10-06  Technion - Israel Institute of Technology
# 3  1926-08-11  1982-10-18        MRC Laboratory of Molecular Biology
# 4  1948-00-00  2021-10-07                                        NaN
#
#   organization_city organization_country  death_city death_country  death_date
# 0      Stanford, CA                  USA         NaN           NaN         NaN
# 1        Copenhagen              Denmark  Copenhagen       Denmark  2009-09-08
# 2             Haifa               Israel         NaN           NaN         NaN
# 3         Cambridge       United Kingdom         NaN           NaN  2018-11-20
# 4               NaN                  NaN         NaN           NaN         NaN

# %%
all_laureates_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   laureate_id           1004 non-null   int64
#  1   awardYear             1004 non-null   object
#  2   category              1004 non-null   object
#  3   prize                 1004 non-null   object
#  4   motivation            1004 non-null   object
#  5   portion               1004 non-null   object
#  6   laureate_type         1004 non-null   object
#  7   fullname              976 non-null    object
#  8   gender                976 non-null    object
#  9   birth_city            972 non-null    object
#  10  birth_country         974 non-null    object
#  11  birth_date            976 non-null    object
#  12  dateAwarded           1004 non-null   object
#  13  organization_name     741 non-null    object
#  14  organization_city     736 non-null    object
#  15  organization_country  738 non-null    object
#  16  death_city            659 non-null    object
#  17  death_country         665 non-null    object
#  18  death_date            680 non-null    object
# dtypes: int64(1), object(18)
# memory usage: 149.2+ KB

# %%
# Changing the type of columns to appropiate types 
all_laureates_data['awardYear'].astype(int)
# Out:
# 0       2001
# 1       1975
# 2       2004
# 3       1982
# 4       2021
#         ...
# 999     2008
# 1000    2016
# 1001    1986
# 1002    2005
# 1003    2000
# Name: awardYear, Length: 1004, dtype: int32

# %%
import datetime

# %%
date=datetime.datetime(1943,1,1)

# %%
datetime.datetime?
# Out:
# Init signature: datetime.datetime(self, /, *args, **kwargs)
# Docstring:
# datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#
# The year, month and day arguments are required. tzinfo may be None, or an
# instance of a tzinfo subclass. The remaining arguments may be ints.
# File:           c:\users\dassa\anaconda3\lib\datetime.py
# Type:           type
# Subclasses:     ABCTimestamp, _NaT

# %%
# To convert a string into datetime object we can use strptime()

# %%
date
# Out:
# datetime.datetime(1943, 1, 1, 0, 0)

# %%
date_data={'date':['1943-01-12','1999-09-25']}

# %%
date_df=pd.DataFrame(date_data)

# %%
def split_date_str(date):
    date=date.split("-")
    date_num=[int(i) for i in date]
    return date_num

# %%
split_date_str('1943-01-12')
# Out:
# [1943, 1, 12]

# %%
datetime.datetime.strptime('1943-01-12','%Y-%m-%d')
# Out:
# datetime.datetime(1943, 1, 12, 0, 0)

# %%
# Creating a function 
def convert_datestr_datetime(date):
    return datetime.datetime.strptime(date,'%Y-%m-%d')

# %%
date_df['date'].apply(convert_datestr_datetime)
# Out:
# 0   1943-01-12
# 1   1999-09-25
# Name: date, dtype: datetime64[ns]
